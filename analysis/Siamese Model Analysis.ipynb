# %%
import sys

sys.path.append('../generate_dataset/resources')
sys.path.append('../Siamese')
import SiameseNet
from pytorch_fast_elmo import FastElmo, batch_to_char_ids
import sys
from scipy.cluster.hierarchy import dendrogram, linkage
import scipy
import matplotlib.pyplot as plt
import random
import torch
from typing import List
import numpy as np
import utils
import termcolor


from typing import NewType

# %%
class Vector(object):
    
    def __init__(self, vec, sentence, index):
        
        self.vec = vec
        self.sentence = sentence
        self.index = index
        self.size = np.linalg.norm(self.vec)
    
    def get_word(self):
        
        return self.sentence[self.index]
    
    def get_vector(self): 
        
        return self.vec
    
    def get_sentence(self):
        
        return self.sentence
    
    def get_index(self):
        
        return self.index
    
    def get_size(self):
        
        return self.size
    
    def __str__(self):
        
        words = self.get_sentence()
        i = self.get_index()
        before = " ".join(words[:i])
        after = " ".join(words[i + 1:])
        word = termcolor.colored(self.get_word(), "blue", attrs = ['bold'])
        sent = '""' + before + " " + word + " " + after + '"'
        return sent
    
    def similarity(self, other):
        
        if other is self: return -np.inf
        
        return self.get_vector().dot(other.get_vector())/(self.get_size() * other.get_size())
    
    @staticmethod
    def get_closest_vector(vec, vecs):
    
        closest = max(vecs, key = lambda vector: vector.similarity(vec))
        return closest

# %%
def transform(model, vector: Vector):
    
    vec_pytorch = torch.from_numpy(vector.get_vector()).float()
    vector.vec = model._represent(vec_pytorch).detach().numpy()
    
    
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
def print_closest_vectors(sample, all_vecs):
    
    for vector in sample:
        closest = Vector.get_closest_vector(vector, all_vecs)
        print("The closest vector to\n{}\nIs\n{} \n ==========================================\n".format(vector, closest))
    
def load_sents(fname = "sents_f", max_length = 15):
    
    with open(fname, "r") as f:
              
        lines = f.readlines()
    
    lines =  [line.strip().split(" ") for line in lines]
    if max_length is not None:
        lines = list(filter(lambda sentence: len(sentence) < max_length, lines))
    return lines

def load_model(name = "model.pt"):
    net = SiameseNet.SiameseNet()
    net.load_state_dict(torch.load(name))
    net.eval()
    return net

def list_vectors(vecs, sents: List[List[str]]) -> List[Vector]:
    
    num_sentences = len(sents)
    sents_indices_and_vecs =  zip(range(num_sentences), vecs)
    all_vectors = []

    for sent_index, sent_vectors in sents_indices_and_vecs:
        
        for i, (w,vec) in enumerate(zip(sents[sent_index], vecs[sent_index])):   
            
            v = Vector(vec.detach().numpy(), sents[sent_index], i)
            all_vectors.append(v)
            
    return all_vectors

# %% [markdown]
# Load pretrained ELMO and a collection of Wikipedia sentences.

# %%
all_sentences = load_sents(max_length = 15)
options_file = "../generate_dataset/" + utils.DEFAULT_PARAMS["elmo_options"]
weight_file = "../generate_dataset/" + utils.DEFAULT_PARAMS["elmo_weights"]
elmo = FastElmo(options_file, weight_file)

# %%
N = 1000
subset_size = 150
random.seed(0)
sentences = all_sentences[:N]

# %% [markdown]
# Collect ELMO states over N sentences, and load pretrained Siamese network.

# %%
character_ids = batch_to_char_ids(sentences)
embeddings = elmo(character_ids) # collect elmo states
network = load_model()

# %% [markdown]
# ### Find the closest vectors to a collection of (original) ELMO vectors.

# %%
vecs = list_vectors(embeddings["elmo_representations"][0], sentences)
subset = np.random.choice(vecs, size = subset_size)
print_closest_vectors(subset, vecs)
# Out:
# The closest vector to
# ""the girls quickly flee back to land , but the couple follows them ."
# Is
# ""the groom carries the bride on his back and runs away with her ."
#  ==========================================
#
# The closest vector to
# ""some of his most prominent roles are his appearances in er as dr ."
# Is
# ""some of the organizations are actually the youth wings of larger political parties ."
#  ==========================================
#
# The closest vector to
# ""garcia blasts morales with a left hook that launches morales through the ropes . "
# Is
# ""german night fighters , although five more bombers crash upon returning to england . "
#  ==========================================
#
# The closest vector to
# ""i called the tune , i could not get them to dance together ."
# Is
# ""perry was called to the bar in 1980 and took silk in 2006 ."
#  ==========================================
#
# The closest vector to
# ""there is little or no percussion and rhythm is not a prominent element ."
# Is
# ""there is little or no percussion and rhythm is not a prominent element ."
#  ==========================================
#
# The closest vector to
# ""complete participation researcher is completely integrated in population of study beforehand ( i ."
# Is
# ""yes , because recording the author of a completely faithful reproduction is pointless ."
#  ==========================================
#
# The closest vector to
# ""adds nothing to the reader 's understanding of society 's perspective on napoleon ."
# Is
# ""each of these historians shed light on the topic from a different perspective ."
#  ==========================================
#
# The closest vector to
# ""the opposition has also forced the government to cancel the annual military parade ."
# Is
# ""a procession also took place in the honor of the temple of heaven ."
#  ==========================================
#
# The closest vector to
# ""see rules of the supreme court of the united states ( 2005 ed ."
# Is
# ""see rules of the supreme court of the united states ( 2005 ed ."
#  ==========================================
#
# The closest vector to
# ""the birds of the gambia ( 2nd edition , 1991 ) by m ."
# Is
# ""the ocean liner ran aground in the río grande do sul , brazil ."
#  ==========================================
#
# The closest vector to
# ""the khmer rouge gave us guns and pushed us into the front line ."
# Is
# ""strong support experienced member , often reverts vandalism and beats me to it ."
#  ==========================================
#
# The closest vector to
# ""estimated height is 69 to 92 feet ( 21 to 28 meters ) ."
# Is
# ""non notable road ( not a highway or some main city road ) ."
#  ==========================================
#
# The closest vector to
# ""i 've been known to rush to judgment on far too many occasions ."
# Is
# ""this village is known as birthplace of famous freedom fighter dal bahadur singh ."
#  ==========================================
#
# The closest vector to
# ""the first endowment of the fund was 2 million us dollar from mr ."
# Is
# ""on byron glacier alone , researchers estimate the worms numbered around 30 million ."
#  ==========================================
#
# The closest vector to
# ""lion red rugby league annual , new zealand rugby football league , 1986 ."
# Is
# ""lion red rugby league annual , new zealand rugby football league , 1986 ."
#  ==========================================
#
# The closest vector to
# ""opinions , when informed , and criticism , when constructive , are valuable ."
# Is
# ""opinions , when informed , and criticism , when constructive , are valuable ."
#  ==========================================
#
# The closest vector to
# ""i trust we have an admin here who knows what to do next !"
# Is
# ""we are writing an encyclopedia here , we are not an advertising service ."
#  ==========================================
#
# The closest vector to
# ""the london business houses bridges relay is run on the same course annually ."
# Is
# ""it is run and edited by students at uc berkeley school of law ."
#  ==========================================
#
# The closest vector to
# ""as for the last comment there , i am seeking an objective decision ."
# Is
# ""for instance , like the red link i have given to you above ."
#  ==========================================
#
# The closest vector to
# ""if so , no problem , it will take less than a minute ."
# Is
# "" so , since redirects are cheap , we can go with this alternative ."
#  ==========================================
#
# The closest vector to
# ""national archives and records administration ( talk ) stub-class ( no-class ) added ."
# Is
# ""seven sisters ( queensland ) ( talk ) unassessed-class ( no-class ) added ."
#  ==========================================
#
# The closest vector to
# ""our ball state course students have been coordinating their topic proposals with me ."
# Is
# ""doing it on wiki allows for transparency in your investigation ( s ) ."
#  ==========================================
#
# The closest vector to
# ""senate he was succeeded by another democrat , vincent harrington of sioux city ."
# Is
# ""february 9 , 1984 ) , was a politician in ontario , canada ."
#  ==========================================
#
# The closest vector to
# ""it operated flights mainly to southern europe from its hub at brussels airport ."
# Is
# ""bathurst airport is an airport serving bathurst , new south wales , australia ."
#  ==========================================
#
# The closest vector to
# ""rewrite grammar nazi on the grounds that it is in extremely poor taste ."
# Is
# ""soviets , others from the same school class fighting for the nazi germans ."
#  ==========================================
#
# The closest vector to
# ""when they did so , however , they were hampered by limited skills ."
# Is
# ""efforts to rebuild the niagara were hampered by the lack of original plans ."
#  ==========================================
#
# The closest vector to
# ""the main purpose of the game is control as many locations as possible ."
# Is
# ""my main reason for asking the question and inviting debate was to learn ."
#  ==========================================
#
# The closest vector to
# ""now is a good time to make sure that everything is still verified . "
# Is
# ""whether it is a list or not is left to you to decide . "
#  ==========================================
#
# The closest vector to
# ""the album was still released on victory records on july 6 , 2010 ."
# Is
# ""the fifth volume is scheduled to be released on april 22 , 2009 ."
#  ==========================================
#
# The closest vector to
# ""its average depth is and its maximum depth is , near the dam . "
# Is
# ""for its entire length , it runs roughly parallel to the kern river . "
#  ==========================================
#
# The closest vector to
# ""the discussion was a about the synthesis of sources to advance a point ."
# Is
# ""keep the article is about a notable character from the power rangers franchise ."
#  ==========================================
#
# The closest vector to
# ""different projections contain different assumptions of future social and economic development ( e ."
# Is
# ""different projections contain different assumptions of future social and economic development ( e ."
#  ==========================================
#
# The closest vector to
# ""its school functions have now been taken over by service children 's education ."
# Is
# ""game machines were installed in many department stores and children 's play areas ."
#  ==========================================
#
# The closest vector to
# ""looks like it was split from censorship with just brazil and venezuela ( !"
# Is
# ""made a nom per csd f1 but was declined with no reason why ."
#  ==========================================
#
# The closest vector to
# ""jefferson college ) in 1856 and received a master 's degree in 1859 ."
# Is
# ""sutherland became the pitt coach in 1924 , where he remained through 1938 ."
#  ==========================================
#
# The closest vector to
# ""although he was raised in a religious family , norman was an atheist ."
# Is
# ""the school is housed in a building that was originally the high school ."
#  ==========================================
# The closest vector to
# ""the most common apartment size was 5 rooms of which there were 23 ."
# Is
# ""the most common apartment size was 4 rooms of which there were 26 ."
#  ==========================================
#
# The closest vector to
# ""the report examined nearly 300 individuals and hundreds of classified armed forces signals ."
# Is
# ""he got the name from seeing multiple road signs during a road trip ."
#  ==========================================
#
# The closest vector to
# ""the power plant has 1 generating unit with an installed capacity of 3 ."
# Is
# ""the power plant has 1 generating unit with an installed capacity of 3 ."
#  ==========================================
#
# The closest vector to
# ""ok , i guess this is a test of how closely we read ."
# Is
# ""this is an evolution of a matrix that happens inside one similarity class ."
#  ==========================================
#
# The closest vector to
# "" winters are quite cold with plenty of snow , with temperatures ranging between ."
# Is
# ""the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""the following stadiums are considered home grounds for the teams in the competition ."
# Is
# ""rewrite grammar nazi on the grounds that it is in extremely poor taste ."
#  ==========================================
#
# The closest vector to
# ""note the article under discussion here was tagged for by anonymous spa 64 ."
# Is
# ""additionally , the article you created must stand up to the notability test ."
#  ==========================================
#
# The closest vector to
# ""a hand made by hitting two consecutive cards on the turn and river ."
# Is
# ""the park is filled with small caves , especially on the mountain proper ."
#  ==========================================
#
# The closest vector to
# ""i do not know whether this has anything to do with my question ."
# Is
# ""wp concerned with vaughan politics , if the other afds are any indication ."
#  ==========================================
#
# The closest vector to
# ""former president salad appointed seven people to his cabinet on 4 august 2007 ."
# Is
# ""the cabinet of nigeria is the executive branch of the government of nigeria ."
#  ==========================================
#
# The closest vector to
# ""it would have been nice to have more eyes go through the article ."
# Is
# ""i hope to get an independent assessment on the additions i have made ."
#  ==========================================
#
# The closest vector to
# ""it is a member of the international association of national public health institutes ."
# Is
# ""it is a member of the international association of national public health institutes ."
#  ==========================================
#
# The closest vector to
# ""this experiment provided the first lunar gravity data from a low polar orbit ."
# Is
# ""then we can have a general discussion on whether to extend the experiment ."
#  ==========================================
#
# The closest vector to
# ""he was elected lieutenant governor in 1982 as running mate of richard f ."
# Is
# ""he was a delegate to the democratic national conventions in 1952 and 1956 ."
#  ==========================================
#
# The closest vector to
# ""peaceful world was the first album featuring this new version of the band ."
# Is
# ""their performance at the festival garnered a lot of attention for the band ."
#  ==========================================
#
# The closest vector to
# ""additionally , the article you created must stand up to the notability test ."
# Is
# ""the fourth side was the main stand , which held only 1500 seats ."
#  ==========================================
#
# The closest vector to
# ""sebastian , on the weekend nearest to 20 january , his feast day . "
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories . "
#  ==========================================
#
# The closest vector to
# ""i do not know whether this has anything to do with my question ."
# Is
# ""wp concerned with vaughan politics , if the other afds are any indication ."
#  ==========================================
#
# The closest vector to
# "" the falcons first season was also the start of the super bowl era ."
# Is
# "" the baltimore colts ran a version of the play in december , 1970 ."
#  ==========================================
#
# The closest vector to
# ""he was the son of robert the magnificent , the duke of normandy ."
# Is
# ""he was the eldest son of richard , third son of the hon ."
#  ==========================================
#
# The closest vector to
# ""world series as the chicago white sox defeated the cubs in six games ."
# Is
# ""rbi in the series as the cardinals defeated the mets in seven games ."
#  ==========================================
#
# The closest vector to
# ""not only that , he was the top american ace of the conflict ."
# Is
# ""not only that , he was the top american ace of the conflict ."
#  ==========================================
#
# The closest vector to
# ""the remaining teams either folded or chose to play in lower local leagues ."
# Is
# ""all prisoners were residents of lower saxony ( then province of hanover ) ."
#  ==========================================
#
# The closest vector to
# ""the master of science in administration was added in the winter of 1983 ."
# Is
# ""his intention to provide a similar volume for latin literature was never fulfilled ."
#  ==========================================
#
# The closest vector to
# ""in 1959 all of galway 's competing hurling teams transferred provinces to munster . "
# Is
# ""all four ships participated in the japanese invasion of the dutch east indies . "
#  ==========================================
#
# The closest vector to
# ""he leaves a trail for the police to follow and he is convicted ."
# Is
# ""she is working a low salary job and has gotten into great debts ."
#  ==========================================
#
# The closest vector to
# ""click on that link , and you will go to the redirect page ."
# Is
# ""you can also summarize this in a new section in the evidence page ."
#  ==========================================
#
# The closest vector to
# ""i vote to keep so that it continues to be available to all ."
# Is
# ""point , i still vote delete , for the previous arguments laid out ."
#  ==========================================
#
# The closest vector to
# ""in 1858 , he took up an appointment in rome academy , pennsylvania ."
# Is
# ""in 1996 he was made an honorary student of christ church , oxford ."
#  ==========================================
#
# The closest vector to
# ""the creation of a board of supervision to regulate the poor law system ."
# Is
# ""it was evident , however , that the system needed to be enlarged ."
#  ==========================================
#
# The closest vector to
# ""i think is a pretty reasonable idea , and might also be useful ."
# Is
# ""they might make wikipedia grow faster than the software and hardware can support ."
#  ==========================================
#
# The closest vector to
# ""a small brick waiting shelter was provided for passengers using the up platform ."
# Is
# ""public transport to , from and throughout the area is provided by bus ."
#  ==========================================
#
# The closest vector to
# ""june 5 , 1950 ) was an american author of children 's literature ."
# Is
# ""his intention to provide a similar volume for latin literature was never fulfilled ."
#  ==========================================
#
# The closest vector to
# ""to continue in the face of such criticism tends to imply bad faith ."
# Is
# ""but such situations are necessarily rare , since the policy says they are ."
#  ==========================================
#
# The closest vector to
# ""some members of the group separated themselves from the band to write tracks ."
# Is
# ""though coming from toronto , she went back to hong kong to compete ."
#  ==========================================
# The closest vector to
# ""he received a phd in composition from the university of york in 1984 ."
# Is
# ""he graduated from hamilton college in clinton , new york , in 1823 ."
#  ==========================================
#
# The closest vector to
# ""each member of the project team is expected to keep a project diary ."
# Is
# ""i am ready to make an introduction at the category page to explain ."
#  ==========================================
#
# The closest vector to
# ""the master of science in administration was added in the winter of 1983 ."
# Is
# ""she was recognized for her outstanding research in 2004 with the thomas c ."
#  ==========================================
#
# The closest vector to
# ""some of his most prominent roles are his appearances in er as dr ."
# Is
# ""following his stint at marvel he signed exclusively with dc comics in 2004 ."
#  ==========================================
#
# The closest vector to
# ""but please be careful to record exactly where such ads were originally published ."
# Is
# ""but such situations are necessarily rare , since the policy says they are ."
#  ==========================================
#
# The closest vector to
# "" in 1959 all of galway 's competing hurling teams transferred provinces to munster ."
# Is
# "" in 1988 the front of the cathedral gained a bronze statue of st ."
#  ==========================================
#
# The closest vector to
# ""its school functions have now been taken over by service children 's education ."
# Is
# ""game machines were installed in many department stores and children 's play areas ."
#  ==========================================
#
# The closest vector to
# ""jeremy clarkson bought a red range rover which he believed had a 3 ."
# Is
# ""in 1943 , she obtained a medical degree from the university of chicago ."
#  ==========================================
#
# The closest vector to
# "" the master of science in administration was added in the winter of 1983 ."
# Is
# "" the secretary for scotland became the secretary of state for scotland in 1926 ."
#  ==========================================
#
# The closest vector to
# ""spartans on stage and ticket sales for the show were limited to 300 ."
# Is
# ""we really just tried to get our personality as a team on film ."
#  ==========================================
#
# The closest vector to
# ""bureaucrats that are active regularly are the bureaucrats that were promoted more recently ."
# Is
# ""bureaucrats that are active regularly are the bureaucrats that were promoted more recently ."
#  ==========================================
#
# The closest vector to
# ""the architecture is well founded on formal scheduling analysis and control theoretical results ."
# Is
# ""allows for a systematic evaluation of all potential projects at the same time ."
#  ==========================================
#
# The closest vector to
# ""a hand made by hitting two consecutive cards on the turn and river ."
# Is
# ""i doubt more than a one line update can be made for this ."
#  ==========================================
#
# The closest vector to
# ""jun 2005 ( utc ) close , you 're missing two four things . "
# Is
# ""mar 30 , 2005 ( utc ) apparently , it 's fixed now . "
#  ==========================================
#
# The closest vector to
# ""image of a book cover , found at random house publishers web site . "
# Is
# ""the subject of the article is covered in appropriate detail elsewhere on wikipedia . "
#  ==========================================
#
# The closest vector to
# "" it would have been nice to have more eyes go through the article ."
# Is
# "" it seems like these two should be merged into and categorized by os ."
#  ==========================================
#
# The closest vector to
# "" they immediately gave him the full ten points because they needed more musicians ."
# Is
# "" they actively encouraged his painting activities and later supported him in higher education ."
#  ==========================================
#
# The closest vector to
# ""it was later re-released on the virtual console and on the playstation network ."
# Is
# ""the album was still released on victory records on july 6 , 2010 ."
#  ==========================================
#
# The closest vector to
# ""he was voted the best defender in the 2010 thai division 1 league ."
# Is
# ""denis law is the second greatest goalscorer in the history of manchester united ."
#  ==========================================
#
# The closest vector to
# "" the church was rebuilt after it had been damaged in world war i ."
# Is
# "" the statue was broken in two while being transported to their georgia parish ."
#  ==========================================
#
# The closest vector to
# ""disco tango '' was the danish entry in the eurovision song contest 1979 ."
# Is
# ""payne was born in black rock , barbados , on 21 december 1948 ."
#  ==========================================
#
# The closest vector to
# ""for the defense john cromwell william powell , kay francis , william b ."
# Is
# ""for the defense john cromwell william powell , kay francis , william b ."
#  ==========================================
#
# The closest vector to
# ""the stuff i have found has been dominated by ( 1 ) www . "
# Is
# ""i just do n't see how this page is useful in any ways . "
#  ==========================================
#
# The closest vector to
# ""cyclone justin was the largest tropical cyclone to hit northern queensland in 1997 ."
# Is
# ""it was the first open cup tournament to be named after lamar hunt ."
#  ==========================================
#
# The closest vector to
# ""however , this threatens a massive earthquake that could destroy the entire city ."
# Is
# ""during twelve months of fighting in italy the squadron destroyed 172 enemy aircraft ."
#  ==========================================
#
# The closest vector to
# "" the was a japanese revolutionary armed group , established on 15 july 1971 ."
# Is
# "" the sparrow quartet is an american acoustic music group that formed in 2005 ."
#  ==========================================
#
# The closest vector to
# ""i do not think this treatment of davis reflects well on this project ."
# Is
# ""but i think this reflects a perception of the arbcom as a court ."
#  ==========================================
#
# The closest vector to
# ""if merge , then delete the 2 redirects as they are rather irrelevant ."
# Is
# ""threats against wikipedia only count if they are legal or made on wikipedia ."
#  ==========================================
#
# The closest vector to
# ""it was signed into law by the president of ireland , michael d ."
# Is
# ""after leaving his government job , patrick was a consultant to the u ."
#  ==========================================
#
# The closest vector to
# ""the master of science in administration was added in the winter of 1983 ."
# Is
# ""the university of oregon awarded him their law meritorious service award in 1985 ."
#  ==========================================
#
# The closest vector to
# ""john ridge began unauthorized talks with the jackson administration in the late 1820s . "
# Is
# ""other escaped slaves joined various seminole bands as free members of the tribe . "
#  ==========================================
#
# The closest vector to
# ""signs in the abandoned station also state `` museum '' as the name ."
# Is
# ""titans of the ice age exhibition '' at the field museum in chicago ."
#  ==========================================
#
# The closest vector to
# ""fundraising and architecture plans are underway for a new building in downtown ballard . "
# Is
# ""this sandstone library follows the earlier library plan austin developed at dwight hall . "
#  ==========================================
#
# The closest vector to
# ""landmarks in this area include windsor mill middle school and rutherford business park ."
# Is
# ""landmarks in this area include windsor mill middle school and rutherford business park ."
#  ==========================================
#
# The closest vector to
# ""the falcons first season was also the start of the super bowl era ."
# Is
# ""the falcons first season was also the start of the super bowl era ."
#  ==========================================
#
# The closest vector to
# ""i already added a little information about it to california state route 88 ."
# Is
# ""i added a bit to the introduction as well as the history section ."
#  ==========================================
# The closest vector to
# ""he accused one of those two wikipedians of being on the kennedy payroll ."
# Is
# ""black canary offers her a spot on the new birds of prey roster ."
#  ==========================================
#
# The closest vector to
# ""henry cotton wins his third british open , at the age of 41 ."
# Is
# ""this was his second all star , also winning an award in 2004 ."
#  ==========================================
#
# The closest vector to
# ""michael was amongst a group of leaders of the communist underground in iraq ."
# Is
# ""the was a japanese revolutionary armed group , established on 15 july 1971 ."
#  ==========================================
#
# The closest vector to
# ""automobile magazine named the audi a7 `` 2012 automobile of the year '' ."
# Is
# "" automobile magazine named the audi a7 `` 2012 automobile of the year '' ."
#  ==========================================
#
# The closest vector to
# ""actually , i drafted a good bit of the text of that essay ."
# Is
# ""i already added a little information about it to california state route 88 ."
#  ==========================================
#
# The closest vector to
# ""the fifth volume is scheduled to be released on april 22 , 2009 ."
# Is
# ""putting every household at risk , to be released in september , 2004 ."
#  ==========================================
#
# The closest vector to
# ""i had written that before i saw the newspaper report on that death ."
# Is
# ""the format of the table was done before i saw that other page ."
#  ==========================================
#
# The closest vector to
# ""he then added , `` these damn indians have gone absolutely wild [ ."
# Is
# ""she thinks i 'm crazy but i 'm just growing old '' ) ."
#  ==========================================
#
# The closest vector to
# ""the series aired from july 5 , 1943 to july 6 , 1945 ."
# Is
# ""the series aired from july 5 , 1943 to july 6 , 1945 ."
#  ==========================================
#
# The closest vector to
# ""this will take some time , but i 'll do it , too ."
# Is
# ""the dark knight ( film ) are that i explain them too much ."
#  ==========================================
#
# The closest vector to
# ""the party was registered on 6 january 2011 with the australian electoral commission ."
# Is
# ""andrew 's protestant episcopal church , was already listed on the national register ."
#  ==========================================
#
# The closest vector to
# ""in 1976 he turned professional and won a national title in the sprint ."
# Is
# ""buck baker won the pole and herb thomas was victorious in the race ."
#  ==========================================
#
# The closest vector to
# ""the axis of the rotation can be either inside or outside the target ."
# Is
# ""six months later , the red army invaded the axis forces in slovakia ."
#  ==========================================
#
# The closest vector to
# ""it was printed in november 1998 to celebrate the 5th anniversary of magic ."
# Is
# ""however in the closing credits , guinness is billed second with hawkins third ."
#  ==========================================
#
# The closest vector to
# ""the tigers won the second game 2-1 to move onto the championship game ."
# Is
# ""the first women 's european championship was held in denmark in july 1989 ."
#  ==========================================
#
# The closest vector to
# ""i think many muslim communities , for example singapore muslims , would not ."
# Is
# ""repetition occurs many times in this poem , for example `` o captain !"
#  ==========================================
#
# The closest vector to
# ""list of world war ii aces from south africa ( talk ) reassessed ."
# Is
# ""list of schedule ii drugs ( talk ) unassessed-class ( no-class ) removed ."
#  ==========================================
#
# The closest vector to
# ""andrews , george `` porky '' was inducted as an athlete in 1967 ."
# Is
# ""disco tango '' was the danish entry in the eurovision song contest 1979 ."
#  ==========================================
#
# The closest vector to
# ""this view is of the paperback edition ( 2009 ) from it books ."
# Is
# ""tracks 5 , 7 and 10 are from the album beneath the remains ."
#  ==========================================
#
# The closest vector to
# ""it is said the newspaper survived only because lincoln was a smart politician ."
# Is
# ""joe is a technician aboard the toronto and a good friend of tom ."
#  ==========================================
#
# The closest vector to
# ""it is said the newspaper survived only because lincoln was a smart politician ."
# Is
# ""it also describes the kind of humor a man like abraham lincoln had ."
#  ==========================================
#
# The closest vector to
# ""seven sisters ( queensland ) ( talk ) unassessed-class ( no-class ) added ."
# Is
# ""seven sisters ( queensland ) ( talk ) unassessed-class ( no-class ) added ."
#  ==========================================
#
# The closest vector to
# ""by the mid-1980s she was regarded as a veteran of the adult industry ."
# Is
# ""by the mid-1980s she was regarded as a veteran of the adult industry ."
#  ==========================================
#
# The closest vector to
# ""in february , 1998 , syndicated sports talk replaced oldies during those hours . "
# Is
# ""take a show that was first broadcast in 1979 and ran till 1988 . "
#  ==========================================
#
# The closest vector to
# ""according to the 1998 census it has a population of 10 , 301 ."
# Is
# ""the pediatric intensive care unit has 12 beds , including 4 isolation rooms ."
#  ==========================================
#
# The closest vector to
# ""he then added , `` these damn indians have gone absolutely wild [ ."
# Is
# ""he then added , `` these damn indians have gone absolutely wild [ ."
#  ==========================================
#
# The closest vector to
# ""in 1996 he was made an honorary student of christ church , oxford ."
# Is
# ""in the mid-1990s he opened a post card stand in cairns , queensland ."
#  ==========================================
#
# The closest vector to
# ""six months later , the red army invaded the axis forces in slovakia . "
# Is
# ""the war began with the landing of nine hundred military advisors in saigon . "
#  ==========================================
#
# The closest vector to
# ""thousands of people protest against the ruling hamas party in the gaza strip ."
# Is
# ""thousands of people protest against the ruling hamas party in the gaza strip ."
#  ==========================================
#
# The closest vector to
# ""bathurst airport is an airport serving bathurst , new south wales , australia ."
# Is
# ""he is interred at the west street cemetery in milford , new hampshire ."
#  ==========================================
#
# The closest vector to
# ""programs had to be written in a specific way to access expanded memory ."
# Is
# ""we have consensus from the deletion nominator to redirect to the correct spelling ."
#  ==========================================
#
# The closest vector to
# ""there is little or no percussion and rhythm is not a prominent element ."
# Is
# ""there is little or no percussion and rhythm is not a prominent element ."
#  ==========================================
#
# The closest vector to
# ""the film won several national awards as well as state and other awards ."
# Is
# ""the challenge is a free campaign supported by national civic and health organizations ."
#  ==========================================
#
# The closest vector to
# ""in 1943 , she obtained a medical degree from the university of chicago ."
# Is
# ""the hearings were televised live at the state of illinois center in chicago ."
#  ==========================================
#
# The closest vector to
# ""hence the material in the discussions section and the appeal for more information ."
# Is
# ""i added a bit to the introduction as well as the history section ."
#  ==========================================
#
# The closest vector to
# ""i may not know any ww2 author , but i can always search ."
# Is
# ""i may be too involved in the text and thus be missing something ."
#  ==========================================
# The closest vector to
# ""hello , i 'm looking for information on a ship named hms joanna ."
# Is
# ""another town named dudley originally existed several miles north from its current location ."
#  ==========================================
#
# The closest vector to
# ""many have tried to break this record , but few have come close ."
# Is
# ""a few of the sources merely mention the subject in a trivial context ."
#  ==========================================
#
# The closest vector to
# "" alberta legislative building - the legislature of alberta consists of two component 1 ."
# Is
# ""alberta legislative building - the legislature of alberta consists of two component 1 ."
#  ==========================================
#
# The closest vector to
# ""his career at the bar ended with the outbreak of world war ii ."
# Is
# ""settled in france , and fought for the french in world war ii ."
#  ==========================================
#
# The closest vector to
# ""but once again , it proves that honesty always gets you in trouble . "
# Is
# ""the notion that you lock people up for smoking marijuana is pretty silly . "
#  ==========================================
#
# The closest vector to
# ""by 1835 this group was well established in the diocese , but fr ."
# Is
# ""the statue was broken in two while being transported to their georgia parish ."
#  ==========================================
#
# The closest vector to
# ""there used to be a post office which was previously a police barracks ."
# Is
# ""seven are chosen annually , two from the previous year continued in office ."
#  ==========================================

# %% [markdown]
# ### Now, first apply the trained Siamese network to each vector, and recalculate closest vectors.

# %%
for v in vecs:
    transform(network, v)

subset = np.random.choice(vecs, size = subset_size)
print_closest_vectors(subset, vecs)
# Out:
# The closest vector to
# ""at the moment , the bus lanes are being built throughout the city ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""press ok to continue , or cancel to stay on the current page ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""he has also depicted various christian themes including the christian cross and churches ."
# Is
# ""i 've missed several meetings , maybe i will try to show up ."
#  ==========================================
#
# The closest vector to
# ""i added a bit to the introduction as well as the history section ."
# Is
# ""ticket number i edited the template so that the ticket number is displayed ."
#  ==========================================
#
# The closest vector to
# ""his second song of the evening was `` does your mother know '' ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""logo is a language that was specifically designed to introduce children to programming ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""the stuff i have found has been dominated by ( 1 ) www ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""the report examined nearly 300 individuals and hundreds of classified armed forces signals ."
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# ""in 1976 he turned professional and won a national title in the sprint ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""he ended the season appearing in 79 games with the club , batting ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""it was evident , however , that the system needed to be enlarged ."
# Is
# "" he had no where to go with virtually no money in his pocket ."
#  ==========================================
#
# The closest vector to
# "" all 67 seats in the minnesota senate were up for election in 2012 ."
# Is
# ""in july of the same year , he was elevated to chief justice ."
#  ==========================================
#
# The closest vector to
# ""they 've been reviewed by charity navigator [ 1 ] and by give ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# "" do not use them unless your gun is meant to take the pressure ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""by 1835 this group was well established in the diocese , but fr ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""he then returns to the burial ground and sets fire to the coffin ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""i suspect that implied in the question ) focus on work in mainspace ."
# Is
# ""your next edit indicated that you meant the notability tag for a section ."
#  ==========================================
#
# The closest vector to
# ""it is run and edited by students at uc berkeley school of law ."
# Is
# ""players may enter a `` focus '' mode , which provides several advantages ."
#  ==========================================
#
# The closest vector to
# ""please judge this article on its encyclopedic merits and not its subject matter ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""i do not think this treatment of davis reflects well on this project ."
# Is
# ""i had written that before i saw the newspaper report on that death ."
#  ==========================================
#
# The closest vector to
# ""you go the other way to turn those characters into the original data ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# "" by 1972 , it was still only grades 10 , 11 and 12 ."
# Is
# ""separation proved unfortunate to his marriage , which ended in divorce in 1962 ."
#  ==========================================
#
# The closest vector to
# "" each year , it 's produced a limited number of limited edition pieces ."
# Is
# ""this view is of the paperback edition ( 2009 ) from it books ."
#  ==========================================
#
# The closest vector to
# ""clark house ( newton , massachusetts ) , also known as the rev ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# "" the top of the cape may lighthouse , from july 4 , 2005 ."
# Is
# "" the economic status of information security came to the intellectual fore around 2000 ."
#  ==========================================
#
# The closest vector to
# ""after a series of splits , however , the church disbanded in 1952 ."
# Is
# ""the only source given has a 2 sentence passing mention of the topic ."
#  ==========================================
#
# The closest vector to
# ""different schools of painting are shown from the sixteenth to the twentieth centuries ."
# Is
# ""the second ran only 300 copies pressed on the same solid orange vinyl ."
#  ==========================================
#
# The closest vector to
# ""complete participation researcher is completely integrated in population of study beforehand ( i ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""henry cotton wins his third british open , at the age of 41 ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""in 1959 , he was appointed ambassador to the soviet union and poland ."
# Is
# ""also two levels of shops and restaurants in the square were a success ."
#  ==========================================
#
# The closest vector to
# ""in the north wall of the chancel is a single narrow pointed window ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""but once again , it proves that honesty always gets you in trouble ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""a small brick waiting shelter was provided for passengers using the up platform ."
# Is
# ""your next edit indicated that you meant the notability tag for a section ."
#  ==========================================
#
# The closest vector to
# ""they might make wikipedia grow faster than the software and hardware can support ."
# Is
# ""in recent years the mcc was generating enough money to support the school ."
#  ==========================================
#
# The closest vector to
# ""the birds of the gambia ( 2nd edition , 1991 ) by m ."
# Is
# ""the only source given has a 2 sentence passing mention of the topic ."
#  ==========================================
# The closest vector to
# ""the german national archives hold no records for the presentation of the swords ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# "" the final decision was taken on the uefa meeting on 13 may 2009 ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""he has no definitive personal , cultural or sexual identity throughout the book ."
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# ""likely to any significant extent to stimulate or encourage the commission of offences ."
# Is
# ""frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# ""marriage information per parish records in devon and verified with researcher in uk ."
# Is
# ""she thinks i 'm crazy but i 'm just growing old '' ) ."
#  ==========================================
#
# The closest vector to
# ""founder of petty enterprises , level cross , north carolina , near greensboro ."
# Is
# ""in july of the same year , he was elevated to chief justice ."
#  ==========================================
#
# The closest vector to
# ""the following stadiums are considered home grounds for the teams in the competition ."
# Is
# ""in july of the same year , he was elevated to chief justice ."
#  ==========================================
#
# The closest vector to
# ""the house changed hands many times over the years before finally being demolished ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""although the magazine ceased publication , another project is still being kept alive ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""this is a result of the origins of the internet as a u ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# "" da silva then moved to italy in 1991 where he played for u ."
# Is
# "" he had no where to go with virtually no money in his pocket ."
#  ==========================================
#
# The closest vector to
# ""the economic status of information security came to the intellectual fore around 2000 ."
# Is
# ""frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# ""the only source given has a 2 sentence passing mention of the topic ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""when the child is ill , the mother will know how to pray ."
# Is
# ""rr law , he could be in some cases , but not all ."
#  ==========================================
#
# The closest vector to
# ""not the sort of thing the reference desk is set up to answer ."
# Is
# ""rr law , he could be in some cases , but not all ."
#  ==========================================
#
# The closest vector to
# ""michael was amongst a group of leaders of the communist underground in iraq . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""after a series of splits , however , the church disbanded in 1952 ."
# Is
# ""the only source given has a 2 sentence passing mention of the topic ."
#  ==========================================
#
# The closest vector to
# ""the waters of the pacific ocean then carried the body out to sea ."
# Is
# ""w ) in 1990 , the population was recorded at 6 , 190 ."
#  ==========================================
#
# The closest vector to
# ""season 6 gets three different houses where the housemates have to live in ."
# Is
# ""the color balance adjustment and wider view are improvements , in my view ."
#  ==========================================
#
# The closest vector to
# ""he studied economics at temple university , and taught journalism at temple university ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""in september 1938 , the navy placed an order for 30 production aircraft ."
# Is
# ""w ) in 1990 , the population was recorded at 6 , 190 ."
#  ==========================================
#
# The closest vector to
# ""copyright violation from this page and probably several others on the same site ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""in 1941 , the museum building and artifacts were badly damaged by bombing ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# "" founded in 1872 , it is the oldest college humor magazine in america ."
# Is
# "" the acquisitions in green bay and new orleans were part of this strategy ."
#  ==========================================
#
# The closest vector to
# ""each party is represented by an attorney while witnesses and evidence are presented ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""td sends the chargers to the divisional playoffs for the third consecutive season ."
# Is
# ""in november 2007 , sears holdings corporation announced the purchase of a 13 ."
#  ==========================================
#
# The closest vector to
# ""threats against wikipedia only count if they are legal or made on wikipedia ."
# Is
# ""the second ran only 300 copies pressed on the same solid orange vinyl ."
#  ==========================================
#
# The closest vector to
# ""zhao also established a new world record for most points scored ( 76 . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# "" can we forget about the other articles , and discuss this one only ."
# Is
# ""in recent years the mcc was generating enough money to support the school ."
#  ==========================================
#
# The closest vector to
# ""bureaucrats that are active regularly are the bureaucrats that were promoted more recently ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""rock and roll people '' which is from the mind games sessions ) ."
# Is
# ""marriage information per parish records in devon and verified with researcher in uk ."
#  ==========================================
#
# The closest vector to
# ""the was a japanese revolutionary armed group , established on 15 july 1971 ."
# Is
# ""she thinks i 'm crazy but i 'm just growing old '' ) ."
#  ==========================================
#
# The closest vector to
# ""when they did so , however , they were hampered by limited skills . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""o o o o o o aa ha ha aa aa aa aa ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""in this context , joe 's reply is both meaningful and arguably accurate . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
# The closest vector to
# ""bill clinton was born in the city and state of hope , arkansas ."
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# ""she was sold in 1831 to commercial interests and returned to cape town ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""randall died on february 13 , 2013 after suffering complications from a stroke ."
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# ""in november 2007 , sears holdings corporation announced the purchase of a 13 ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""this particular article though , is not of featured quality as of yet ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""he was the eldest son of richard , third son of the hon ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""mammal articles needing attention for more details on when this should be used ."
# Is
# ""i had written that before i saw the newspaper report on that death ."
#  ==========================================
#
# The closest vector to
# "" please judge this article on its encyclopedic merits and not its subject matter ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""they actively encouraged his painting activities and later supported him in higher education ."
# Is
# ""welding allows a large sculpture to be cast in pieces , then joined ."
#  ==========================================
#
# The closest vector to
# ""they immediately gave him the full ten points because they needed more musicians ."
# Is
# ""it was evident , however , that the system needed to be enlarged ."
#  ==========================================
#
# The closest vector to
# ""efforts to rebuild the niagara were hampered by the lack of original plans ."
# Is
# ""in recent years the mcc was generating enough money to support the school ."
#  ==========================================
#
# The closest vector to
# ""language study had always been one of the core problems for the mission ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""he made his debut in the chinese professional baseball league at age 23 ."
# Is
# ""welding allows a large sculpture to be cast in pieces , then joined ."
#  ==========================================
#
# The closest vector to
# ""he has since continued playing live with muse on their 2nd law tour ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""he left one daughter , married to john taylor , chancellor of salisbury ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""adds nothing to the reader 's understanding of society 's perspective on napoleon ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""taliban of afghanistan and hussein of iraq were openly hostile towards the u ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""the 3rd attack wing and group operated out of fort crockett , texas ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""there exists also a provincial electoral district of a similar name ( st ."
# Is
# ""in recent years the mcc was generating enough money to support the school ."
#  ==========================================
#
# The closest vector to
# ""clark house ( newton , massachusetts ) , also known as the rev ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""the lord is a cat , owned by the ruler of the universe ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""in september 1938 , the navy placed an order for 30 production aircraft ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""there are many stories and myths surrounding the building and the harrison family . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# "" i just got a reply from school officials saying thanks , no details ."
# Is
# ""ticket number i edited the template so that the ticket number is displayed ."
#  ==========================================
#
# The closest vector to
# ""mla style if possible , or at the very least adding reference section ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""british malaya and siam due to the culture and arts inside the temple ."
# Is
# ""i am a new admin and i am seeking help from other admins ."
#  ==========================================
#
# The closest vector to
# "" there used to be a post office which was previously a police barracks ."
# Is
# ""ticket number i edited the template so that the ticket number is displayed ."
#  ==========================================
#
# The closest vector to
# ""target identification is typically the starting point of the modern drug discovery process ."
# Is
# ""frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# ""for the same reasons that have been stated before in this perennial proposal ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""she has acted in hindi movies and guest appearances in numerous television shows ."
# Is
# ""the parents also act like zombies maybe ignoring the reality of the situation ."
#  ==========================================
#
# The closest vector to
# ""she joined the royal ballet in 1954 and became a soloist in 1958 . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""i would not be closing them unless they were unanimous or nearly so ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""the baltimore colts ran a version of the play in december , 1970 ."
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# ""w ) in 1990 , the population was recorded at 6 , 190 ."
# Is
# ""welding allows a large sculpture to be cast in pieces , then joined ."
#  ==========================================
#
# The closest vector to
# ""former president salad appointed seven people to his cabinet on 4 august 2007 ."
# Is
# ""jun 2005 ( utc ) close , you 're missing two four things ."
#  ==========================================
#
# The closest vector to
# ""you do n't have to be a genius to know what they do ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
# The closest vector to
# ""chain falls tend to use internal gear sets to provide the mechanical advantage ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""their performance at the festival garnered a lot of attention for the band . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""i may not know any ww2 author , but i can always search ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""she thinks i 'm crazy but i 'm just growing old '' ) ."
# Is
# ""i 've missed several meetings , maybe i will try to show up ."
#  ==========================================
#
# The closest vector to
# ""all the resources in the world could not create a free use equivalent ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""to continue in the face of such criticism tends to imply bad faith ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""serie a season , in which it only just managed to avoid relegation ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""the sound of drums '' and `` last of the time lords '' ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""jefferson college ) in 1856 and received a master 's degree in 1859 ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""the subject of the article is covered in appropriate detail elsewhere on wikipedia ."
# Is
# "" he had no where to go with virtually no money in his pocket ."
#  ==========================================
#
# The closest vector to
# ""strong support experienced member , often reverts vandalism and beats me to it ."
# Is
# ""the national library of norway n y sites are integrated in the catalog ."
#  ==========================================
#
# The closest vector to
# "" a poet , athlete , stud , and a liar by charles pratt ."
# Is
# ""i am ready to make an introduction at the category page to explain ."
#  ==========================================
#
# The closest vector to
# ""the series was put on hiatus in 2006 and officially canceled in 2008 ."
# Is
# "" he had no where to go with virtually no money in his pocket ."
#  ==========================================
#
# The closest vector to
# ""payne was born in black rock , barbados , on 21 december 1948 ."
# Is
# ""roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# ""this implementation has a few nice extensions and outputs many different image formats ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""it received the hydraulic brake boost system from the rs and turbo 3 ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""the blocks were also supposedly used for selling slaves during the slave period ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""opinions , when informed , and criticism , when constructive , are valuable ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""walton moved to montreal , quebec , after her first novel was published ."
# Is
# ""w ) in 1990 , the population was recorded at 6 , 190 ."
#  ==========================================
#
# The closest vector to
# ""in 1975 , he was named parliamentary secretary to the minister for defence ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""initially , the simplicity bearing was only offered in closed , imperial sizes ."
# Is
# "" the master of science in administration was added in the winter of 1983 ."
#  ==========================================
#
# The closest vector to
# ""has been doing an excellent job patrolling new pages for speedy deletion criteria . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""at the 2006 census , its population was 157 , in 37 families ."
# Is
# ""at the end of the 2007 season , leicestershire offered pope a contract ."
#  ==========================================
#
# The closest vector to
# ""at the end of the 2007 season , leicestershire offered pope a contract ."
# Is
# ""w ) in 1990 , the population was recorded at 6 , 190 ."
#  ==========================================
#
# The closest vector to
# ""trinity united methodist church is a popular wedding venue in the lafayette area ."
# Is
# ""frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# ""the secretary for scotland became the secretary of state for scotland in 1926 ."
# Is
# ""in recent years the mcc was generating enough money to support the school ."
#  ==========================================
#
# The closest vector to
# ""lowell grew quickly to a city of 33 , 000 people by 1850 ."
# Is
# ""measurements made include a wide range of physical , chemical and biological variables ."
#  ==========================================
#
# The closest vector to
# "" miller , jr and jeffrey paul , oxford , basil blackwell , pp ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
#
# The closest vector to
# ""in february , 1998 , syndicated sports talk replaced oldies during those hours ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""a special collector 's edition was released in march 2009 on rhino records . "
# Is
# ""welding allows a large sculpture to be cast in pieces , then joined ."
#  ==========================================
#
# The closest vector to
# ""yes , so long as the whole thing is in air tight containers . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""rock and roll people '' which is from the mind games sessions ) ."
# Is
# ""this view is of the paperback edition ( 2009 ) from it books ."
#  ==========================================
#
# The closest vector to
# ""the 3rd attack wing and group operated out of fort crockett , texas ."
# Is
# "" the economic status of information security came to the intellectual fore around 2000 ."
#  ==========================================
#
# The closest vector to
# ""at the 2006 census , its population was 157 , in 37 families ."
# Is
# ""frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# ""it was later re-released on the virtual console and on the playstation network ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""the old jail facility will be turned over to the national historical commission ."
# Is
# ""w ) in 1990 , the population was recorded at 6 , 190 ."
#  ==========================================
# The closest vector to
# ""he got the name from seeing multiple road signs during a road trip ."
# Is
# ""rr law , he could be in some cases , but not all ."
#  ==========================================
#
# The closest vector to
# ""efforts to rebuild the niagara were hampered by the lack of original plans . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""prominent proponents of liberal arts in the united states have included mortimer j ."
# Is
# ""frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# ""other complete sentences consist of two or more clauses ( see below ) . "
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""enormous quantities of water were also required for the operation of the locomotive ."
# Is
# ""a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# ""opinions , when informed , and criticism , when constructive , are valuable ."
# Is
# ""that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# ""his version of the song peaked at number 44 on hot country songs ."
# Is
# ""i would like to make edits under my real name from now on ."
#  ==========================================
#
# The closest vector to
# ""trinity united methodist church is a popular wedding venue in the lafayette area ."
# Is
# ""i was the one added it within the article as a proper reference ."
#  ==========================================
