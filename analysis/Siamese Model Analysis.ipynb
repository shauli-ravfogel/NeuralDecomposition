# %%
import sys
sys.path.append('../generate_dataset')
sys.path.append('../Siamese')

from pytorch_fast_elmo import FastElmo, batch_to_char_ids
import sys
from scipy.cluster.hierarchy import dendrogram, linkage
import scipy
import matplotlib.pyplot as plt
import random
import model
import torch
from typing import List
import numpy as np
import utils

from typing import NewType

# %%
class Vector(object):
    
    def __init__(self, vec, sentence, index):
        
        self.vec = vec
        self.sentence = sentence
        self.index = index
        self.size = np.linalg.norm(self.vec)
    
    def get_word(self):
        
        return self.sentence[self.index]
    
    def get_vector(self): 
        
        return self.vec
    
    def get_sentence(self):
        
        return self.sentence
    
    def get_index(self):
        
        return self.index
    
    def get_size(self):
        
        return self.size
    
    def __str__(self):
        
        words = self.get_sentence()
        i = self.get_index()
        sent = '"' + " ".join(words[:i]) + color.BOLD + color.BLUE + " " + words[i] + color.END + " " + " ".join(words[i + 1:]) + '"'
        return sent
    
    def similarity(self, other):
        
        if other is self: return -np.inf
        
        return self.get_vector().dot(other.get_vector())/(self.get_size() * other.get_size())
    
    @staticmethod
    def get_closest_vector(vec, vecs):
    
        closest = max(vecs, key = lambda vector: vector.similarity(vec))
        return closest

# %%
def transform(model, vector: Vector):
    
    vec_pytorch = torch.from_numpy(vector.get_vector()).float()
    vector.vec = model._represent(vec_pytorch).detach().numpy()
    
    
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
def print_closest_vectors(sample, all_vecs):
    
    for vector in sample:
        closest = Vector.get_closest_vector(vector, all_vecs)
        print("The closest vector to\n{}\nIs\n{} \n ==========================================\n".format(vector, closest))
    
def load_sents(fname = "sents_f", max_length = 15):
    
    with open(fname, "r") as f:
              
        lines = f.readlines()
    
    lines =  [line.strip().split(" ") for line in lines]
    if max_length is not None:
        lines = list(filter(lambda sentence: len(sentence) < max_length, lines))
    return lines

def load_model(name = "model.pt"):
    net = model.SiameseNet()
    net.load_state_dict(torch.load(name))
    net.eval()
    return net

def list_vectors(vecs, sents: List[List[str]]) -> List[Vector]:
    
    num_sentences = len(sents)
    sents_indices_and_vecs =  zip(range(num_sentences), vecs)
    all_vectors = []

    for sent_index, sent_vectors in sents_indices_and_vecs:
        
        for i, (w,vec) in enumerate(zip(sents[sent_index], vecs[sent_index])):   
            
            v = Vector(vec.detach().numpy(), sents[sent_index], i)
            all_vectors.append(v)
            
    return all_vectors

# %% [markdown]
# Load pretrained ELMO and a collection of Wikipedia sentences.

# %%
all_sentences = load_sents(max_length = 15)
options_file = "../generate_dataset/" + utils.DEFAULT_PARAMS["elmo_options"]
weight_file = "../generate_dataset/" + utils.DEFAULT_PARAMS["elmo_weights"]
elmo = FastElmo(options_file, weight_file)

# %%
N = 1000
subset_size = 150
random.seed(0)
sentences = all_sentences[:N]

# %% [markdown]
# Collect ELMO states over N sentences, and load pretrained Siamese network.

# %%
character_ids = batch_to_char_ids(sentences)
embeddings = elmo(character_ids) # collect elmo states
network = load_model()

# %% [markdown]
# Find the closest vectors to a collection of vectors.

# %%
vecs = list_vectors(embeddings["elmo_representations"][0], sentences)
subset = np.random.choice(vecs, size = subset_size)
print_closest_vectors(subset, vecs)
# Out:
# The closest vector to
# "pierce died of complications from an abdominal infection in los angeles , california ."
# Is
# "he died of cancer at a veterans administration hospital in houston , texas ."
#  ==========================================
#
# The closest vector to
# "my main reason for asking the question and inviting debate was to learn ."
# Is
# "if another administrator blocked the user , i would ask for their view ."
#  ==========================================
#
# The closest vector to
# "he was elected lieutenant governor in 1982 as running mate of richard f ."
# Is
# "joe is a technician aboard the toronto and a good friend of tom ."
#  ==========================================
#
# The closest vector to
# "the other six temples are located in villages , largely in remote locations ."
# Is
# " other complete sentences consist of two or more clauses ( see below ) ."
#  ==========================================
#
# The closest vector to
# "looks like it was split from censorship with just brazil and venezuela ( ! "
# Is
# "i trust we have an admin here who knows what to do next ! "
#  ==========================================
#
# The closest vector to
# "in 2001 , peter handed the site over to chris williams as editor ."
# Is
# "in 2001 , peter handed the site over to chris williams as editor ."
#  ==========================================
#
# The closest vector to
# "relies primarily on primary sources and imdb - neither of which are sufficient . "
# Is
# "allows for a systematic evaluation of all potential projects at the same time . "
#  ==========================================
#
# The closest vector to
# "it was printed in november 1998 to celebrate the 5th anniversary of magic ."
# Is
# "during ceremonies they are in charge of animation , speaking , and singing ."
#  ==========================================
#
# The closest vector to
# "large net benefit to the project , and will make a fine admin ."
# Is
# "the color balance adjustment and wider view are improvements , in my view ."
#  ==========================================
#
# The closest vector to
# "its average depth is and its maximum depth is , near the dam ."
# Is
# "its average depth is and its maximum depth is , near the dam ."
#  ==========================================
#
# The closest vector to
# " he was voted the best defender in the 2010 thai division 1 league ."
# Is
# " he ended the season appearing in 79 games with the club , batting ."
#  ==========================================
#
# The closest vector to
# "but such situations are necessarily rare , since the policy says they are ."
# Is
# "these designated levels are not standard but vary according to each organizations preference ."
#  ==========================================
#
# The closest vector to
# "all states were required to be fully participating by january 1 , 2010 ."
# Is
# "prominent proponents of liberal arts in the united states have included mortimer j ."
#  ==========================================
#
# The closest vector to
# " the latter break is usually preferable , but harder for black to achieve ."
# Is
# " the first example remains awkward in the article , despite your recent changes ."
#  ==========================================
#
# The closest vector to
# "benson produced miss understood , and has been one of her songwriting collaborators ."
# Is
# "eagle rock records is one of the record labels of eagle rock entertainment ."
#  ==========================================
#
# The closest vector to
# "her spirit returns to her old apartment where she later finds true love ."
# Is
# "i did some research online and found this to be a common problem ."
#  ==========================================
#
# The closest vector to
# "comic sans which had the most negative influence on agreement of the six ."
# Is
# "for the same reasons that have been stated before in this perennial proposal ."
#  ==========================================
#
# The closest vector to
# "while wins over middlesbrough , blackburn rovers and bolton perhaps the most important ."
# Is
# "sul for this name , they have the greatest priority for this name ."
#  ==========================================
#
# The closest vector to
# "in such a case it is quite uncommon to issue a 3rr block ."
# Is
# "then we can have a general discussion on whether to extend the experiment ."
#  ==========================================
#
# The closest vector to
# "an anon already went and added two more ( which i reverted ) ."
# Is
# "delete no source for the concept around which this page has been created ."
#  ==========================================
#
# The closest vector to
# "in the 1920s it housed various writers ' organizations and a literary museum ."
# Is
# "he has also depicted various christian themes including the christian cross and churches ."
#  ==========================================
#
# The closest vector to
# "he was terrified of death and had never been sick in his life ."
# Is
# "she was attracted to and later had relationships with both men and women ."
#  ==========================================
#
# The closest vector to
# "however , when returned to his natural age , these abilities were lost ."
# Is
# "titans of the ice age exhibition '' at the field museum in chicago ."
#  ==========================================
#
# The closest vector to
# "bathurst airport is an airport serving bathurst , new south wales , australia ."
# Is
# "bathurst airport is an airport serving bathurst , new south wales , australia ."
#  ==========================================
#
# The closest vector to
# "there used to be a post office which was previously a police barracks ."
# Is
# "there used to be a post office which was previously a police barracks ."
#  ==========================================
#
# The closest vector to
# "move - archive somewhere ( without a redirect ) ; do not delete ."
# Is
# "i made one quickly for you ( using an orphaned template page ) ."
#  ==========================================
#
# The closest vector to
# "some free blacks in the north also founded small businesses and even newspapers ."
# Is
# "prominent proponents of liberal arts in the united states have included mortimer j ."
#  ==========================================
#
# The closest vector to
# "in this context , joe 's reply is both meaningful and arguably accurate ."
# Is
# " joe is a technician aboard the toronto and a good friend of tom ."
#  ==========================================
#
# The closest vector to
# "but such situations are necessarily rare , since the policy says they are ."
# Is
# "so , since redirects are cheap , we can go with this alternative ."
#  ==========================================
#
# The closest vector to
# "in it their performance is evaluated by the abbot of the particular college ."
# Is
# "they 've been reviewed by charity navigator [ 1 ] and by give ."
#  ==========================================
#
# The closest vector to
# "delete no source for the concept around which this page has been created ."
# Is
# "a handful of dictionaries has been used as the source for the list ."
#  ==========================================
#
# The closest vector to
# "he leaves a trail for the police to follow and he is convicted ."
# Is
# "he leaves a trail for the police to follow and he is convicted ."
#  ==========================================
#
# The closest vector to
# "he then spent a season at crewe alexandra where was again a regular ."
# Is
# "serie a season , in which it only just managed to avoid relegation ."
#  ==========================================
#
# The closest vector to
# "comment i think that it has a lot of potential as a list ."
# Is
# "i do not know whether this has anything to do with my question ."
#  ==========================================
#
# The closest vector to
# "it has started from the moment of the explosion , thus not eternal . "
# Is
# "it results in a system that is far less than it should be . "
#  ==========================================
# The closest vector to
# "unreferenced and unverifiable music album that even does n't contain its artist name !"
# Is
# "sul for this name , they have the greatest priority for this name ."
#  ==========================================
#
# The closest vector to
# "strong support experienced member , often reverts vandalism and beats me to it ."
# Is
# "they had come from places where they had already experienced and known humiliation ."
#  ==========================================
#
# The closest vector to
# "in november 2007 , sears holdings corporation announced the purchase of a 13 ."
# Is
# "the play was adapted for tv by the australian broadcasting corporation in 1973 ."
#  ==========================================
#
# The closest vector to
# "the library also has video games , computer games , and internet facilities ."
# Is
# "it was founded over 100 years ago and has more than 700 employees ."
#  ==========================================
#
# The closest vector to
# "the human condition refers to the experience of existence and life as humans ."
# Is
# "he was terrified of death and had never been sick in his life ."
#  ==========================================
#
# The closest vector to
# "a special collector 's edition was released in march 2009 on rhino records ."
# Is
# "green cow ( energy drink which is an obvious parody of red bull ."
#  ==========================================
#
# The closest vector to
# "deadline for house and senate to reconcile the two versions of the bill ."
# Is
# "deadline for house and senate to reconcile the two versions of the bill ."
#  ==========================================
#
# The closest vector to
# "serie a season , in which it only just managed to avoid relegation ."
# Is
# "the latter break is usually preferable , but harder for black to achieve ."
#  ==========================================
#
# The closest vector to
# "the articles seem to advocate the ideas they cover and to overlap significantly ."
# Is
# "image of a book cover , found at random house publishers web site ."
#  ==========================================
#
# The closest vector to
# "again , this is a matter of personal preference and not a must ."
# Is
# "this is a result of the origins of the internet as a u ."
#  ==========================================
#
# The closest vector to
# "the pediatric intensive care unit has 12 beds , including 4 isolation rooms ."
# Is
# "the pediatric intensive care unit has 12 beds , including 4 isolation rooms ."
#  ==========================================
#
# The closest vector to
# "garcia blasts morales with a left hook that launches morales through the ropes ."
# Is
# "garcia blasts morales with a left hook that launches morales through the ropes ."
#  ==========================================
#
# The closest vector to
# "bn does not give you anything other than numbers and the close date ."
# Is
# "it does not even seem to be a topic of speculation for historians ."
#  ==========================================
#
# The closest vector to
# "the remaining teams either folded or chose to play in lower local leagues ."
# Is
# "august 8 i am confused on how to play 1000 blank white cards ."
#  ==========================================
#
# The closest vector to
# "la tech hosts the annual squire creek invitational and the argent financial classic ."
# Is
# "de 30 south of the city of milford in the cedar creek area ."
#  ==========================================
#
# The closest vector to
# "please judge this article on its encyclopedic merits and not its subject matter ."
# Is
# "in addition , many critics wrote positively of the characters and their actions ."
#  ==========================================
#
# The closest vector to
# "all 67 seats in the minnesota senate were up for election in 2012 ."
# Is
# "this renovation project started in 2010 and is going to end in 2013 ."
#  ==========================================
#
# The closest vector to
# "what the high schools in a particular area do is not in doubt ."
# Is
# "in one particular case , he attacked three policemen and confiscated their pistols ."
#  ==========================================
#
# The closest vector to
# "although he was raised in a religious family , norman was an atheist ."
# Is
# "there are many stories and myths surrounding the building and the harrison family ."
#  ==========================================
#
# The closest vector to
# "the park is filled with small caves , especially on the mountain proper ."
# Is
# "the park contains memorials to the ipswich martyrs which was installed in 1903 ."
#  ==========================================
#
# The closest vector to
# "the article should be retained and improved in accordance with our editing policy ."
# Is
# "fringe , would have to be proved , and covered to be notable ."
#  ==========================================
#
# The closest vector to
# "you do n't have to be a genius to know what they do ."
# Is
# "every human being is a spiritual being as well as a physical being ."
#  ==========================================
#
# The closest vector to
# "on february 28 2013 , the lions signed smith to a contract extension ."
# Is
# "in 2012 , he was made a knight of the order of st ."
#  ==========================================
#
# The closest vector to
# "the following stadiums are considered home grounds for the teams in the competition ."
# Is
# "the following stadiums are considered home grounds for the teams in the competition ."
#  ==========================================
#
# The closest vector to
# "they actively encouraged his painting activities and later supported him in higher education ."
# Is
# "his wife died december 22 , 1871 and was buried next to him ."
#  ==========================================
#
# The closest vector to
# "in 1988 , he published his first book dedicated entirely to film theory ."
# Is
# "in 1975 , he was named parliamentary secretary to the minister for defence ."
#  ==========================================
#
# The closest vector to
# "iraqi soldiers engaged in running battles with insurgents up and down haifa street ."
# Is
# "german night fighters , although five more bombers crash upon returning to england ."
#  ==========================================
#
# The closest vector to
# "he has also depicted various christian themes including the christian cross and churches ."
# Is
# "main features include the welfare and memorial parks and st mary 's church ."
#  ==========================================
#
# The closest vector to
# "in 1943 , she obtained a medical degree from the university of chicago . "
# Is
# "she received a ba in english literature from florida state university in 1958 . "
#  ==========================================
#
# The closest vector to
# "the natives named the rocks , `` the devil 's stepping stones '' ."
# Is
# "the natives named the rocks , `` the devil 's stepping stones '' ."
#  ==========================================
#
# The closest vector to
# "it was elected at the 1946 general election in november of that year ."
# Is
# "western cape vote ) on the proportional representation ballot in the 2011 election ."
#  ==========================================
#
# The closest vector to
# "a third song , `` do n't stop '' , peaked at no ."
# Is
# "the album became michaels highest charting solo album to date peaking at no ."
#  ==========================================
#
# The closest vector to
# " please stop treating us as if the world has a vendetta against you ."
# Is
# " please ask us about specific issues when you have done your own research ."
#  ==========================================
#
# The closest vector to
# "landmarks in this area include windsor mill middle school and rutherford business park ."
# Is
# "also two levels of shops and restaurants in the square were a success ."
#  ==========================================
#
# The closest vector to
# "please stop treating us as if the world has a vendetta against you ."
# Is
# "the parents also act like zombies maybe ignoring the reality of the situation ."
#  ==========================================
# The closest vector to
# "notable enough for our purposes means receiving significant coverage in reliable secondary sources ."
# Is
# "on the main topic of discussion here , our practice is well established ."
#  ==========================================
#
# The closest vector to
# "the tang chinese had recruited many central asian turks into their armed forces ."
# Is
# "i know people that within their family that are not really well off ."
#  ==========================================
#
# The closest vector to
# "iraqi soldiers engaged in running battles with insurgents up and down haifa street ."
# Is
# "iraqi soldiers engaged in running battles with insurgents up and down haifa street ."
#  ==========================================
#
# The closest vector to
# "if it did exist in the mid-1990s , that version is certainly notable ."
# Is
# "his version of the song peaked at number 44 on hot country songs ."
#  ==========================================
#
# The closest vector to
# "it appears to have had a lavish binding decorated with a roman cameo ."
# Is
# "on trials , had a top speed of from at a displacement of ."
#  ==========================================
#
# The closest vector to
# "murray in 1926 based on six cases of sudden death in young rabbits ."
# Is
# "this happened a couple of years before brian 's death in the 1970s ."
#  ==========================================
#
# The closest vector to
# "the film won several national awards as well as state and other awards ."
# Is
# "roberts , kate ( 2001 ) , sun and storm and other stories ."
#  ==========================================
#
# The closest vector to
# "he was the eldest son of richard , third son of the hon ."
# Is
# "he was 3rd chairperson of board of governors of sustainable development policy institute ."
#  ==========================================
#
# The closest vector to
# "irwin received his bachelor 's degree in english at the university of st ."
# Is
# "the university of oregon awarded him their law meritorious service award in 1985 ."
#  ==========================================
#
# The closest vector to
# "quick and dirty checkuser policy proposal ] ] , please have a look ."
# Is
# "a physical examination is performed to look for typical signs of pulmonary hypertension ."
#  ==========================================
#
# The closest vector to
# "strong keep - most primary schools are not notable but this one is ."
# Is
# "i know people that within their family that are not really well off ."
#  ==========================================
#
# The closest vector to
# "o o o o o o aa ha ha aa aa aa aa ."
# Is
# "o o o o o o aa ha ha aa aa aa aa ."
#  ==========================================
#
# The closest vector to
# "hundreds of species of birds migrating from africa and northern asia stop over . "
# Is
# "ants randy is plagued by an increasing stream of ants into his home . "
#  ==========================================
#
# The closest vector to
# " he is also the only cadet who signed up himself for the school ."
# Is
# " he also participated at the 2004 summer olympics for his native asian country ."
#  ==========================================
#
# The closest vector to
# "opened on may 21 , 1978 , the station was originally known as ."
# Is
# "it is located on the burden plantation , a agricultural research experiment station ."
#  ==========================================
#
# The closest vector to
# "such regions are primarily located in the states of central and southern europe ."
# Is
# "the other six temples are located in villages , largely in remote locations ."
#  ==========================================
#
# The closest vector to
# "keep - this , however , is a horse of a different color ."
# Is
# "each of these historians shed light on the topic from a different perspective ."
#  ==========================================
#
# The closest vector to
# "the freezing rain persisted for many hours , leading to extensive ice damage ."
# Is
# "winters are quite cold with plenty of snow , with temperatures ranging between ."
#  ==========================================
#
# The closest vector to
# "it is clear my language is not that of a native french speaker ."
# Is
# "settled in france , and fought for the french in world war ii ."
#  ==========================================
#
# The closest vector to
# "grace attended high school at macon 's windsor academy , graduating in 1977 ."
# Is
# "in 1858 , he took up an appointment in rome academy , pennsylvania ."
#  ==========================================
#
# The closest vector to
# "he also participated at the 2004 summer olympics for his native asian country ."
# Is
# "in 2007 , villa was actively training to make the 2010 winter paralympics ."
#  ==========================================
#
# The closest vector to
# "founder of petty enterprises , level cross , north carolina , near greensboro ."
# Is
# "its average depth is and its maximum depth is , near the dam ."
#  ==========================================
#
# The closest vector to
# "likely to any significant extent to stimulate or encourage the commission of offences . "
# Is
# "fringe , would have to be proved , and covered to be notable . "
#  ==========================================
#
# The closest vector to
# "the articles seem to advocate the ideas they cover and to overlap significantly ."
# Is
# "in addition , many critics wrote positively of the characters and their actions ."
#  ==========================================
#
# The closest vector to
# "jeff wilde was transformed into a cyborg by the secret empire 's scientists ."
# Is
# "the composition of julian 's army at strasbourg can only be partially reconstructed ."
#  ==========================================
#
# The closest vector to
# "the sound of drums '' and `` last of the time lords '' ."
# Is
# "frank stack collection - a special collection of the university of missouri libraries ."
#  ==========================================
#
# The closest vector to
# "this particular article though , is not of featured quality as of yet ."
# Is
# "it was never released to the public and is not available for reading ."
#  ==========================================
#
# The closest vector to
# "putting every household at risk , to be released in september , 2004 ."
# Is
# "the top of the cape may lighthouse , from july 4 , 2005 ."
#  ==========================================
#
# The closest vector to
# "write up a draft in your userspace and bring it here to show ."
# Is
# "sorry if this is n't the correct way to add a comment here ."
#  ==========================================
#
# The closest vector to
# "the two together are hard enough for a man with two arms '' ."
# Is
# "the natives named the rocks , `` the devil 's stepping stones '' ."
#  ==========================================
#
# The closest vector to
# "our ball state course students have been coordinating their topic proposals with me ."
# Is
# "our ball state course students have been coordinating their topic proposals with me ."
#  ==========================================
#
# The closest vector to
# "i only use 20 mb of the 750 mb available on the cd ."
# Is
# "just edit your user page , and put whatever you want on it !"
#  ==========================================
#
# The closest vector to
# "point , i still vote delete , for the previous arguments laid out ."
# Is
# "some of the keep arguments are weak , but some are reasonably strong ."
#  ==========================================
#
# The closest vector to
# "she had recently graduated from university prior to her recruitment to the military ."
# Is
# "this happened a couple of years before brian 's death in the 1970s ."
#  ==========================================
# The closest vector to
# "there is also a plan on having food service in the near future ."
# Is
# "founder of petty enterprises , level cross , north carolina , near greensboro ."
#  ==========================================
#
# The closest vector to
# "it think it also needs to be expanded , based on the sources ."
# Is
# "that very well may happen , but that is for later to decide ."
#  ==========================================
#
# The closest vector to
# "that quote could be used as an example for what wp is not ."
# Is
# "it could just be like friendly , but have the different types available ."
#  ==========================================
#
# The closest vector to
# "income tax ( building societies ) ( audit powers ) regulations 1992 s . "
# Is
# "relevant to sole traders , it also somewhat amended individual voluntary arrangements procedures . "
#  ==========================================
#
# The closest vector to
# "there is no need to explicitly point out the error in the article ."
# Is
# "i think the whole approach is making too much out of the problem ."
#  ==========================================
#
# The closest vector to
# "he served in the united states house of representatives from 1983 to 1993 ."
# Is
# "he served in the vermont senate from 1851 to 1852 was senate president ."
#  ==========================================
#
# The closest vector to
# "driver refuses to pay jackie in full , and jackie demands his payment . "
# Is
# "after hearing that , jerry leaves the relationship on a comedic high note . "
#  ==========================================
#
# The closest vector to
# "japanese culture and japanese language , making the most of a powerful debut ."
# Is
# "japanese culture and japanese language , making the most of a powerful debut ."
#  ==========================================
#
# The closest vector to
# "m off their own goal line and thwarted several other good scoring chances ."
# Is
# "another was to this `` article '' on its author 's own site ."
#  ==========================================
#
# The closest vector to
# "the acquisitions in green bay and new orleans were part of this strategy ."
# Is
# "stuart street is one of the main streets of dunedin , new zealand ."
#  ==========================================
#
# The closest vector to
# "representative town meeting , though no town has adopted this form of government . "
# Is
# "some of the organizations are actually the youth wings of larger political parties . "
#  ==========================================
#
# The closest vector to
# "there was a discussion on it in wikipedia a couple of months ago ."
# Is
# "this happened a couple of years before brian 's death in the 1970s ."
#  ==========================================
#
# The closest vector to
# "that links to a disambiguation page , listing quite a few other articles ."
# Is
# "click on that link , and you will go to the redirect page ."
#  ==========================================
#
# The closest vector to
# "all 67 seats in the minnesota senate were up for election in 2012 ."
# Is
# "all 67 seats in the minnesota senate were up for election in 2012 ."
#  ==========================================
#
# The closest vector to
# "it was founded over 100 years ago and has more than 700 employees . "
# Is
# "it has had only 4 owners in its more than 120 year history . "
#  ==========================================
#
# The closest vector to
# "mla style if possible , or at the very least adding reference section ."
# Is
# "would someone please commit on the above question which relates to reference 8 ."
#  ==========================================
#
# The closest vector to
# "roger lowell putnam was born on december 19 , 1893 , in boston ."
# Is
# "payne was born in black rock , barbados , on 21 december 1948 ."
#  ==========================================
#
# The closest vector to
# "changing the words after the vertical bar will not affect the link itself ."
# Is
# "so the atmospheric pressure increase on top of mt everest will be minuscule ."
#  ==========================================
#
# The closest vector to
# "trains will reach top speeds of 250 kilometres per hour on this line ."
# Is
# "on trials , had a top speed of from at a displacement of ."
#  ==========================================
#
# The closest vector to
# "some of his most prominent roles are his appearances in er as dr ."
# Is
# " prominent proponents of liberal arts in the united states have included mortimer j ."
#  ==========================================
#
# The closest vector to
# "you will have much more control with your linux box doing the routing ."
# Is
# "so , since redirects are cheap , we can go with this alternative ."
#  ==========================================
#
# The closest vector to
# "the first bath rugby matches were also played on the ground in 1884 ."
# Is
# "the current house was built from the remains of the fort in 1793 ."
#  ==========================================
#
# The closest vector to
# "this temple had been added to the list of protected memorials in india ."
# Is
# "all that article is a bullet point list of biography details ( e ."
#  ==========================================
#
# The closest vector to
# "i am open to suggestions for a better sentence meeting the two criteria ."
# Is
# "i am trying to discuss the issue and doing so in good faith ."
#  ==========================================
#
# The closest vector to
# "most of his territory was annexed and became part of the bombay presidency ."
# Is
# "this village is known as birthplace of famous freedom fighter dal bahadur singh ."
#  ==========================================
#
# The closest vector to
# "nc 104 ends at nc 103 without as much as a guide sign ."
# Is
# "comment i think that it has a lot of potential as a list ."
#  ==========================================
#
# The closest vector to
# "species in this family range in body length from about four to 8 ."
# Is
# "the power plant has 1 generating unit with an installed capacity of 3 ."
#  ==========================================
#
# The closest vector to
# "spartans on stage and ticket sales for the show were limited to 300 ."
# Is
# "spartans on stage and ticket sales for the show were limited to 300 ."
#  ==========================================
#
# The closest vector to
# "most reef fishes have body shapes that are different from open water fishes . "
# Is
# "this list is a few of the more common and more invasive species . "
#  ==========================================
#
# The closest vector to
# "i suspect that implied in the question ) focus on work in mainspace ."
# Is
# "there is no need to explicitly point out the error in the article ."
#  ==========================================
#
# The closest vector to
# "it results in a system that is far less than it should be ."
# Is
# "the architecture is well founded on formal scheduling analysis and control theoretical results ."
#  ==========================================
#
# The closest vector to
# "the subject of the article is covered in appropriate detail elsewhere on wikipedia ."
# Is
# "contributions from sockpuppet accounts of indef blocked users are not welcome on wikipedia ."
#  ==========================================
#
# The closest vector to
# "it is rather simple to roll them and polish off the edges video ."
# Is
# "just edit your user page , and put whatever you want on it !"
#  ==========================================
#
# The closest vector to
# "however in the closing credits , guinness is billed second with hawkins third ."
# Is
# "in this context , joe 's reply is both meaningful and arguably accurate ."
#  ==========================================
# The closest vector to
# "this implementation has a few nice extensions and outputs many different image formats ."
# Is
# "on february 28 2013 , the lions signed smith to a contract extension ."
#  ==========================================
#
# The closest vector to
# "the 3rd attack wing and group operated out of fort crockett , texas ."
# Is
# "pierce died of complications from an abdominal infection in los angeles , california ."
#  ==========================================
#
# The closest vector to
# "she studied classical guitar techniques and began composing from the age of 11 ."
# Is
# "he made his debut in the chinese professional baseball league at age 23 ."
#  ==========================================
#
# The closest vector to
# "the latter applies to all 27 current member states of the european union ."
# Is
# "this resolved catalan 's conjecture for all but a finite number of cases ."
#  ==========================================
#
# The closest vector to
# " former president salad appointed seven people to his cabinet on 4 august 2007 ."
# Is
# "former president salad appointed seven people to his cabinet on 4 august 2007 ."
#  ==========================================
#
# The closest vector to
# "stuart street is one of the main streets of dunedin , new zealand ."
# Is
# "once it was one of the most important small kingdoms of south arabia ."
#  ==========================================
#
# The closest vector to
# "alberta legislative building - the legislature of alberta consists of two component 1 ."
# Is
# "other complete sentences consist of two or more clauses ( see below ) ."
#  ==========================================
#
# The closest vector to
# "new zealand 4 points , india , sri lanka 2 , pakistan 0 ."
# Is
# "new zealand 4 points , india , sri lanka 2 , pakistan 0 ."
#  ==========================================
#
# The closest vector to
# "they were arguably the group that brought about the resurgence of garage rock ."
# Is
# "bureaucrats that are active regularly are the bureaucrats that were promoted more recently ."
#  ==========================================
#
# The closest vector to
# "it joins the kabul river a few miles below the city of kabul ."
# Is
# "de 30 south of the city of milford in the cedar creek area ."
#  ==========================================
#
# The closest vector to
# "a third song , `` do n't stop '' , peaked at no ."
# Is
# "his dvd , `` we 'll see '' , was released in 2006 ."
#  ==========================================
#
# The closest vector to
# " he was born in burton , new brunswick , the son of g ."
# Is
# " he was the son of robert the magnificent , the duke of normandy ."
#  ==========================================

# %% [markdown]
# Now, first apply the trained Siamese network to each vector, and recalculate closest vectors.

# %%
for v in vecs:
    transform(network, v)

random.seed(0)
subset = np.random.choice(vecs, size = subset_size)
print_closest_vectors(subset, vecs)
# Out:
# The closest vector to
# "notable enough for our purposes means receiving significant coverage in reliable secondary sources ."
# Is
# "dont delete - you guys have any idea how popular this man is ."
#  ==========================================
#
# The closest vector to
# " in july of the same year , he was elevated to chief justice ."
# Is
# "the baltimore colts ran a version of the play in december , 1970 ."
#  ==========================================
#
# The closest vector to
# "now if only we can get someone to write the australian literature article ."
# Is
# "i am ready to make an introduction at the category page to explain ."
#  ==========================================
#
# The closest vector to
# " the notion that you lock people up for smoking marijuana is pretty silly ."
# Is
# "that is why the 50 members should not directly represent the organizations notability ."
#  ==========================================
#
# The closest vector to
# "the effects in local government is immediate and an awareness factor is critical ."
# Is
# "keep the information is accurate , and is useful enough to be kept ."
#  ==========================================
#
# The closest vector to
# "we are writing an encyclopedia here , we are not an advertising service ."
# Is
# "we really just tried to get our personality as a team on film ."
#  ==========================================
#
# The closest vector to
# "shoulder injuries limited lópez to just nine innings for the angels in 1967 ."
# Is
# "it is rather simple to roll them and polish off the edges video ."
#  ==========================================
#
# The closest vector to
# "parker was also involved in ship building and trade with the west indies ."
# Is
# "it was written by michael palin and terry jones of monty python fame ."
#  ==========================================
#
# The closest vector to
# "william spencer and samuel browning first formed a partnership between 1778 and 1781 ."
# Is
# "the sisters of providence in the pacific northwest established providence hospital in 1905 ."
#  ==========================================
#
# The closest vector to
# "efforts are made to ensure laboratory safety videos are both relevant and engaging ."
# Is
# "efforts are made to ensure laboratory safety videos are both relevant and engaging ."
#  ==========================================
#
# The closest vector to
# "this word is still being used in some areas of the southern spain ."
# Is
# "wp concerned with vaughan politics , if the other afds are any indication ."
#  ==========================================
#
# The closest vector to
# "they announced their reunion in 2009 , and have released a new album ."
# Is
# "we have posted other auction records ( on art , for example ) ."
#  ==========================================
#
# The closest vector to
# " she was appointed poet laureate on 31 july 1978 by governor cliff finch ."
# Is
# "although he was successful in chicago , bennett decided to return to oregon ."
#  ==========================================
#
# The closest vector to
# "the blocks were also supposedly used for selling slaves during the slave period ."
# Is
# "thus , template titles are subject to the same rules as article titles ."
#  ==========================================
#
# The closest vector to
# "it was registered at the ministry of justice on february 27 , 1998 ."
# Is
# "in 1956 , the city of guadalajara named a street in his honor ."
#  ==========================================
#
# The closest vector to
# "he had no where to go with virtually no money in his pocket . "
# Is
# "he was terrified of death and had never been sick in his life . "
#  ==========================================
#
# The closest vector to
# "note the article under discussion here was tagged for by anonymous spa 64 ."
# Is
# "i was n't trying to make a record that people could relate to ."
#  ==========================================
#
# The closest vector to
# "the construction contract for old central was awarded on june 20 , 1893 ."
# Is
# "according to the 1998 census it has a population of 10 , 301 ."
#  ==========================================
#
# The closest vector to
# "instead , individual shots or short sequences were processed for special visual effects ."
# Is
# "the most depressed comic book characters '' on the best week ever blog ."
#  ==========================================
#
# The closest vector to
# "this was mainly achieved with cannon , but there were variations with spells ."
# Is
# "when they did so , however , they were hampered by limited skills ."
#  ==========================================
#
# The closest vector to
# "most of the information in these articles is already incorporated in existing documentation ."
# Is
# "i do not think this treatment of davis reflects well on this project ."
#  ==========================================
#
# The closest vector to
# "there used to be a post office which was previously a police barracks ."
# Is
# "hello , i 'm looking for information on a ship named hms joanna ."
#  ==========================================
#
# The closest vector to
# "the community forum allows users to share ideas , components , and protocols ."
# Is
# "income tax ( building societies ) ( audit powers ) regulations 1992 s ."
#  ==========================================
#
# The closest vector to
# "it was the first full reunion for the student body in 20 years ."
# Is
# " the tang chinese had recruited many central asian turks into their armed forces ."
#  ==========================================
#
# The closest vector to
# "by the mid-1980s she was regarded as a veteran of the adult industry ."
# Is
# "he even stops going to school and become a slave to his mother ."
#  ==========================================
#
# The closest vector to
# "i will be only too pleased to address the root problem with editors . "
# Is
# "if they lack interest , they will not vote by their own choice . "
#  ==========================================
#
# The closest vector to
# "in the 1920s it housed various writers ' organizations and a literary museum ."
# Is
# "income tax ( building societies ) ( audit powers ) regulations 1992 s ."
#  ==========================================
#
# The closest vector to
# "joe is a technician aboard the toronto and a good friend of tom ."
# Is
# "i am sure that lucius sweet can not be considered a one-time character ."
#  ==========================================
#
# The closest vector to
# "alumni of the university include some of the major figures of modern history . "
# Is
# "the larvae are pale green with a broad black line along each side . "
#  ==========================================
#
# The closest vector to
# "in february , 1998 , syndicated sports talk replaced oldies during those hours . "
# Is
# "they had come from places where they had already experienced and known humiliation . "
#  ==========================================
#
# The closest vector to
# "in 1956 , the city of guadalajara named a street in his honor ."
# Is
# "after his term as collector of customs , he retired to his plantation ."
#  ==========================================
#
# The closest vector to
# "i had a family growing , and i decided to be with them ."
# Is
# "i had a family growing , and i decided to be with them ."
#  ==========================================
#
# The closest vector to
# "henry cotton wins his third british open , at the age of 41 ."
# Is
# "this is a corporate logo for traveller 's tales and their associated website ."
#  ==========================================
#
# The closest vector to
# "i just do n't see how this page is useful in any ways . "
# Is
# "it is clear my language is not that of a native french speaker . "
#  ==========================================
#
# The closest vector to
# "unit 2 was cleared by the regulator ski and was free to restart ."
# Is
# "you go the other way to turn those characters into the original data ."
#  ==========================================
#
# The closest vector to
# "lion red rugby league annual , new zealand rugby football league , 1986 ."
# Is
# "at the end of october , wichita was assigned to task group 34 ."
#  ==========================================
# The closest vector to
# "june 18 , 2004 [ 2 ] whilst others implement many other strategies ."
# Is
# "in 1959 all of galway 's competing hurling teams transferred provinces to munster ."
#  ==========================================
#
# The closest vector to
# "different schools of painting are shown from the sixteenth to the twentieth centuries ."
# Is
# "the most depressed comic book characters '' on the best week ever blog ."
#  ==========================================
#
# The closest vector to
# "the piece in the pocket can be put back on the board later ."
# Is
# "a hand made by hitting two consecutive cards on the turn and river ."
#  ==========================================
#
# The closest vector to
# "the blocks were also supposedly used for selling slaves during the slave period ."
# Is
# "even if married in another state , it is not recognized within missouri ."
#  ==========================================
#
# The closest vector to
# "fringe , would have to be proved , and covered to be notable ."
# Is
# "wp concerned with vaughan politics , if the other afds are any indication ."
#  ==========================================
#
# The closest vector to
# "i am trying to discuss the issue and doing so in good faith ."
# Is
# "i do n't believe you are permitted to have a say in it ."
#  ==========================================
#
# The closest vector to
# "by the seventh season , anthony is working hard to complete law school ."
# Is
# "you go the other way to turn those characters into the original data ."
#  ==========================================
#
# The closest vector to
# "the village was enhanced in june 2005 by the addition of a pharmacy ."
# Is
# "made a nom per csd f1 but was declined with no reason why ."
#  ==========================================
#
# The closest vector to
# "one is by looking for clusters of parameter values which work particularly well ."
# Is
# "each order is considered atomic , though there is no support of transactions ."
#  ==========================================
#
# The closest vector to
# "at the 2006 census , its population was 157 , in 37 families ."
# Is
# "the baltimore colts ran a version of the play in december , 1970 ."
#  ==========================================
#
# The closest vector to
# "these units included the norwegian independent company 1 and 5 troop , no ."
# Is
# "however , the links added do seem to provide more evidence of notability ."
#  ==========================================
#
# The closest vector to
# "the latter applies to all 27 current member states of the european union ."
# Is
# "according to the 1998 census it has a population of 10 , 301 ."
#  ==========================================
#
# The closest vector to
# "fm ) is a radio station licensed to moscow , idaho , usa ."
# Is
# "it is rather simple to roll them and polish off the edges video ."
#  ==========================================
#
# The closest vector to
# "chain falls tend to use internal gear sets to provide the mechanical advantage ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "sometimes a tv station may air the same show twice back to back ."
# Is
# "i think that every issue should be dealt with on an individual basis ."
#  ==========================================
#
# The closest vector to
# "i am open to suggestions for a better sentence meeting the two criteria ."
# Is
# "we really just tried to get our personality as a team on film ."
#  ==========================================
#
# The closest vector to
# "the community support for the project was another key aspect of its success ."
# Is
# "he presently does not have a website so the link should be removed ."
#  ==========================================
#
# The closest vector to
# " those are the best places to get some advice on starting out here ."
# Is
# "keep - the reference in the article convinces me she satisfies the gng ."
#  ==========================================
#
# The closest vector to
# "large net benefit to the project , and will make a fine admin ."
# Is
# "i am sure that lucius sweet can not be considered a one-time character ."
#  ==========================================
#
# The closest vector to
# "breaking and entering ( novel ) , a 2000 crime novel by h ."
# Is
# "january 12 , 1931 ) was an indian freedom fighter , a revolutionary ."
#  ==========================================
#
# The closest vector to
# "miller , jr and jeffrey paul , oxford , basil blackwell , pp ."
# Is
# "evans , partial differential equations , american mathematical society , providence , 1998 ."
#  ==========================================
#
# The closest vector to
# "i did some research online and found this to be a common problem ."
# Is
# "ok , i guess this is a test of how closely we read ."
#  ==========================================
#
# The closest vector to
# "cows , goats , pigs and sheep are raised throughout villa de ramos ."
# Is
# "many people seem to have strong opinions on the subject ( see e ."
#  ==========================================
#
# The closest vector to
# "the national workers ' union is a trade union in trinidad and tobago ."
# Is
# "january 12 , 1931 ) was an indian freedom fighter , a revolutionary ."
#  ==========================================
#
# The closest vector to
# "a tax break issued by the government has failed to revive the industry ."
# Is
# "when they did so , however , they were hampered by limited skills ."
#  ==========================================
#
# The closest vector to
# "each party is represented by an attorney while witnesses and evidence are presented ."
# Is
# "rock and roll people '' which is from the mind games sessions ) ."
#  ==========================================
#
# The closest vector to
# "he arrived in hong kong in 1945 as part of the royal marines ."
# Is
# "he was flying back to dublin after spending christmas in the slovak republic ."
#  ==========================================
#
# The closest vector to
# "all 67 seats in the minnesota senate were up for election in 2012 ."
# Is
# "instead , individual shots or short sequences were processed for special visual effects ."
#  ==========================================
#
# The closest vector to
# "over the next few years , newton had guest roles in various shows ."
# Is
# "in july of the same year , he was elevated to chief justice ."
#  ==========================================
#
# The closest vector to
# "the tang chinese had recruited many central asian turks into their armed forces ."
# Is
# "now is a good time to make sure that everything is still verified . "
#  ==========================================
#
# The closest vector to
# "remnants of fire found during the excavation show that the city was burnt ."
# Is
# "instead , individual shots or short sequences were processed for special visual effects ."
#  ==========================================
#
# The closest vector to
# "a redirect is unnecessary also -- it 's not a reasonable search term ."
# Is
# "i am sure that lucius sweet can not be considered a one-time character ."
#  ==========================================
#
# The closest vector to
# "he was the son of robert the magnificent , the duke of normandy . "
# Is
# "it is said the newspaper survived only because lincoln was a smart politician . "
#  ==========================================
#
# The closest vector to
# "even if married in another state , it is not recognized within missouri ."
# Is
# "yes , so long as the whole thing is in air tight containers ."
#  ==========================================
#
# The closest vector to
# "some free blacks in the north also founded small businesses and even newspapers ."
# Is
# "eight teams take part and the competition is composed of a single league ."
#  ==========================================
# The closest vector to
# "that is , concerning the offices and majesty of christ the mediator ] ."
# Is
# "rock and roll people '' which is from the mind games sessions ) ."
#  ==========================================
#
# The closest vector to
# "peter and wendy free her , and peter is honored by the tribe ."
# Is
# " the community support for the project was another key aspect of its success ."
#  ==========================================
#
# The closest vector to
# "the fifth volume is scheduled to be released on april 22 , 2009 . "
# Is
# "they had come from places where they had already experienced and known humiliation . "
#  ==========================================
#
# The closest vector to
# "bureaucrats that are active regularly are the bureaucrats that were promoted more recently ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "he served in the vermont senate from 1851 to 1852 was senate president ."
# Is
# "da silva then moved to italy in 1991 where he played for u ."
#  ==========================================
#
# The closest vector to
# " opened on may 21 , 1978 , the station was originally known as ."
# Is
# "instead , individual shots or short sequences were processed for special visual effects ."
#  ==========================================
#
# The closest vector to
# " large net benefit to the project , and will make a fine admin ."
# Is
# "this is a corporate logo for traveller 's tales and their associated website ."
#  ==========================================
#
# The closest vector to
# "in july of the same year , he was elevated to chief justice ."
# Is
# "in 1994 , jack took hoover to court over the free flight promotion ."
#  ==========================================
#
# The closest vector to
# "my main reason for asking the question and inviting debate was to learn ."
# Is
# "i brought it up in the talk pages but it was n't resolved ."
#  ==========================================
#
# The closest vector to
# "in this context , joe 's reply is both meaningful and arguably accurate ."
# Is
# " it is also stated on-screen before purchase that not all boxes are compatible ."
#  ==========================================
#
# The closest vector to
# "write up a draft in your userspace and bring it here to show ."
# Is
# "i am sure that lucius sweet can not be considered a one-time character ."
#  ==========================================
#
# The closest vector to
# "made a nom per csd f1 but was declined with no reason why ."
# Is
# "i brought it up in the talk pages but it was n't resolved ."
#  ==========================================
#
# The closest vector to
# "i will be only too pleased to address the root problem with editors . "
# Is
# "if they lack interest , they will not vote by their own choice . "
#  ==========================================
#
# The closest vector to
# "the character herself would n't make a visual appearance until battlefield in 1989 ."
# Is
# "i brought it up in the talk pages but it was n't resolved ."
#  ==========================================
#
# The closest vector to
# "the amount of time you spend at the reference desk is quite interesting ."
# Is
# "the cabinet of nigeria is the executive branch of the government of nigeria ."
#  ==========================================
#
# The closest vector to
# "with this , he is also wearing a large fur coat and hat ."
# Is
# "at the end of october , wichita was assigned to task group 34 ."
#  ==========================================
#
# The closest vector to
# "iron and steel production were also central to the development of the town ."
# Is
# "relies primarily on primary sources and imdb - neither of which are sufficient ."
#  ==========================================
#
# The closest vector to
# "the article should be retained and improved in accordance with our editing policy ."
# Is
# "large net benefit to the project , and will make a fine admin ."
#  ==========================================
#
# The closest vector to
# "the most depressed comic book characters '' on the best week ever blog ."
# Is
# "the baltimore colts ran a version of the play in december , 1970 ."
#  ==========================================
#
# The closest vector to
# "the acquisitions in green bay and new orleans were part of this strategy ."
# Is
# "evans , partial differential equations , american mathematical society , providence , 1998 ."
#  ==========================================
#
# The closest vector to
# "he was terrified of death and had never been sick in his life ."
# Is
# "he even stops going to school and become a slave to his mother ."
#  ==========================================
#
# The closest vector to
# "he got the name from seeing multiple road signs during a road trip . "
# Is
# "they immediately gave him the full ten points because they needed more musicians . "
#  ==========================================
#
# The closest vector to
# "looks like it was split from censorship with just brazil and venezuela ( !"
# Is
# "i brought it up in the talk pages but it was n't resolved ."
#  ==========================================
#
# The closest vector to
# "this was mainly achieved with cannon , but there were variations with spells ."
# Is
# "the parents also act like zombies maybe ignoring the reality of the situation ."
#  ==========================================
#
# The closest vector to
# "rbi in the series as the cardinals defeated the mets in seven games ."
# Is
# "the baltimore colts ran a version of the play in december , 1970 ."
#  ==========================================
#
# The closest vector to
# "w ) in 1990 , the population was recorded at 6 , 190 ."
# Is
# "according to the 1998 census it has a population of 10 , 301 ."
#  ==========================================
#
# The closest vector to
# "bureaucrats that are active regularly are the bureaucrats that were promoted more recently ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# " if merge , then delete the 2 redirects as they are rather irrelevant ."
# Is
# "yes , so long as the whole thing is in air tight containers ."
#  ==========================================
#
# The closest vector to
# "that is why the 50 members should not directly represent the organizations notability ."
# Is
# " the falcons first season was also the start of the super bowl era ."
#  ==========================================
#
# The closest vector to
# "the final gravity is the specific gravity measured at the completion of fermentation ."
# Is
# "the articles seem to advocate the ideas they cover and to overlap significantly ."
#  ==========================================
#
# The closest vector to
# "it is rather simple to roll them and polish off the edges video ."
# Is
# "it was written by michael palin and terry jones of monty python fame ."
#  ==========================================
#
# The closest vector to
# "by age 14 , however , he decided to devote himself to composition . "
# Is
# "he was terrified of death and had never been sick in his life . "
#  ==========================================
#
# The closest vector to
# "the effects in local government is immediate and an awareness factor is critical . "
# Is
# "the larvae are pale green with a broad black line along each side . "
#  ==========================================
#
# The closest vector to
# "f pilots saw , were not over taiwan , but in north yemen ."
# Is
# "i do n't believe you are permitted to have a say in it ."
#  ==========================================
#
# The closest vector to
# "at the 2006 census , its population was 157 , in 37 families ."
# Is
# "instead , individual shots or short sequences were processed for special visual effects ."
#  ==========================================
#
# The closest vector to
# "this particular article though , is not of featured quality as of yet ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
# The closest vector to
# "national archives and records administration ( talk ) stub-class ( no-class ) added ."
# Is
# "income tax ( building societies ) ( audit powers ) regulations 1992 s ."
#  ==========================================
#
# The closest vector to
# "would someone please commit on the above question which relates to reference 8 ."
# Is
# "you go the other way to turn those characters into the original data ."
#  ==========================================
#
# The closest vector to
# "wikipedia article into an example of a point merely to illustrate that point ."
# Is
# "i do n't believe you are permitted to have a say in it ."
#  ==========================================
#
# The closest vector to
# "or perhaps the prose should be touched up first and then cut down ."
# Is
# "i do n't believe you are permitted to have a say in it ."
#  ==========================================
#
# The closest vector to
# "if merge , then delete the 2 redirects as they are rather irrelevant ."
# Is
# "that is why the 50 members should not directly represent the organizations notability ."
#  ==========================================
#
# The closest vector to
# "keep - the reference in the article convinces me she satisfies the gng ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "some of his most prominent roles are his appearances in er as dr ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "i found no reliable and independent sources that show this organization is notable ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "i think the whole approach is making too much out of the problem ."
# Is
# "keep - the reference in the article convinces me she satisfies the gng ."
#  ==========================================
#
# The closest vector to
# "residents of the village live either in the village or on outlying farms ."
# Is
# "there are also extant portions of commentaries on the gospels from his pen ."
#  ==========================================
#
# The closest vector to
# "hair that included stops in south carolina , georgia , tennessee and kentucky ."
# Is
# "it is the most popular kernel function used in support vector machine classification ."
#  ==========================================
#
# The closest vector to
# "one of the vehicles is still kept in storage by the police forces ."
# Is
# "he was flying back to dublin after spending christmas in the slovak republic ."
#  ==========================================
#
# The closest vector to
# "i do not know whether this has anything to do with my question ."
# Is
# "i do n't believe you are permitted to have a say in it ."
#  ==========================================
#
# The closest vector to
# "did all of the above , but still no joy for for me ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "thanks again for seeking constructive feedback as opposed to engaging in destructive actions ."
# Is
# "thanks again for seeking constructive feedback as opposed to engaging in destructive actions ."
#  ==========================================
#
# The closest vector to
# "it is clear my language is not that of a native french speaker ."
# Is
# "i will not engage with people who are rude from the word go ."
#  ==========================================
#
# The closest vector to
# "born in hamilton , ferguson has been a keen rangers fan since childhood ."
# Is
# "he even stops going to school and become a slave to his mother ."
#  ==========================================
#
# The closest vector to
# "it is one of the largest cable operators in the republic of serbia ."
# Is
# "it is a unique creative vision of a small isolated group of individuals ."
#  ==========================================
#
# The closest vector to
# "different schools of painting are shown from the sixteenth to the twentieth centuries . "
# Is
# "the larvae are pale green with a broad black line along each side . "
#  ==========================================
#
# The closest vector to
# "the school is housed in a building that was originally the high school . "
# Is
# "they had come from places where they had already experienced and known humiliation . "
#  ==========================================
#
# The closest vector to
# "the remaining teams either folded or chose to play in lower local leagues ."
# Is
# "then we can have a general discussion on whether to extend the experiment ."
#  ==========================================
#
# The closest vector to
# "the transfer function is also known as the system function or network function ."
# Is
# "initially , the simplicity bearing was only offered in closed , imperial sizes ."
#  ==========================================
#
# The closest vector to
# "main features include the welfare and memorial parks and st mary 's church ."
# Is
# "the articles seem to advocate the ideas they cover and to overlap significantly ."
#  ==========================================
#
# The closest vector to
# "his second song of the evening was `` does your mother know '' ."
# Is
# "the murray river is the only large , permanent river in the state ."
#  ==========================================
#
# The closest vector to
# "they announced their reunion in 2009 , and have released a new album ."
# Is
# "the birds of the gambia ( 2nd edition , 1991 ) by m ."
#  ==========================================
#
# The closest vector to
# "he then added , `` these damn indians have gone absolutely wild [ ."
# Is
# "i figured out that i was tired of helping others make their art ."
#  ==========================================
#
# The closest vector to
# "he studied economics at temple university , and taught journalism at temple university ."
# Is
# "in july of the same year , he was elevated to chief justice ."
#  ==========================================
#
# The closest vector to
# "this department focuses on assessing the quality of wikipedia 's electronic related articles ."
# Is
# "each order is considered atomic , though there is no support of transactions ."
#  ==========================================
#
# The closest vector to
# "but there are no other details except that it was taken in 1941 ."
# Is
# "each order is considered atomic , though there is no support of transactions ."
#  ==========================================
#
# The closest vector to
# "it results in a system that is far less than it should be ."
# Is
# "i think is a pretty reasonable idea , and might also be useful ."
#  ==========================================
#
# The closest vector to
# "some members of the group separated themselves from the band to write tracks ."
# Is
# "but i think this reflects a perception of the arbcom as a court ."
#  ==========================================
#
# The closest vector to
# "in the mid-1990s he opened a post card stand in cairns , queensland ."
# Is
# "january 12 , 1931 ) was an indian freedom fighter , a revolutionary ."
#  ==========================================
#
# The closest vector to
# "their performance at the festival garnered a lot of attention for the band ."
# Is
# "delete without prejudice to recreation if reliable sources are found about the man ."
#  ==========================================
#
# The closest vector to
# "the khmer rouge gave us guns and pushed us into the front line ."
# Is
# "the stuff i have found has been dominated by ( 1 ) www ."
#  ==========================================
#
# The closest vector to
# "once it was one of the most important small kingdoms of south arabia ."
# Is
# "other complete sentences consist of two or more clauses ( see below ) ."
#  ==========================================
#
# The closest vector to
# "seven are chosen annually , two from the previous year continued in office ."
# Is
# "complete participation researcher is completely integrated in population of study beforehand ( i ."
#  ==========================================
#
# The closest vector to
# "clark house ( newton , massachusetts ) , also known as the rev ."
# Is
# "income tax ( building societies ) ( audit powers ) regulations 1992 s ."
#  ==========================================
#
# The closest vector to
# "i think is a pretty reasonable idea , and might also be useful ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
#
# The closest vector to
# "anyone can remove them at any time without violating any guideline or policy ."
# Is
# "you go the other way to turn those characters into the original data ."
#  ==========================================
#
# The closest vector to
# "some members of the group separated themselves from the band to write tracks ."
# Is
# "chain falls tend to use internal gear sets to provide the mechanical advantage ."
#  ==========================================
#
# The closest vector to
# "the hearings were televised live at the state of illinois center in chicago ."
# Is
# " the tang chinese had recruited many central asian turks into their armed forces ."
#  ==========================================
#
# The closest vector to
# "it does not even seem to be a topic of speculation for historians ."
# Is
# "i have been doing it manually , but it is pretty time consuming ."
#  ==========================================
# The closest vector to
# " one of five players in nba history to win consecutive finals mvp awards ."
# Is
# "january 12 , 1931 ) was an indian freedom fighter , a revolutionary ."
#  ==========================================
