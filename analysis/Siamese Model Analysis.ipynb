# %%
import sys

sys.path.append('../generate_dataset/resources')
sys.path.append('../Siamese')
import SiameseNet
from pytorch_fast_elmo import FastElmo, batch_to_char_ids
import sys
from scipy.cluster.hierarchy import dendrogram, linkage
import scipy
import matplotlib.pyplot as plt
import random
import torch
from typing import List
import numpy as np
import utils
import termcolor


from typing import NewType

# %%
class Vector(object):
    
    def __init__(self, vec, sentence, index):
        
        self.vec = vec
        self.sentence = sentence
        self.index = index
        self.size = np.linalg.norm(self.vec)
    
    def get_word(self):
        
        return self.sentence[self.index]
    
    def get_vector(self): 
        
        return self.vec
    
    def get_sentence(self):
        
        return self.sentence
    
    def get_index(self):
        
        return self.index
    
    def get_size(self):
        
        return self.size
    
    def __str__(self):
        
        words = self.get_sentence()
        i = self.get_index()
        before = " ".join(words[:i])
        after = " ".join(words[i + 1:])
        word = "***"+termcolor.colored(self.get_word(), "blue", attrs = ['bold'])+"***"
        sent = '""' + before + " " + word + " " + after + '"' + "***WORD: {} ***".format(self.get_word())
        return sent
    
    def similarity(self, other):
        
        if other is self: return -np.inf
        
        return self.get_vector().dot(other.get_vector())/(self.get_size() * other.get_size())
    
    @staticmethod
    def get_closest_vector(vec, vecs):
    
        closest = max(vecs, key = lambda vector: vector.similarity(vec))
        return closest

# %%
def transform(model, vector: Vector):
    
    vec_pytorch = torch.from_numpy(vector.get_vector()).float()
    vector.vec = model._represent(vec_pytorch).detach().numpy()
    
    
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
def print_closest_vectors(sample, all_vecs):
    
    for vector in sample:
        closest = Vector.get_closest_vector(vector, all_vecs)
        print("The closest vector to\n{}\nIs\n{} \n ==========================================\n".format(vector, closest))
    
def load_sents(fname = "sents_f", max_length = 15):
    
    with open(fname, "r") as f:
              
        lines = f.readlines()
    
    lines =  [line.strip().split(" ") for line in lines]
    if max_length is not None:
        lines = list(filter(lambda sentence: len(sentence) < max_length, lines))
    return lines

def load_model(name = "model.pt"):
    net = SiameseNet.SiameseNet()
    net.load_state_dict(torch.load(name))
    net.eval()
    return net

def list_vectors(vecs, sents: List[List[str]]) -> List[Vector]:
    
    num_sentences = len(sents)
    sents_indices_and_vecs =  zip(range(num_sentences), vecs)
    all_vectors = []

    for sent_index, sent_vectors in sents_indices_and_vecs:
        
        for i, (w,vec) in enumerate(zip(sents[sent_index], vecs[sent_index])):   
            
            v = Vector(vec.detach().numpy(), sents[sent_index], i)
            all_vectors.append(v)
            
    return all_vectors

# %% [markdown]
# Load pretrained ELMO and a collection of Wikipedia sentences.

# %%
all_sentences = load_sents(max_length = 15)
options_file = "../generate_dataset/" + utils.DEFAULT_PARAMS["elmo_options"]
weight_file = "../generate_dataset/" + utils.DEFAULT_PARAMS["elmo_weights"]
elmo = FastElmo(options_file, weight_file)

# %%
N = 1000
subset_size = 150
random.seed(0)
sentences = all_sentences[:N]

# %% [markdown]
# Collect ELMO states over N sentences, and load pretrained Siamese network.

# %%
character_ids = batch_to_char_ids(sentences)
embeddings = elmo(character_ids) # collect elmo states
network = load_model()

# %% [markdown]
# ### Find the closest vectors to a collection of (original) ELMO vectors.

# %%
vecs = list_vectors(embeddings["elmo_representations"][0], sentences)
subset = np.random.choice(vecs, size = subset_size)
print_closest_vectors(subset, vecs)
# Out:
# The closest vector to
# ""and ***they*** are multiple and independent and have the necessary articles and reviews ."***WORD: they ***
# Is
# "" ***they*** 've been reviewed by charity navigator [ 1 ] and by give ."***WORD: they ***
#  ==========================================
#
# The closest vector to
# ""the statue was broken in two while being transported to ***their*** georgia parish ."***WORD: their ***
# Is
# ""at this point , he was taken to ***his*** home town for burial ."***WORD: his ***
#  ==========================================
#
# The closest vector to
# ""it includes literary uses and commentary on the term as used in society ***.*** "***WORD: . ***
# Is
# ""thus , template titles are subject to the same rules as article titles ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""target identification is typically the starting point of the modern drug discovery process ***.*** "***WORD: . ***
# Is
# ""it is the most popular kernel function used in support vector machine classification ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""this word is still being used in some areas of the ***southern*** spain ."***WORD: southern ***
# Is
# ""such regions are primarily located in the states of central and ***southern*** europe ."***WORD: southern ***
#  ==========================================
#
# The closest vector to
# ""european cup was the 20th edition of europe 's premier club handball ***tournament*** ."***WORD: tournament ***
# Is
# ""it was the first open cup ***tournament*** to be named after lamar hunt ."***WORD: tournament ***
#  ==========================================
#
# The closest vector to
# ""peter street slip , but occasionally found next to the bay street docks ***.*** "***WORD: . ***
# Is
# ""there is little left of the world war ii dodge city army airfield ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""sebastian , on the weekend nearest ***to*** 20 january , his feast day ."***WORD: to ***
# Is
# ""route 250 ; the road extends all the way ***to*** sandusky , oh ."***WORD: to ***
#  ==========================================
#
# The closest vector to
# ""estimated height is 69 to 92 feet ( 21 ***to*** 28 meters ) ."***WORD: to ***
# Is
# ""estimated height is 69 ***to*** 92 feet ( 21 to 28 meters ) ."***WORD: to ***
#  ==========================================
#
# The closest vector to
# ""the total number is uncertain but it is thought there were around four ***.*** "***WORD: . ***
# Is
# ""however , the links added do seem to provide more evidence of notability ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""hair that included stops in south carolina , georgia , ***tennessee*** and kentucky ."***WORD: tennessee ***
# Is
# ""hair that included stops in south carolina , ***georgia*** , tennessee and kentucky ."***WORD: georgia ***
#  ==========================================
#
# The closest vector to
# ""but thanks for your reasoned comments and input , and ***your*** good luck !"***WORD: your ***
# Is
# ""but thanks for ***your*** reasoned comments and input , and your good luck !"***WORD: your ***
#  ==========================================
#
# The closest vector to
# ""please ask us about ***specific*** issues when you have done your own research ."***WORD: specific ***
# Is
# ""the final gravity is the ***specific*** gravity measured at the completion of fermentation ."***WORD: specific ***
#  ==========================================
#
# The closest vector to
# ""these designated levels are not standard ***but*** vary according to each organizations preference ."***WORD: but ***
# Is
# ""strong keep - most primary schools are not notable ***but*** this one is ."***WORD: but ***
#  ==========================================
#
# The closest vector to
# ""he got the ***name*** from seeing multiple road signs during a road trip ."***WORD: name ***
# Is
# ""sul for this ***name*** , they have the greatest priority for this name ."***WORD: name ***
#  ==========================================
#
# The closest vector to
# ""at the end of october , wichita was ***assigned*** to task group 34 ."***WORD: assigned ***
# Is
# ""the construction contract for old central was ***awarded*** on june 20 , 1893 ."***WORD: awarded ***
#  ==========================================
#
# The closest vector to
# ""keep the information is accurate , and is useful enough to be kept ***.*** "***WORD: . ***
# Is
# ""possible hoax , or at the least , something made up one day ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""in 1988 , he published his ***first*** book dedicated entirely to film theory ."***WORD: first ***
# Is
# ""his ***first*** novel , summer on the water , was published in 1948 ."***WORD: first ***
#  ==========================================
#
# The closest vector to
# ""when they did so , however , they were ***hampered*** by limited skills ."***WORD: hampered ***
# Is
# ""efforts to rebuild the niagara were ***hampered*** by the lack of original plans ."***WORD: hampered ***
#  ==========================================
#
# The closest vector to
# ""those ***are*** the best places to get some advice on starting out here ."***WORD: are ***
# Is
# ""the color balance adjustment and wider view ***are*** improvements , in my view ."***WORD: are ***
#  ==========================================
#
# The closest vector to
# ""the ocean liner ***ran*** aground in the río grande do sul , brazil ."***WORD: ran ***
# Is
# ""take a show that was first broadcast in 1979 and ***ran*** till 1988 ."***WORD: ran ***
#  ==========================================
#
# The closest vector to
# ""adds nothing to the reader 's understanding of ***society*** 's perspective on napoleon ."***WORD: society ***
# Is
# ""it includes literary uses and commentary on the term as used in ***society*** ."***WORD: society ***
#  ==========================================
#
# The closest vector to
# ""of thee i sing ( song ) , a ***song*** from the musical ."***WORD: song ***
# Is
# ""cheng released his debut ep , sing a ***song*** , in october 2009 ."***WORD: song ***
#  ==========================================
#
# The closest vector to
# ""the house changed hands many times over the years before finally being demolished ***.*** "***WORD: . ***
# Is
# ""this happened a couple of years before brian 's death in the 1970s ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""he was terrified of death and ***had*** never been sick in his life ."***WORD: had ***
# Is
# ""he ***had*** no where to go with virtually no money in his pocket ."***WORD: had ***
#  ==========================================
#
# The closest vector to
# ""wikipedia ***(*** en ) - instant is the one you are looking for ."***WORD: ( ***
# Is
# ""all that article is a bullet point list of biography details ***(*** e ."***WORD: ( ***
#  ==========================================
#
# The closest vector to
# ""this was a rebellion against the british colonial ***government*** in 1837 and 1838 ."***WORD: government ***
# Is
# ""representative town meeting , though no town has adopted this form of ***government*** ."***WORD: government ***
#  ==========================================
#
# The closest vector to
# ""for the defense john cromwell william powell , kay francis ***,*** william b ."***WORD: , ***
# Is
# ""for the defense john cromwell william powell ***,*** kay francis , william b ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# ""he received a phd from the university ***of*** north carolina at chapel hill ."***WORD: of ***
# Is
# ""in 1943 , she obtained a medical degree from the university ***of*** chicago ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""founded in 1872 , it is the oldest college humor magazine ***in*** america ."***WORD: in ***
# Is
# ""it is one of the largest cable operators ***in*** the republic of serbia ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""the journal expressed ***initial*** concern regarding the paper 's validity on november 1 ."***WORD: initial ***
# Is
# ""the journal expressed initial ***concern*** regarding the paper 's validity on november 1 ."***WORD: concern ***
#  ==========================================
#
# The closest vector to
# ""all 67 seats in the minnesota senate were up for ***election*** in 2012 ."***WORD: election ***
# Is
# ""it was elected at the 1946 general ***election*** in november of that year ."***WORD: election ***
#  ==========================================
#
# The closest vector to
# ""the editors of that article can add ***anything*** else they want from here ."***WORD: anything ***
# Is
# ""i do not possess ***anything*** either as landed property or as cash account ."***WORD: anything ***
#  ==========================================
#
# The closest vector to
# ""he was terrified of death and ***had*** never been sick in his life ."***WORD: had ***
# Is
# ""he ***had*** no where to go with virtually no money in his pocket ."***WORD: had ***
#  ==========================================
#
# The closest vector to
# ""wp concerned with vaughan politics , ***if*** the other afds are any indication ."***WORD: if ***
# Is
# ""now ***if*** only we can get someone to write the australian literature article ."***WORD: if ***
#  ==========================================
# The closest vector to
# ""in 2007 , villa was ***actively*** training to make the 2010 winter paralympics ."***WORD: actively ***
# Is
# ""they ***actively*** encouraged his painting activities and later supported him in higher education ."***WORD: actively ***
#  ==========================================
#
# The closest vector to
# ""applications for single source analytics ***,*** new york , ny , united states ."***WORD: , ***
# Is
# ""applications for single source analytics , new york ***,*** ny , united states ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# ""the hearings were televised ***live*** at the state of illinois center in chicago ."***WORD: live ***
# Is
# ""he has since continued playing ***live*** with muse on their 2nd law tour ."***WORD: live ***
#  ==========================================
#
# The closest vector to
# ""the composition of julian 's army at strasbourg can only ***be*** partially reconstructed ."***WORD: be ***
# Is
# ""the piece in the pocket can ***be*** put back on the board later ."***WORD: be ***
#  ==========================================
#
# The closest vector to
# ""then we can have a general discussion ***on*** whether to extend the experiment ."***WORD: on ***
# Is
# ""mammal articles needing attention for more details ***on*** when this should be used ."***WORD: on ***
#  ==========================================
#
# The closest vector to
# ""different schools of painting are shown ***from*** the sixteenth to the twentieth centuries ."***WORD: from ***
# Is
# ""the series aired ***from*** july 5 , 1943 to july 6 , 1945 ."***WORD: from ***
#  ==========================================
#
# The closest vector to
# ""support members of small communities who support the larger good of the nation ***.*** "***WORD: . ***
# Is
# ""some of the organizations are actually the youth wings of larger political parties ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""due to data partition , x can ***not*** be accessed directly from b ."***WORD: not ***
# Is
# ""i am sure that lucius sweet can ***not*** be considered a one-time character ."***WORD: not ***
#  ==========================================
#
# The closest vector to
# "" ***in*** 1942 , garrett gave it to princeton 's institute for advanced study ."***WORD: in ***
# Is
# "" ***in*** 1930 , jackson was elected to membership in the american law institute ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""the economic status of information security came to the intellectual fore around 2000 ***.*** "***WORD: . ***
# Is
# ""has been doing an excellent job patrolling new pages for speedy deletion criteria ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""the stuff i have found has been dominated by ( 1 ) www ***.*** "***WORD: . ***
# Is
# ""i just do n't see how this page is useful in any ways ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""the teenagers ***get*** to work , bringing in food , cleaning , etc ."***WORD: get ***
# Is
# ""i hope to ***get*** an independent assessment on the additions i have made ."***WORD: get ***
#  ==========================================
#
# The closest vector to
# ""he was terrified of death and had never been sick in his life ***.*** "***WORD: . ***
# Is
# ""he had no where to go with virtually no money in his pocket ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""rogers also requested jackson 's medical records from murray but never received them ***.*** "***WORD: . ***
# Is
# ""although he was successful in chicago , bennett decided to return to oregon ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""but mainly because he wants to beat ***me*** ( and always does ) ."***WORD: me ***
# Is
# ""oppose as others , i see too many traits that would worry ***me*** ."***WORD: me ***
#  ==========================================
#
# The closest vector to
# ""a few of the sources merely mention the subject ***in*** a trivial context ."***WORD: in ***
# Is
# ""you can also summarize this ***in*** a new section in the evidence page ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""this word is still being used ***in*** some areas of the southern spain ."***WORD: in ***
# Is
# ""the program continues to be shown ***in*** major cities throughout the united states ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""its school functions have now been taken ***over*** by service children 's education ."***WORD: over ***
# Is
# ""the old jail facility will be turned ***over*** to the national historical commission ."***WORD: over ***
#  ==========================================
#
# The closest vector to
# ""serbia claims all of kosovo , turkey does not claim all ***of*** cyprus ."***WORD: of ***
# Is
# ""serbia claims all ***of*** kosovo , turkey does not claim all of cyprus ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""miller is a distinguished professor of english at the ***university*** of california irvine ."***WORD: university ***
# Is
# ""irwin received his bachelor 's degree in english at the ***university*** of st ."***WORD: university ***
#  ==========================================
#
# The closest vector to
# ""he was a delegate ***to*** the democratic national conventions in 1952 and 1956 ."***WORD: to ***
# Is
# ""in 1959 , he was appointed ambassador ***to*** the soviet union and poland ."***WORD: to ***
#  ==========================================
#
# The closest vector to
# ""he presently does ***not*** have a website so the link should be removed ."***WORD: not ***
# Is
# ""arabic does ***not*** have an indefinite article like the english a or an ."***WORD: not ***
#  ==========================================
#
# The closest vector to
# "" ***pierce*** died of complications from an abdominal infection in los angeles , california ."***WORD: pierce ***
# Is
# "" ***walton*** moved to montreal , quebec , after her first novel was published ."***WORD: walton ***
#  ==========================================
#
# The closest vector to
# ""surrey reclaimed the title that yorkshire had taken from them the ***previous*** season ."***WORD: previous ***
# Is
# ""seven are chosen annually , two from the ***previous*** year continued in office ."***WORD: previous ***
#  ==========================================
#
# The closest vector to
# ""its average depth is and its maximum depth is , ***near*** the dam ."***WORD: near ***
# Is
# ""founder of petty enterprises , level cross , north carolina , ***near*** greensboro ."***WORD: near ***
#  ==========================================
#
# The closest vector to
# ""please read the article first , ***before*** you comment on things like these ."***WORD: before ***
# Is
# ""the format of the table was done ***before*** i saw that other page ."***WORD: before ***
#  ==========================================
#
# The closest vector to
# ""in 1943 , she obtained a medical ***degree*** from the university of chicago ."***WORD: degree ***
# Is
# ""irwin received his bachelor 's ***degree*** in english at the university of st ."***WORD: degree ***
#  ==========================================
#
# The closest vector to
# ""although ***he*** was raised in a religious family , norman was an atheist ."***WORD: he ***
# Is
# "" ***he*** was a missionary to the sandwich islands , also known as hawaii ."***WORD: he ***
#  ==========================================
#
# The closest vector to
# ""mla style if possible , or at the very least adding ***reference*** section ."***WORD: reference ***
# Is
# ""would someone please commit on the above question which relates to ***reference*** 8 ."***WORD: reference ***
#  ==========================================
#
# The closest vector to
# ""henry cotton ***wins*** his third british open , at the age of 41 ."***WORD: wins ***
# Is
# ""buck baker ***won*** the pole and herb thomas was victorious in the race ."***WORD: won ***
#  ==========================================
#
# The closest vector to
# ""landmarks in this area include windsor mill ***middle*** school and rutherford business park ."***WORD: middle ***
# Is
# ""landmarks in this area include windsor mill middle ***school*** and rutherford business park ."***WORD: school ***
#  ==========================================
#
# The closest vector to
# ""for the defense john ***cromwell*** william powell , kay francis , william b ."***WORD: cromwell ***
# Is
# ""for the defense john cromwell ***william*** powell , kay francis , william b ."***WORD: william ***
#  ==========================================
#
# The closest vector to
# ""there were 2 , 102 housing units at ***an*** average density of 72 ."***WORD: an ***
# Is
# ""there were 3 , 210 housing units at ***an*** average density of 106 ."***WORD: an ***
#  ==========================================
#
# The closest vector to
# ""february 9 , 1984 ) , was a politician ***in*** ontario , canada ."***WORD: in ***
# Is
# ""party of socialist democracy ) was a political party ***in*** quebec , canada ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""other complete sentences consist of two ***or*** more clauses ( see below ) ."***WORD: or ***
# Is
# ""arabic does not have an indefinite article like the english a ***or*** an ."***WORD: or ***
#  ==========================================
#
# The closest vector to
# ""these designated levels ***are*** not standard but vary according to each organizations preference ."***WORD: are ***
# Is
# ""thus , template titles ***are*** subject to the same rules as article titles ."***WORD: are ***
#  ==========================================
# The closest vector to
# ""in 1988 ***,*** he published his first book dedicated entirely to film theory ."***WORD: , ***
# Is
# ""in 1951 ***,*** he became dean of the college of arts and sciences ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# ""applicants ***shall*** have only five ( 5 ) attempts to pass the examination ."***WORD: shall ***
# Is
# ""that is why the 50 members ***should*** not directly represent the organizations notability ."***WORD: should ***
#  ==========================================
#
# The closest vector to
# ""the dark knight ( film ***)*** are that i explain them too much ."***WORD: ) ***
# Is
# ""the birds of the gambia ( 2nd edition , 1991 ***)*** by m ."***WORD: ) ***
#  ==========================================
#
# The closest vector to
# ""the main ( west ) facade is five bays with a central ***doorway*** ."***WORD: doorway ***
# Is
# ""in the north wall of the chancel is a single narrow pointed ***window*** ."***WORD: window ***
#  ==========================================
#
# The closest vector to
# ""the female flowers are usually solitary , at the base of the inflorescence ***.*** "***WORD: . ***
# Is
# ""the larvae are pale green with a broad black line along each side ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""they only contain a portion of the healthy nutrients which we ***know*** about ."***WORD: know ***
# Is
# ""you do n't have to be a genius to ***know*** what they do ."***WORD: know ***
#  ==========================================
#
# The closest vector to
# ""then he ***trades*** the smallest amount when his trading is at its worst ."***WORD: trades ***
# Is
# ""he ***plays*** the title character in the 2013 feature film the lone ranger ."***WORD: plays ***
#  ==========================================
#
# The closest vector to
# ""the national workers ' union ***is*** a trade union in trinidad and tobago ."***WORD: is ***
# Is
# ""the cabinet of nigeria ***is*** the executive branch of the government of nigeria ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""mr wilkinson whose family ***had*** farmed in the village for a hundred years ."***WORD: had ***
# Is
# ""he was terrified of death and ***had*** never been sick in his life ."***WORD: had ***
#  ==========================================
#
# The closest vector to
# ""extremely minor character not even mentioned in the adaptations that i ***can*** recall ."***WORD: can ***
# Is
# ""i may not know any ww2 author , but i ***can*** always search ."***WORD: can ***
#  ==========================================
#
# The closest vector to
# ""oppose as others , i see too ***many*** traits that would worry me ."***WORD: many ***
# Is
# ""there are ***many*** stories and myths surrounding the building and the harrison family ."***WORD: many ***
#  ==========================================
#
# The closest vector to
# ""although ***he*** was successful in chicago , bennett decided to return to oregon ."***WORD: he ***
# Is
# ""although ***he*** was raised in a religious family , norman was an atheist ."***WORD: he ***
#  ==========================================
#
# The closest vector to
# ""fundraising and architecture plans are underway for a new building in downtown ballard ***.*** "***WORD: . ***
# Is
# ""this sandstone library follows the earlier library plan austin developed at dwight hall ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""keep the information is accurate , and is useful enough ***to*** be kept ."***WORD: to ***
# Is
# ""it was evident , however , that the system needed ***to*** be enlarged ."***WORD: to ***
#  ==========================================
#
# The closest vector to
# ""the ***statements*** of which you complain are sourced to an apparently reliable source ."***WORD: statements ***
# Is
# ""in fact some of your ***comments*** are also applicable to the norway counterpart ."***WORD: comments ***
#  ==========================================
#
# The closest vector to
# ""delete no source for the concept around which ***this*** page has been created ."***WORD: this ***
# Is
# ""rationale was `` i 'm not sure why ***this*** page was ever created ."***WORD: this ***
#  ==========================================
#
# The closest vector to
# ""if he can `` confess his sin ***''*** , slater will stop killing ."***WORD: '' ***
# Is
# ""his second song of the evening was `` does your mother know ***''*** ."***WORD: '' ***
#  ==========================================
#
# The closest vector to
# ""the most common apartment size was 5 rooms of ***which*** there were 23 ."***WORD: which ***
# Is
# ""the most common apartment size was 4 rooms of ***which*** there were 26 ."***WORD: which ***
#  ==========================================
#
# The closest vector to
# ""other escaped slaves joined various seminole ***bands*** as free members of the tribe ."***WORD: bands ***
# Is
# ""some members of the group separated themselves from the ***band*** to write tracks ."***WORD: band ***
#  ==========================================
#
# The closest vector to
# ""rationale was `` i 'm not sure why ***this*** page was ever created ."***WORD: this ***
# Is
# ""delete no source for the concept around which ***this*** page has been created ."***WORD: this ***
#  ==========================================
#
# The closest vector to
# ""rationale was `` i ***'m*** not sure why this page was ever created ."***WORD: 'm ***
# Is
# ""hello , i ***'m*** looking for information on a ship named hms joanna ."***WORD: 'm ***
#  ==========================================
#
# The closest vector to
# ""in our present world view , the paper ***is*** flat and infinitely large ."***WORD: is ***
# Is
# ""this particular article though , ***is*** not of featured quality as of yet ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""in 2001 , peter handed the site over to chris williams as ***editor*** ."***WORD: editor ***
# Is
# ""i seem to be a fairly well-known ***editor*** on this project and others ."***WORD: editor ***
#  ==========================================
#
# The closest vector to
# ""the tone is ok , but the article strikes ***me*** as overly detailed ."***WORD: me ***
# Is
# ""oppose as others , i see too many traits that would worry ***me*** ."***WORD: me ***
#  ==========================================
#
# The closest vector to
# ""there were 3 , 210 housing units at an average density of 106 ***.*** "***WORD: . ***
# Is
# ""there were 2 , 102 housing units at an average density of 72 ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""enormous quantities of water were also required for ***the*** operation of the locomotive ."***WORD: the ***
# Is
# ""iron and steel production were also central to ***the*** development of the town ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""his wife died december ***22*** , 1871 and was buried next to him ."***WORD: 22 ***
# Is
# ""roger lowell putnam was born on december ***19*** , 1893 , in boston ."***WORD: 19 ***
#  ==========================================
#
# The closest vector to
# ""perhaps your reason for ***being*** in this discussion is simply a personal attack ."***WORD: being ***
# Is
# ""he accused one of those two wikipedians of ***being*** on the kennedy payroll ."***WORD: being ***
#  ==========================================
#
# The closest vector to
# ""i do not possess anything either as landed property ***or*** as cash account ."***WORD: or ***
# Is
# ""i do not possess anything either as landed property or ***as*** cash account ."***WORD: as ***
#  ==========================================
#
# The closest vector to
# ""in narrative sequence it is preceded by point ***of*** impact and black light ."***WORD: of ***
# Is
# ""the result was speedy delete a7 , group with no assertion ***of*** notability ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""our ball state course students have been coordinating their topic proposals with ***me*** ."***WORD: me ***
# Is
# ""oppose as others , i see too many traits that would worry ***me*** ."***WORD: me ***
#  ==========================================
#
# The closest vector to
# ""we are writing an encyclopedia here , we are ***not*** an advertising service ."***WORD: not ***
# Is
# ""it is vital to remember that the committee is ***not*** a governing body ."***WORD: not ***
#  ==========================================
#
# The closest vector to
# ""there were 3 , 210 housing units ***at*** an average density of 106 ."***WORD: at ***
# Is
# ""there were 2 , 102 housing units ***at*** an average density of 72 ."***WORD: at ***
#  ==========================================
#
# The closest vector to
# ""language study had ***always*** been one of the core problems for the mission ."***WORD: always ***
# Is
# ""that , however , has clearly ***never*** been the case in human experience ."***WORD: never ***
#  ==========================================
#
# The closest vector to
# ""he ***was*** killed in an aircraft crash near cairns on 7 march 1943 ."***WORD: was ***
# Is
# ""he ***was*** buried in the grange cemetery , edinburgh , on 22 oct ."***WORD: was ***
#  ==========================================
#
# The closest vector to
# ""sometimes a tv station may air the same ***show*** twice back to back ."***WORD: show ***
# Is
# ""spartans on stage and ticket sales for the ***show*** were limited to 300 ."***WORD: show ***
#  ==========================================
# The closest vector to
# ""complete participation ***researcher*** is completely integrated in population of study beforehand ( i ."***WORD: researcher ***
# Is
# ""marriage information per parish records in devon and verified with ***researcher*** in uk ."***WORD: researcher ***
#  ==========================================
#
# The closest vector to
# ""he was the ***eldest*** son of richard , third son of the hon ."***WORD: eldest ***
# Is
# ""he was the eldest ***son*** of richard , third son of the hon ."***WORD: son ***
#  ==========================================
#
# The closest vector to
# ""thousands of people protest against the ruling hamas party in the gaza ***strip*** ."***WORD: strip ***
# Is
# ""thousands of people protest against the ruling hamas party in the ***gaza*** strip ."***WORD: gaza ***
#  ==========================================
#
# The closest vector to
# ""yes , because recording the author of a completely faithful reproduction is ***pointless*** ."***WORD: pointless ***
# Is
# ""a redirect is ***unnecessary*** also -- it 's not a reasonable search term ."***WORD: unnecessary ***
#  ==========================================
#
# The closest vector to
# ""cyclone justin was the largest ***tropical*** cyclone to hit northern queensland in 1997 ."***WORD: tropical ***
# Is
# ""cyclone justin was the largest tropical ***cyclone*** to hit northern queensland in 1997 ."***WORD: cyclone ***
#  ==========================================
#
# The closest vector to
# ""the girls quickly flee back to land , ***but*** the couple follows them ."***WORD: but ***
# Is
# ""many have tried to break this record , ***but*** few have come close ."***WORD: but ***
#  ==========================================
#
# The closest vector to
# ""fa is under the command of ***the*** 2nd brigade , 4th infantry division ."***WORD: the ***
# Is
# ""singh was commissioned into ***the*** 2nd battalion of the rajput regiment in 1978 ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""we have posted other auction records ( ***on*** art , for example ) ."***WORD: on ***
# Is
# ""watson ***on*** the play of the hand at contract bridge by louis h ."***WORD: on ***
#  ==========================================
#
# The closest vector to
# ""strong support experienced member , often reverts ***vandalism*** and beats me to it ."***WORD: vandalism ***
# Is
# ""all of the prisoners were rescued , some reportedly showing signs of ***torture*** ."***WORD: torture ***
#  ==========================================
#
# The closest vector to
# ""finalists and acting nominations for the 2011 derby city film festival ***announced*** '' ."***WORD: announced ***
# Is
# ""a new record , will still kill , has been ***announced*** for release ."***WORD: announced ***
#  ==========================================
#
# The closest vector to
# ""the play was adapted for tv by ***the*** australian broadcasting corporation in 1973 ."***WORD: the ***
# Is
# ""he received a phd in composition from ***the*** university of york in 1984 ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""the structure was separated from the ***city*** by a moat and a wall ."***WORD: city ***
# Is
# ""at the moment , the bus lanes are being built throughout the ***city*** ."***WORD: city ***
#  ==========================================
#
# The closest vector to
# ""in 11 appearances at the us open , he ***partnered*** 11 different players ."***WORD: partnered ***
# Is
# ""other escaped slaves ***joined*** various seminole bands as free members of the tribe ."***WORD: joined ***
#  ==========================================
#
# The closest vector to
# ""some ***of*** the keep arguments are weak , but some are reasonably strong ."***WORD: of ***
# Is
# ""some ***of*** the organizations are actually the youth wings of larger political parties ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""in december 2008 she suffered a very ***hard*** injury of her right knee ."***WORD: hard ***
# Is
# ""in december 2008 she suffered a ***very*** hard injury of her right knee ."***WORD: very ***
#  ==========================================
#
# The closest vector to
# ""i 'll come back later after others have had ***a*** chance to comment ."***WORD: a ***
# Is
# ""i do n't believe you are permitted to have ***a*** say in it ."***WORD: a ***
#  ==========================================
#
# The closest vector to
# ""in such a case it is quite uncommon to issue ***a*** 3rr block ."***WORD: a ***
# Is
# ""actually , i drafted ***a*** good bit of the text of that essay ."***WORD: a ***
#  ==========================================
#
# The closest vector to
# ""each year , it 's produced a ***limited*** number of limited edition pieces ."***WORD: limited ***
# Is
# ""each year , it 's produced a limited number of ***limited*** edition pieces ."***WORD: limited ***
#  ==========================================
#
# The closest vector to
# ""he died ***in*** the attempt , though , and was buried at sea ."***WORD: in ***
# Is
# ""he was killed ***in*** an aircraft crash near cairns on 7 march 1943 ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""the character herself ***would*** n't make a visual appearance until battlefield in 1989 ."***WORD: would ***
# Is
# ""this is an essay and ***would*** require a fundamental rewrite to be encyclopedic ."***WORD: would ***
#  ==========================================
#
# The closest vector to
# ""she was recognized for her outstanding research in 2004 with the thomas c ***.*** "***WORD: . ***
# Is
# ""he was elected lieutenant governor in 1982 as running mate of richard f ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""strong keep - most primary ***schools*** are not notable but this one is ."***WORD: schools ***
# Is
# ""different ***schools*** of painting are shown from the sixteenth to the twentieth centuries ."***WORD: schools ***
#  ==========================================
#
# The closest vector to
# ""he also participated at the 2004 summer olympics for his native asian country ***.*** "***WORD: . ***
# Is
# ""he made his debut in the chinese professional baseball league at age 23 ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# "" ***although*** the magazine ceased publication , another project is still being kept alive ."***WORD: although ***
# Is
# "" ***although*** he was successful in chicago , bennett decided to return to oregon ."***WORD: although ***
#  ==========================================
#
# The closest vector to
# ""okay , just to clarify ***one*** thing , it may have been unclear ."***WORD: one ***
# Is
# ""possible hoax , or at the least , something made up ***one*** day ."***WORD: one ***
#  ==========================================
#
# The closest vector to
# ""charles county , approximately from the confluence of the missouri ***and*** mississippi rivers ."***WORD: and ***
# Is
# ""hair that included stops in south carolina , georgia , tennessee ***and*** kentucky ."***WORD: and ***
#  ==========================================
#
# The closest vector to
# ""the prevailing peace and order remains the best argument for promoting ***the*** province ."***WORD: the ***
# Is
# ""iron and steel production were also central to the development of ***the*** town ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""the natives named the rocks , `` the devil 's stepping stones ***''*** ."***WORD: '' ***
# Is
# ""the sound of drums '' and `` last of the time lords ***''*** ."***WORD: '' ***
#  ==========================================
#
# The closest vector to
# ""i ***can*** see there is nothing of the sort in that article ) ."***WORD: can ***
# Is
# ""i may not know any ww2 author , but i ***can*** always search ."***WORD: can ***
#  ==========================================
#
# The closest vector to
# ""groundbreaking was april 20 , 2008 with construction to ***occur*** in three phases ."***WORD: occur ***
# Is
# ""often observed in spring , but can also ***occur*** in summer and autumn ."***WORD: occur ***
#  ==========================================
#
# The closest vector to
# ""for the same ***reasons*** that have been stated before in this perennial proposal ."***WORD: reasons ***
# Is
# ""rfa , after being opposed for the same ***reason*** in the first one ."***WORD: reason ***
#  ==========================================
#
# The closest vector to
# ""thousands of ***people*** protest against the ruling hamas party in the gaza strip ."***WORD: people ***
# Is
# ""many ***people*** seem to have strong opinions on the subject ( see e ."***WORD: people ***
#  ==========================================
# The closest vector to
# ""rbi in the series as the cardinals ***defeated*** the mets in seven games ."***WORD: defeated ***
# Is
# ""world series as the chicago white sox ***defeated*** the cubs in six games ."***WORD: defeated ***
#  ==========================================
#
# The closest vector to
# ""the dialogue in the scene ***was*** also taken directly from the original article ."***WORD: was ***
# Is
# ""the discussion ***was*** a about the synthesis of sources to advance a point ."***WORD: was ***
#  ==========================================
#
# The closest vector to
# ""it was ***the*** first full reunion for the student body in 20 years ."***WORD: the ***
# Is
# ""it was ***the*** first open cup tournament to be named after lamar hunt ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""it is a member of the international association of national public ***health*** institutes ."***WORD: health ***
# Is
# ""the challenge is a free campaign supported by national civic and ***health*** organizations ."***WORD: health ***
#  ==========================================
#
# The closest vector to
# ""he worked with youth orchestras including the ***national*** youth orchestra of great britain ."***WORD: national ***
# Is
# ""the ***national*** library of norway n y sites are integrated in the catalog ."***WORD: national ***
#  ==========================================
#
# The closest vector to
# ""she had recently graduated from university prior to ***her*** recruitment to the military ."***WORD: her ***
# Is
# ""following ***his*** stint at marvel he signed exclusively with dc comics in 2004 ."***WORD: his ***
#  ==========================================
#
# The closest vector to
# ""i hope to get an independent assessment on the additions i have made ***.*** "***WORD: . ***
# Is
# ""as for the last comment there , i am seeking an objective decision ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""the university of oregon awarded him their law meritorious service award in 1985 ***.*** "***WORD: . ***
# Is
# ""grace attended high school at macon 's windsor academy , graduating in 1977 ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""plus a ***number*** of people have stated that your editing style is problematic ."***WORD: number ***
# Is
# ""each year , it 's produced a limited ***number*** of limited edition pieces ."***WORD: number ***
#  ==========================================
#
# The closest vector to
# ""the warning was placed ***with*** the comment that it was my last warning ."***WORD: with ***
# Is
# ""the violin then joins the cello ***with*** a distorted version of the theme ."***WORD: with ***
#  ==========================================
#
# The closest vector to
# ""the only source given has a 2 sentence passing mention of the ***topic*** ."***WORD: topic ***
# Is
# ""each of these historians shed light on the ***topic*** from a different perspective ."***WORD: topic ***
#  ==========================================

# %% [markdown]
# ### Now, first apply the trained Siamese network to each vector, and recalculate closest vectors.

# %%
for v in vecs:
    transform(network, v)

subset = np.random.choice(vecs, size = subset_size)
print_closest_vectors(subset, vecs)
# Out:
# The closest vector to
# ""the ocean liner ran aground in the río grande do sul , ***brazil*** ."***WORD: brazil ***
# Is
# ""rock and roll ***people*** '' which is from the mind games sessions ) ."***WORD: people ***
#  ==========================================
#
# The closest vector to
# ""european or latin american destinations were even in the top ***ten*** for emigrants ."***WORD: ten ***
# Is
# ""he was buried in the grange cemetery , edinburgh , on ***22*** oct ."***WORD: 22 ***
#  ==========================================
#
# The closest vector to
# ""at the time the highway that would become route 32 was ***already*** present ."***WORD: already ***
# Is
# ""even if married in another state , it is ***not*** recognized within missouri ."***WORD: not ***
#  ==========================================
#
# The closest vector to
# ""the accompanying ***music*** video portrays jessica and lisa in a boarding school rebellion ."***WORD: music ***
# Is
# ""the ***stuff*** i have found has been dominated by ( 1 ) www ."***WORD: stuff ***
#  ==========================================
#
# The closest vector to
# ""opened on may 21 ***,*** 1978 , the station was originally known as ."***WORD: , ***
# Is
# ""at the 2006 census ***,*** its population was 157 , in 37 families ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# "" ***the*** first women 's european championship was held in denmark in july 1989 ."***WORD: the ***
# Is
# "" ***the*** master of science in administration was added in the winter of 1983 ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""it could just be like friendly , but ***have*** the different types available ."***WORD: have ***
# Is
# ""i have been doing it manually , but it ***is*** pretty time consuming ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""the first ***example*** remains awkward in the article , despite your recent changes ."***WORD: example ***
# Is
# ""this farming ***community*** has a history dating back to the american revolutionary war ."***WORD: community ***
#  ==========================================
#
# The closest vector to
# ""senate he was succeeded by another democrat , vincent ***harrington*** of sioux city ."***WORD: harrington ***
# Is
# ""i was the one added it within the article as a proper ***reference*** ."***WORD: reference ***
#  ==========================================
#
# The closest vector to
# ""they announced ***their*** reunion in 2009 , and have released a new album ."***WORD: their ***
# Is
# ""he presently does not have ***a*** website so the link should be removed ."***WORD: a ***
#  ==========================================
#
# The closest vector to
# ""most of his territory was annexed and became part of ***the*** bombay presidency ."***WORD: the ***
# Is
# "" ***the*** community support for the project was another key aspect of its success ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""he presently does not have a website so the link should be removed ***.*** "***WORD: . ***
# Is
# ""it is said the newspaper survived only because lincoln was a smart politician ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""it joins the kabul river a few ***miles*** below the city of kabul ."***WORD: miles ***
# Is
# ""murray in 1926 based on six cases of sudden death in young ***rabbits*** ."***WORD: rabbits ***
#  ==========================================
#
# The closest vector to
# ""it is not known well ***enough*** that it has made his wiki entry ."***WORD: enough ***
# Is
# ""plus a number of people have stated that your editing style ***is*** problematic ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""kathy , hidden behind the stage ***curtain*** , sings into a second one ."***WORD: curtain ***
# Is
# ""dont delete - you guys have any idea how popular this ***man*** is ."***WORD: man ***
#  ==========================================
#
# The closest vector to
# ""noble reopened the doors of the chateau ***theatre*** on july 1 , 1994 ."***WORD: theatre ***
# Is
# ""the proximity of memphis the capital and seat of ***power*** at the time ."***WORD: power ***
#  ==========================================
#
# The closest vector to
# ""i want the board to get a more direct link to these communities ***.*** "***WORD: . ***
# Is
# ""if they lack interest , they will not vote by their own choice ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""perry was called to the bar in 1980 and took silk ***in*** 2006 ."***WORD: in ***
# Is
# ""the baltimore colts ran a version of the play ***in*** december , 1970 ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""soviets , others from the ***same*** school class fighting for the nazi germans ."***WORD: same ***
# Is
# ""this sandstone library follows the ***earlier*** library plan austin developed at dwight hall ."***WORD: earlier ***
#  ==========================================
#
# The closest vector to
# ""december 1910 ) was ***a*** german explorer and governor of german east africa ."***WORD: a ***
# Is
# ""he even stops going to school and become ***a*** slave to his mother ."***WORD: a ***
#  ==========================================
#
# The closest vector to
# ""september 1998 ***,*** ( preview of subscription content ) and the 11 p ."***WORD: , ***
# Is
# ""at the end of october ***,*** wichita was assigned to task group 34 ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# "" ***w*** meridian , provides senegal with her first geological maps at this scale ."***WORD: w ***
# Is
# ""income tax ( building societies ) ( audit ***powers*** ) regulations 1992 s ."***WORD: powers ***
#  ==========================================
#
# The closest vector to
# ""soviets , others from the same school class fighting for the nazi ***germans*** ."***WORD: germans ***
# Is
# ""murray in 1926 based on six cases of sudden death in young ***rabbits*** ."***WORD: rabbits ***
#  ==========================================
#
# The closest vector to
# ""i suspect that implied in ***the*** question ) focus on work in mainspace ."***WORD: the ***
# Is
# "" ***the*** community support for the project was another key aspect of its success ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""the album became michaels highest charting solo album to ***date*** peaking at no ."***WORD: date ***
# Is
# ""it is the most popular kernel function used in support vector machine ***classification*** ."***WORD: classification ***
#  ==========================================
#
# The closest vector to
# ""i hope she wants to do it almost ***as*** much as i do ."***WORD: as ***
# Is
# ""sorry , i ca n't help ***as*** i am not a mac user ."***WORD: as ***
#  ==========================================
#
# The closest vector to
# ""trains will reach top speeds of 250 kilometres per hour on ***this*** line ."***WORD: this ***
# Is
# ""tracks 5 , 7 and 10 are from ***the*** album beneath the remains ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""nc 104 ends ***at*** nc 103 without as much as a guide sign ."***WORD: at ***
# Is
# ""there are also extant portions of commentaries ***on*** the gospels from his pen ."***WORD: on ***
#  ==========================================
#
# The closest vector to
# ""the ***program*** continues to be shown in major cities throughout the united states ."***WORD: program ***
# Is
# ""founded in 1973 , the ***school*** has incorporated the educational philosophy of st ."***WORD: school ***
#  ==========================================
#
# The closest vector to
# ""but any other comments about the images , organization , accessibility , ***etc*** ."***WORD: etc ***
# Is
# ""keep - this , however , ***is*** a horse of a different color ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""those are ***the*** best places to get some advice on starting out here ."***WORD: the ***
# Is
# ""that is why ***the*** 50 members should not directly represent the organizations notability ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""there is little or no ***percussion*** and rhythm is not a prominent element ."***WORD: percussion ***
# Is
# ""strong keep - most primary schools are not notable but this one ***is*** ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""payne was born in black rock , ***barbados*** , on 21 december 1948 ."***WORD: barbados ***
# Is
# ""rock and roll ***people*** '' which is from the mind games sessions ) ."***WORD: people ***
#  ==========================================
#
# The closest vector to
# ""william spencer and samuel browning first formed a ***partnership*** between 1778 and 1781 ."***WORD: partnership ***
# Is
# ""he was buried in the grange cemetery , edinburgh , on 22 ***oct*** ."***WORD: oct ***
#  ==========================================
#
# The closest vector to
# ""ants randy is plagued by an increasing stream of ants into his home ***.*** "***WORD: . ***
# Is
# ""they had come from places where they had already experienced and known humiliation ***.*** "***WORD: . ***
#  ==========================================
# The closest vector to
# ""you will have much more control with ***your*** linux box doing the routing ."***WORD: your ***
# Is
# ""it is clear ***my*** language is not that of a native french speaker ."***WORD: my ***
#  ==========================================
#
# The closest vector to
# ""but please be careful to record exactly where such ***ads*** were originally published ."***WORD: ads ***
# Is
# ""efforts are made to ensure laboratory safety ***videos*** are both relevant and engaging ."***WORD: videos ***
#  ==========================================
#
# The closest vector to
# ""titans of the ice age exhibition '' at the field museum in ***chicago*** ."***WORD: chicago ***
# Is
# ""it is the most popular kernel function used in support vector machine ***classification*** ."***WORD: classification ***
#  ==========================================
#
# The closest vector to
# ""the sparrow quartet is an american ***acoustic*** music group that formed in 2005 ."***WORD: acoustic ***
# Is
# ""it is possible that the video may not be ***officially*** released at all ."***WORD: officially ***
#  ==========================================
#
# The closest vector to
# ""if he can `` confess his sin '' , slater will stop ***killing*** ."***WORD: killing ***
# Is
# ""i do n't believe you ***are*** permitted to have a say in it ."***WORD: are ***
#  ==========================================
#
# The closest vector to
# ""following his stint at marvel he signed exclusively with dc comics in 2004 ***.*** "***WORD: . ***
# Is
# ""they had come from places where they had already experienced and known humiliation ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""founding fathers and the origins of gun ***control*** in america ( 2006 ) ."***WORD: control ***
# Is
# ""rock and roll ***people*** '' which is from the mind games sessions ) ."***WORD: people ***
#  ==========================================
#
# The closest vector to
# "" ***looks*** like it was split from censorship with just brazil and venezuela ( !"***WORD: looks ***
# Is
# ""strong keep - most primary schools are not notable but this one ***is*** ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""in 1994 , jack took hoover to court over the free ***flight*** promotion ."***WORD: flight ***
# Is
# ""although ***he*** was successful in chicago , bennett decided to return to oregon ."***WORD: he ***
#  ==========================================
#
# The closest vector to
# "" ***named*** by advisory committee on antarctic names ( us-acan ) for danny l ."***WORD: named ***
# Is
# ""when they did so , however , they ***were*** hampered by limited skills ."***WORD: were ***
#  ==========================================
#
# The closest vector to
# ""rewrite grammar nazi on the grounds that it is in ***extremely*** poor taste ."***WORD: extremely ***
# Is
# ""these designated levels are ***not*** standard but vary according to each organizations preference ."***WORD: not ***
#  ==========================================
#
# The closest vector to
# ""she thinks i ***'m*** crazy but i 'm just growing old '' ) ."***WORD: 'm ***
# Is
# ""i have been doing it manually , but it ***is*** pretty time consuming ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""you will have much more ***control*** with your linux box doing the routing ."***WORD: control ***
# Is
# ""strong support experienced member , often reverts ***vandalism*** and beats me to it ."***WORD: vandalism ***
#  ==========================================
#
# The closest vector to
# ""right thought i could solve this myself and have failed ***in*** epic proportions ."***WORD: in ***
# Is
# ""he was flying back to dublin after spending christmas ***in*** the slovak republic ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""he accused one of those two wikipedians of being ***on*** the kennedy payroll ."***WORD: on ***
# Is
# ""black canary offers her a spot ***on*** the new birds of prey roster ."***WORD: on ***
#  ==========================================
#
# The closest vector to
# ""the player ***strikes*** on this central area with a pair of bamboo sticks ."***WORD: strikes ***
# Is
# ""comment i think that ***it*** has a lot of potential as a list ."***WORD: it ***
#  ==========================================
#
# The closest vector to
# ""would someone please commit on ***the*** above question which relates to reference 8 ."***WORD: the ***
# Is
# ""i am ready to make an introduction at ***the*** category page to explain ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""it also describes the kind of humor a man like abraham lincoln ***had*** ."***WORD: had ***
# Is
# ""it is likely , however , that his performance ***was*** aided by drugs ."***WORD: was ***
#  ==========================================
#
# The closest vector to
# ""the result was speedy delete a7 , group ***with*** no assertion of notability ."***WORD: with ***
# Is
# ""you go the other way ***to*** turn those characters into the original data ."***WORD: to ***
#  ==========================================
#
# The closest vector to
# ""they only contain ***a*** portion of the healthy nutrients which we know about ."***WORD: a ***
# Is
# ""i am sure that lucius sweet can not be considered ***a*** one-time character ."***WORD: a ***
#  ==========================================
#
# The closest vector to
# ""a small brick waiting shelter was provided for ***passengers*** using the up platform ."***WORD: passengers ***
# Is
# ""murray in 1926 based on six cases of sudden death in young ***rabbits*** ."***WORD: rabbits ***
#  ==========================================
#
# The closest vector to
# ""public ***transport*** to , from and throughout the area is provided by bus ."***WORD: transport ***
# Is
# ""rock and roll ***people*** '' which is from the mind games sessions ) ."***WORD: people ***
#  ==========================================
#
# The closest vector to
# ""da silva then moved to italy in 1991 where he played for u ***.*** "***WORD: . ***
# Is
# ""he was terrified of death and had never been sick in his life ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""soviets , others ***from*** the same school class fighting for the nazi germans ."***WORD: from ***
# Is
# ""the baltimore colts ran a version of the play ***in*** december , 1970 ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""actually , i drafted a good bit of the text of that essay ***.*** "***WORD: . ***
# Is
# ""they immediately gave him the full ten points because they needed more musicians ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""these terminal applications usually also support manual entry ***of*** the credit card number ."***WORD: of ***
# Is
# ""but i think this reflects a perception ***of*** the arbcom as a court ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""february 27 , 1859 , bonn ) ***,*** german was a biblical scholar ."***WORD: , ***
# Is
# ""at the end of october ***,*** wichita was assigned to task group 34 ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# ""repetition occurs many times in this poem , for ***example*** `` o captain !"***WORD: example ***
# Is
# ""hair that included stops in south carolina , ***georgia*** , tennessee and kentucky ."***WORD: georgia ***
#  ==========================================
#
# The closest vector to
# ""the master of science in administration was added in the winter ***of*** 1983 ."***WORD: of ***
# Is
# ""the war began with the landing of nine hundred military advisors ***in*** saigon ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""i ***was*** the one added it within the article as a proper reference ."***WORD: was ***
# Is
# ""i figured out that i ***was*** tired of helping others make their art ."***WORD: was ***
#  ==========================================
#
# The closest vector to
# ""efforts to rebuild the niagara were ***hampered*** by the lack of original plans ."***WORD: hampered ***
# Is
# ""i brought it up in the talk pages but it was n't ***resolved*** ."***WORD: resolved ***
#  ==========================================
#
# The closest vector to
# ""it was founded over 100 years ago ***and*** has more than 700 employees ."***WORD: and ***
# Is
# ""eight teams take part ***and*** the competition is composed of a single league ."***WORD: and ***
#  ==========================================
#
# The closest vector to
# ""until these issues are ***addressed*** , the article can not meet ga standards ."***WORD: addressed ***
# Is
# ""whether it is a list or not ***is*** left to you to decide ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""wikipedia bases itself off of ***the*** idea that anyone is free to edit ."***WORD: the ***
# Is
# "" ***the*** community support for the project was another key aspect of its success ."***WORD: the ***
#  ==========================================
# The closest vector to
# ""hello , ***i*** 'm looking for information on a ship named hms joanna ."***WORD: i ***
# Is
# ""i have been doing it manually , but ***it*** is pretty time consuming ."***WORD: it ***
#  ==========================================
#
# The closest vector to
# ""the park in its current state ***was*** opened to the public in 1956 ."***WORD: was ***
# Is
# ""in narrative sequence it ***is*** preceded by point of impact and black light ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""canada for its ***beauty*** , natural landscape , and strong sense of community ."***WORD: beauty ***
# Is
# ""it is the most popular kernel function used in support vector machine ***classification*** ."***WORD: classification ***
#  ==========================================
#
# The closest vector to
# ""joe is a technician aboard the toronto and ***a*** good friend of tom ."***WORD: a ***
# Is
# ""he even stops going to school and become ***a*** slave to his mother ."***WORD: a ***
#  ==========================================
#
# The closest vector to
# ""to me the meaning is very clear that there is no ***fixed*** pattern ."***WORD: fixed ***
# Is
# ""it is possible that the video may not be ***officially*** released at all ."***WORD: officially ***
#  ==========================================
#
# The closest vector to
# ""there exists also a provincial electoral district of a ***similar*** name ( st ."***WORD: similar ***
# Is
# ""it is a ***unique*** creative vision of a small isolated group of individuals ."***WORD: unique ***
#  ==========================================
#
# The closest vector to
# ""on 4 september , recording moves again , this time ***to*** cherokee studios ."***WORD: to ***
# Is
# ""user space is not intended ***to*** indefinitely archive pages of previously deleted content ."***WORD: to ***
#  ==========================================
#
# The closest vector to
# ""the composition ***of*** julian 's army at strasbourg can only be partially reconstructed ."***WORD: of ***
# Is
# ""i do not think this treatment ***of*** davis reflects well on this project ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""yes , so ***long*** as the whole thing is in air tight containers ."***WORD: long ***
# Is
# ""i have been doing it manually , but it ***is*** pretty time consuming ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""flying '' ) ***,*** describing an additional special ability or special scoring opportunity ."***WORD: , ***
# Is
# ""welding allows a large sculpture to be cast in pieces ***,*** then joined ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# ""the first example remains awkward in the article , despite ***your*** recent changes ."***WORD: your ***
# Is
# ""it is clear ***my*** language is not that of a native french speaker ."***WORD: my ***
#  ==========================================
#
# The closest vector to
# ""named by advisory committee on antarctic names ( us-acan ) for danny ***l*** ."***WORD: l ***
# Is
# ""evans , partial differential equations , american mathematical society , ***providence*** , 1998 ."***WORD: providence ***
#  ==========================================
#
# The closest vector to
# ""in recent years the mcc was generating enough money to support the ***school*** ."***WORD: school ***
# Is
# ""after the ***glacier*** melted , the illinois river flowed into the ancient channel ."***WORD: glacier ***
#  ==========================================
#
# The closest vector to
# ""the greek pov is insisting on unique treatment for the republic of macedonia ***.*** "***WORD: . ***
# Is
# ""the larvae are pale green with a broad black line along each side ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""broadcasts can vary in length , anything from 90 minutes to 3 hours ***.*** "***WORD: . ***
# Is
# ""the larvae are pale green with a broad black line along each side ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""seven sisters ( ***queensland*** ) ( talk ) unassessed-class ( no-class ) added ."***WORD: queensland ***
# Is
# ""although ***he*** was successful in chicago , bennett decided to return to oregon ."***WORD: he ***
#  ==========================================
#
# The closest vector to
# "" ***the*** waters of the pacific ocean then carried the body out to sea ."***WORD: the ***
# Is
# "" ***the*** tang chinese had recruited many central asian turks into their armed forces ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# "" ***iron*** and steel production were also central to the development of the town ."***WORD: iron ***
# Is
# ""the new girl ***brooke*** moves to sweet valley , and everyone hates her ."***WORD: brooke ***
#  ==========================================
#
# The closest vector to
# ""there used to be a post office which was ***previously*** a police barracks ."***WORD: previously ***
# Is
# ""it was never released to the public and is ***not*** available for reading ."***WORD: not ***
#  ==========================================
#
# The closest vector to
# "" ***most*** reef fishes have body shapes that are different from open water fishes ."***WORD: most ***
# Is
# ""it ***is*** also stated on-screen before purchase that not all boxes are compatible ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""some of the keep arguments ***are*** weak , but some are reasonably strong ."***WORD: are ***
# Is
# ""i have been doing it manually , but it ***is*** pretty time consuming ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""the assertion about mineral water in the ***pool*** , is of no importance ."***WORD: pool ***
# Is
# ""in the north wall of the ***chancel*** is a single narrow pointed window ."***WORD: chancel ***
#  ==========================================
#
# The closest vector to
# ""efforts are made to ensure laboratory ***safety*** videos are both relevant and engaging ."***WORD: safety ***
# Is
# ""efforts are made to ensure laboratory safety ***videos*** are both relevant and engaging ."***WORD: videos ***
#  ==========================================
#
# The closest vector to
# ""the main purpose of ***the*** game is control as many locations as possible ."***WORD: the ***
# Is
# "" ***the*** amount of time you spend at the reference desk is quite interesting ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""president of the united states for 11 hours of broadcast per ***working*** week ."***WORD: working ***
# Is
# ""species in this family range in body length from about ***four*** to 8 ."***WORD: four ***
#  ==========================================
#
# The closest vector to
# ""until a few days ago , ***i*** even thought he was an admin ."***WORD: i ***
# Is
# "" ***he*** had no where to go with virtually no money in his pocket ."***WORD: he ***
#  ==========================================
#
# The closest vector to
# ""i found no reliable and independent sources that show this organization is ***notable*** ."***WORD: notable ***
# Is
# ""strong keep - most primary schools are not ***notable*** but this one is ."***WORD: notable ***
#  ==========================================
#
# The closest vector to
# ""actually , i drafted a good bit of the text of that essay ***.*** "***WORD: . ***
# Is
# ""they immediately gave him the full ten points because they needed more musicians ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""signs in the abandoned station also state `` museum '' as the ***name*** ."***WORD: name ***
# Is
# ""the ***town*** covered an area of , and existed from 1954 until 1994 ."***WORD: town ***
#  ==========================================
#
# The closest vector to
# ""notable ***enough*** for our purposes means receiving significant coverage in reliable secondary sources ."***WORD: enough ***
# Is
# ""i have been doing it manually , but it ***is*** pretty time consuming ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""the amount of time you spend at the ***reference*** desk is quite interesting ."***WORD: reference ***
# Is
# "" ***that*** quote could be used as an example for what wp is not ."***WORD: that ***
#  ==========================================
#
# The closest vector to
# "" ***he*** plays the title character in the 2013 feature film the lone ranger ."***WORD: he ***
# Is
# ""although ***he*** was successful in chicago , bennett decided to return to oregon ."***WORD: he ***
#  ==========================================
#
# The closest vector to
# ""its duration was 90 minutes and its ***premiere*** occurred on 1 december 2002 ."***WORD: premiere ***
# Is
# ""strong keep - most primary schools are not notable but this ***one*** is ."***WORD: one ***
#  ==========================================
#
# The closest vector to
# ""it is also stated on-screen before ***purchase*** that not all boxes are compatible ."***WORD: purchase ***
# Is
# ""evans , partial differential equations , american mathematical society , ***providence*** , 1998 ."***WORD: providence ***
#  ==========================================
#
# The closest vector to
# ""the sisters ***of*** providence in the pacific northwest established providence hospital in 1905 ."***WORD: of ***
# Is
# ""there are also extant portions ***of*** commentaries on the gospels from his pen ."***WORD: of ***
#  ==========================================
#
# The closest vector to
# ""looks like ***it*** was split from censorship with just brazil and venezuela ( !"***WORD: it ***
# Is
# ""i brought it up in the talk pages but ***it*** was n't resolved ."***WORD: it ***
#  ==========================================
# The closest vector to
# ""signs in the abandoned station also state `` museum '' as the ***name*** ."***WORD: name ***
# Is
# ""the ***town*** covered an area of , and existed from 1954 until 1994 ."***WORD: town ***
#  ==========================================
#
# The closest vector to
# ""a procession also ***took*** place in the honor of the temple of heaven ."***WORD: took ***
# Is
# ""germans were suffering also and they naturally ***gave*** priority to their own suffering ."***WORD: gave ***
#  ==========================================
#
# The closest vector to
# "" ***in*** 1976 he turned professional and won a national title in the sprint ."***WORD: in ***
# Is
# ""he served as a color analyst on chargers radio broadcasts ***in*** the 1970s ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""no ***,*** but you can choose whether the water 's brown or blue ."***WORD: , ***
# Is
# ""upon reaching the village ***,*** they discover that the village has moved on ."***WORD: , ***
#  ==========================================
#
# The closest vector to
# ""it is not known well enough that it has made his wiki entry ***.*** "***WORD: . ***
# Is
# ""it is said the newspaper survived only because lincoln was a smart politician ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# "" ***if*** there is another plausible explanations , i would like to hear it ."***WORD: if ***
# Is
# ""i have been doing it manually , but ***it*** is pretty time consuming ."***WORD: it ***
#  ==========================================
#
# The closest vector to
# ""once more , however , he was not selected for the ***world*** cup ."***WORD: world ***
# Is
# ""the ***main*** ( west ) facade is five bays with a central doorway ."***WORD: main ***
#  ==========================================
#
# The closest vector to
# ""he attacked the bowling immediately , [ ***8*** ] sharing a large partnership ."***WORD: 8 ***
# Is
# ""roberts , kate ( ***2001*** ) , sun and storm and other stories ."***WORD: 2001 ***
#  ==========================================
#
# The closest vector to
# ""our ball state course students have been coordinating their topic proposals ***with*** me ."***WORD: with ***
# Is
# ""he was flying back to dublin after spending christmas ***in*** the slovak republic ."***WORD: in ***
#  ==========================================
#
# The closest vector to
# ""you can change the username and ***have*** user and user talk pages deleted ."***WORD: have ***
# Is
# ""dont delete - you guys ***have*** any idea how popular this man is ."***WORD: have ***
#  ==========================================
#
# The closest vector to
# ""perhaps your reason for being in this discussion ***is*** simply a personal attack ."***WORD: is ***
# Is
# ""i have been doing it manually , but it ***is*** pretty time consuming ."***WORD: is ***
#  ==========================================
#
# The closest vector to
# ""the final decision was taken on the uefa meeting on 13 may 2009 ***.*** "***WORD: . ***
# Is
# ""they had come from places where they had already experienced and known humiliation ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# ""he served in ***the*** vermont senate from 1851 to 1852 was senate president ."***WORD: the ***
# Is
# "" ***the*** tang chinese had recruited many central asian turks into their armed forces ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""the village was enhanced in june ***2005*** by the addition of a pharmacy ."***WORD: 2005 ***
# Is
# ""cyclone justin was the largest tropical cyclone to hit northern queensland in ***1997*** ."***WORD: 1997 ***
#  ==========================================
#
# The closest vector to
# ""hence the material in ***the*** discussions section and the appeal for more information ."***WORD: the ***
# Is
# "" ***the*** birds of the gambia ( 2nd edition , 1991 ) by m ."***WORD: the ***
#  ==========================================
#
# The closest vector to
# ""seven months following the murder of phil , the liquor license was sold ***.*** "***WORD: . ***
# Is
# ""they had come from places where they had already experienced and known humiliation ***.*** "***WORD: . ***
#  ==========================================
#
# The closest vector to
# "" ***game*** machines were installed in many department stores and children 's play areas ."***WORD: game ***
# Is
# ""the first ***people*** 's summit was held in santiago , chile in 1998 ."***WORD: people ***
#  ==========================================
