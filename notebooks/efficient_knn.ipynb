# %%
from scipy import spatial
import gensim
import random

# %%
model = gensim.models.KeyedVectors.load_word2vec_format(
    '../generate_dataset/resources/GoogleNews-vectors-negative300.bin', binary=True)

# %%
model.vectors
# Out:
# array([[ 1.1291504e-03, -8.9645386e-04,  3.1852722e-04, ...,
#         -1.5640259e-03, -1.2302399e-04, -8.6307526e-05],
#        [ 7.0312500e-02,  8.6914062e-02,  8.7890625e-02, ...,
#         -4.7607422e-02,  1.4465332e-02, -6.2500000e-02],
#        [-1.1779785e-02, -4.7363281e-02,  4.4677734e-02, ...,
#          7.1289062e-02, -3.4912109e-02,  2.4169922e-02],
#        ...,
#        [-1.9653320e-02, -9.0820312e-02, -1.9409180e-02, ...,
#         -1.6357422e-02, -1.3427734e-02,  4.6630859e-02],
#        [ 3.2714844e-02, -3.2226562e-02,  3.6132812e-02, ...,
#         -8.8500977e-03,  2.6977539e-02,  1.9042969e-02],
#        [ 4.5166016e-02, -4.5166016e-02, -3.9367676e-03, ...,
#          7.9589844e-02,  7.2265625e-02,  1.3000488e-02]], dtype=float32)

# %%
embeddings = spatial.KDTree(model.vectors)

# %%
distance, indices = embeddings.query(model.vectors[2], k=5)

# %%
random.choice(indices)
# Out:
# 2

# %%
len(list(model.vocab))
# Out:
# 3000000

# %%
model.vectors[0]
# Out:
# array([ 1.1291504e-03, -8.9645386e-04,  3.1852722e-04,  1.5335083e-03,
#         1.1062622e-03, -1.4038086e-03, -3.0517578e-05, -4.1961670e-04,
#        -5.7601929e-04,  1.0757446e-03, -1.0223389e-03, -6.1798096e-04,
#        -7.5531006e-04,  1.4038086e-03, -1.6403198e-03, -6.3323975e-04,
#         1.6326904e-03, -1.0070801e-03, -1.2664795e-03,  6.5231323e-04,
#        -4.1580200e-04, -1.0757446e-03,  1.5258789e-03, -2.7465820e-04,
#         1.4019012e-04,  1.5716553e-03,  1.3580322e-03, -8.3160400e-04,
#        -1.4038086e-03,  1.5792847e-03,  2.5367737e-04, -7.3242188e-04,
#        -1.0538101e-04, -1.1672974e-03,  1.5792847e-03,  6.5612793e-04,
#        -6.5994263e-04,  2.9206276e-06,  1.1291504e-03,  4.2724609e-04,
#        -3.7002563e-04, -1.1520386e-03,  1.2664795e-03, -3.5166740e-06,
#         2.6512146e-04, -4.0245056e-04,  1.4114380e-04, -3.3617020e-05,
#         7.5912476e-04, -5.1879883e-04, -7.1048737e-05,  6.0272217e-04,
# ...

# %%
options = self.embeddings.most_similar(positive = [w], topn = self.topn)
replacement, _ = random.choice(options)
