# %%
import numpy as np
import termcolor

# %%
def load_data(fname = "data.sample.txt"):
    
    with open(fname, "r") as f:
        
        lines = f.readlines()
    
    data = []
    
    for line in lines:
        
        index, sent1, sent2, _, _, label = line.strip().split("\t")
        index, label = int(index.split(".")[0]), int(label)
        sent1, sent2 = sent1.split(" "), sent2.split(" ")
        if sent1 == sent2: continue
        data.append((sent1, sent2, index, label))
        
    return data

def display_example(example):
    
    sent1, sent2, index, label = example
    color = "blue" if label == 1 else "red"
    
    sent1_before = sent1[:index]
    sent2_before = sent2[:index]
    sent1_after = sent1[index + 1:]
    sent2_after = sent2[index + 1:]
    
    w1 = "***" + termcolor.colored(sent1[index], color) + "***"
    w2 =  "***" + termcolor.colored(sent2[index], color) +  "***"
    
    sent1_str = " ".join(sent1_before) + " " + w1 + " " + " ".join(sent1_after)
    sent2_str = " ".join(sent2_before) + " " + w2 + " " + " ".join(sent2_after)
    
    s = "Label: {}\n".format(label) + sent1_str + "\n" + sent2_str + "\n==================================================\n"
    print(s)

# %%
data = load_data()
for example in data:
    display_example(example)
# Out:
# Label: 1
# statement of much titles , ***honor*** writer , bus earth , near quality .
# defense of appropriate claims , ***everything*** size , war influence , near wall .
# ==================================================
#
# Label: 1
# road of ***delete*** criteria , land east , texas emergency , near site .
# television of ***official*** powers , rank none , planning person , near value .
# ==================================================
#
# Label: 0
# statement of much titles , honor writer , bus earth ***,*** near quality .
# the opposition of the success was retained on the global ***respect*** on the decade in one .
# ==================================================
#
# Label: 0
# television of official powers , rank none ***,*** planning person , near value .
# the name of the prize was retained ***on*** the january senate on the religion in 27 .
# ==================================================
#
# Label: 0
# defense of appropriate claims , ***everything*** size , war influence , near wall .
# the area of the round ***was*** retained on the french category on the change in 1964 .
# ==================================================
#
# Label: 0
# statement of much titles , honor writer , bus earth , near ***quality*** .
# the name of the prize was retained on the january senate on ***the*** religion in 27 .
# ==================================================
#
# Label: 1
# it proved chief , and by 1951 was already seeing 500 , 1970 representatives a ***degree*** .
# it proved green , and by 1979 was already seeing 1976 , 1965 individuals a ***november*** .
# ==================================================
#
# Label: 1
# it proved ***chief*** , and by 1951 was already seeing 500 , 1970 representatives a degree .
# it proved ***popular*** , and by 1957 was already seeing 37 , 000 movements a year .
# ==================================================
#
# Label: 1
# it proved green , and by 1979 was ***already*** seeing 1976 , 1965 individuals a november .
# it proved chief , and by 1951 was ***already*** seeing 500 , 1970 representatives a degree .
# ==================================================
#
# Label: 0
# it proved brown , and ***by*** 1987 was already seeing 28 , 1918 elements a analysis .
# no evidence ideas are known ***from*** success as there are n't any length lists of the standard committee to preserve them .
# ==================================================
#
# Label: 0
# it proved brown , and by 1987 was already seeing 28 , 1918 elements a ***analysis*** .
# no list personnel are known from stage as there are n't any north states of ***the*** critical daughter to preserve them .
# ==================================================
#
# Label: 0
# it proved chief , and by 1951 was already seeing 500 ***,*** 1970 representatives a degree .
# no evidence ideas are known from success as there are n't ***any*** length lists of the standard committee to preserve them .
# ==================================================
#
# Label: 0
# it proved ***popular*** , and by 1957 was already seeing 37 , 000 movements a year .
# no cricket ***episodes*** are known from town as there are n't any newspaper positions of the social charge to preserve them .
# ==================================================
#
# Label: 1
# the charles are rural fields data that aim ***to*** give bachelor to the user 's most executive armed goals .
# the prizes are visual arts competitions that aim ***to*** give recognition to the region 's most exciting contemporary artists .
# ==================================================
#
# Label: 1
# the episodes are nice levels lines that aim to give child to the machine 's most ***grand*** atlantic courts .
# the charles are rural fields data that aim to give bachelor to the user 's most ***executive*** armed goals .
# ==================================================
#
# Label: 1
# the charles are rural fields data that aim to give bachelor to the ***user*** 's most executive armed goals .
# the letters are later children categories that aim to give rest to the ***creation*** 's most simple personal goals .
# ==================================================
#
# Label: 0
# the charles are rural fields data that aim to give bachelor to the user 's most executive armed ***goals*** .
# discussions , season order , the basketball tag on fair and free charles , and the light son ***group*** population .
# ==================================================
#
# Label: 0
# the charles are rural fields data that aim to give bachelor to the user 's most ***executive*** armed goals .
# discussions , season order , the basketball tag on fair and free charles , and the ***light*** son group population .
# ==================================================
#
# Label: 0
# the ***episodes*** are nice levels lines that aim to give child to the machine 's most grand atlantic courts .
# studies ***,*** train standard , the downtown north on external and 1st lives , and the 3rd boy police screen .
# ==================================================
#
# Label: 0
# the letters are later children categories that aim to give rest to the ***creation*** 's most simple personal goals .
# studies , train standard , the downtown north on external and 1st lives ***,*** and the 3rd boy police screen .
# ==================================================
#
# Label: 1
# palau makes a edit of staying out of guidelines , refusing to endorse topic 1970s ***or*** countries .
# palau makes a press of staying out of resources , refusing to endorse bit institutions ***or*** levels .
# ==================================================
#
# Label: 1
# palau makes a damage of ***staying*** out of companies , refusing to endorse town 1980s or miles .
# palau makes a edit of ***staying*** out of guidelines , refusing to endorse topic 1970s or countries .
# ==================================================
#
# Label: 1
# palau makes a press of staying out of resources , refusing to ***endorse*** bit institutions or levels .
# palau makes a damage of staying out of companies , refusing to ***endorse*** town 1980s or miles .
# ==================================================
#
# Label: 0
# palau makes a edit of staying out ***of*** guidelines , refusing to endorse topic 1970s or countries .
# during the 1970s , 1980s , and ***beyond*** , exploring continued to offer the national explorer conferences and the law enforcement explorer conferences , as well as unique programs like the explorer mock trial competition .
# ==================================================
#
# Label: 0
# palau makes a press of staying out of resources , refusing to endorse bit institutions or levels ***.***
# during the representatives , 1966 , and beyond , exploring continued to offer the traditional expansion attacks ***and*** the chairman tour attack projects , as well as formal children like the glass eastern range status .
# ==================================================
#
# Label: 0
# palau makes ***a*** press of staying out of resources , refusing to endorse bit institutions or levels .
# during the ***1970s*** , 1980s , and beyond , exploring continued to offer the national explorer conferences and the law enforcement explorer conferences , as well as unique programs like the explorer mock trial competition .
# ==================================================
#
# Label: 0
# palau makes a point of staying out of politics , ***refusing*** to endorse ballot measures or candidates .
# during the arts , 2008 , and beyond , exploring ***continued*** to offer the important germany actions and the period building storm things , as well as french reasons like the prison official damage property .
# ==================================================
#
# Label: 1
# a century before that , during the 15th century , the three colours were mentioned as the coastal signals for this area , with the ***3*** bands straight or diagonal , single or doubled .
# a date before that , during the big year , the 27 numbers were mentioned as the pacific sports for this island , with the ***1953*** championships grand or huge , scientific or doubled .
# ==================================================
#
# Label: 1
# a date ***before*** that , during the big year , the 27 numbers were mentioned as the pacific sports for this island , with the 1953 championships grand or huge , scientific or doubled .
# a request ***before*** that , during the public term , the 100 letters were mentioned as the able 1960s for this position , with the 1951 elements commercial or fifth , personal or doubled .
# ==================================================
#
# Label: 1
# a japan before that , during the legislative road , the nine records were mentioned as the uk nations for this faith , ***with*** the 1980 pages entire or little , middle or doubled .
# a request before that , during the public term , the 100 letters were mentioned as the able 1960s for this position , ***with*** the 1951 elements commercial or fifth , personal or doubled .
# ==================================================
#
# Label: 0
# a japan before ***that*** , during the legislative road , the nine records were mentioned as the uk nations for this faith , with the 1980 pages entire or little , middle or doubled .
# the formal register ***moved*** into his atlantic persons in the television of 2009 , and in energy 5 , the primary red election graduated .
# ==================================================
#
# Label: 0
# a century before that , during the 15th century , the three colours were mentioned as the coastal signals ***for*** this area , with the 3 bands straight or diagonal , single or doubled .
# the high school moved into its new quarters in the spring of 1999 , and in june 2000 , ***the*** first twelfth grade graduated .
# ==================================================
#
# Label: 0
# a price before that , during the active navy , the ***1970*** criteria were mentioned as the controversial leaders for this head , with the 1998 tracks ancient or environmental , canadian or doubled .
# the high school moved into its new quarters in the spring ***of*** 1999 , and in june 2000 , the first twelfth grade graduated .
# ==================================================
#
# Label: 0
# a century before that , during the 15th century , the three colours were ***mentioned*** as the coastal signals for this area , with the 3 bands straight or diagonal , single or doubled .
# the high school moved into its new quarters in the spring of 1999 , ***and*** in june 2000 , the first twelfth grade graduated .
# ==================================================
#
# Label: 1
#  ***on*** google 2013 , he signed a 20th airport plant with the george members , but would be released less than a state later .
#  ***on*** july 17 , he signed a minor league contract with the pittsburgh pirates , but would be released less than a month later .
# ==================================================
#
# Label: 0
# on google ***2013*** , he signed a 20th airport plant with the george members , but would be released less than a state later .
# sorry , ***let*** me take the opportunity to say i too assume good faith .
# ==================================================
#
# Label: 0
# on july ***1947*** , he signed a limited english security with the east films , but would be released less than a wikipedia later .
# sorry , ***let*** me take the edge to say i too assume middle general .
# ==================================================
#
# Label: 0
# on google 2013 , he signed ***a*** 20th airport plant with the george members , but would be released less than a state later .
# sorry , let me take the ***opportunity*** to say i too assume good faith .
# ==================================================
#
# Label: 0
# on july 1947 , he ***signed*** a limited english security with the east films , but would be released less than a wikipedia later .
# sorry , let me take ***the*** opportunity to say i too assume good faith .
# ==================================================
#
# Label: 1
# commander also uses wing famous when one goes to click to add a girl or when browsing the ***object*** .
# mexico also uses leader conservative when one goes to click to add a tennis or when browsing the ***russia*** .
# ==================================================
#
# Label: 1
# commander also uses wing famous when one goes to click to add a girl or when browsing the ***object*** .
# boston also uses deal physical when one goes to click to add a power or when browsing the ***risk*** .
# ==================================================
#
# Label: 0
#  ***highway*** also uses application soviet when one goes to click to add a airport or when browsing the field .
#  ***countdown*** to the crown was a reality series that followed the miss america beauty pageant contestants in the time period leading up to the 2009 pageant .
# ==================================================
#
# Label: 0
# boston also uses deal physical when one goes to click to add a power or when ***browsing*** the risk .
# river to the saint was a matter school that followed the independence turn box virginia elections ***in*** the engine card leading up to the 8 retirement .
# ==================================================
#
# Label: 0
# highway ***also*** uses application soviet when one goes to click to add a airport or when browsing the field .
# river ***to*** the saint was a matter school that followed the independence turn box virginia elections in the engine card leading up to the 8 retirement .
# ==================================================
#
# Label: 0
# highway also uses application soviet when one goes to click to add a airport or ***when*** browsing the field .
# scotland to the capital was a california novel that followed the month construction robert soccer ***votes*** in the television exchange leading up to the 2012 russia .
# ==================================================
#
# Label: 1
# this resolved encyclopedia 's garden for all but a royal safety ***of*** studies .
# this resolved course 's hall for all but a relevant johnson ***of*** operations .
# ==================================================
#
# Label: 0
# this resolved course 's hall for all but a relevant johnson of operations ***.***
# the st reached a country of fans at a valley over ( where ***it*** should have been traveling at ) , and derailed .
# ==================================================
#
# Label: 0
# this resolved encyclopedia 's garden for all but a royal ***safety*** of studies .
# the mary reached a camp of leaders at a communication ***over*** ( where it should have been traveling at ) , and derailed .
# ==================================================
#
# Label: 0
#  ***this*** resolved rock 's amount for all but a august grade of facilities .
#  ***the*** sentence reached a history of purposes at a research over ( where it should have been traveling at ) , and derailed .
# ==================================================
#
# Label: 0
# this resolved rock 's amount for all but a august ***grade*** of facilities .
# the case reached a reason of 1960s at a teacher ***over*** ( where it should have been traveling at ) , and derailed .
# ==================================================
#
# Label: 1
# i 've done about as much as i can on this for ***now*** and would like some comments on possible improvements .
# i 've done about as external as i can on this for ***now*** and would like some activities on online children .
# ==================================================
#
# Label: 0
# i 've done about as much as ***i*** can on this for now and would like some comments on possible improvements .
# after one season , he would move ***to*** the nfl where he served as head coach of the houston oilers for the 1984 and 1985 seasons .
# ==================================================
#
# Label: 0
# i 've done about as formal as i can on this for now and would like some countries on human ***names*** .
# after 1962 student , he would move to the today where he served as glass aircraft of the release operations ***for*** the two and 1986 tracks .
# ==================================================
#
# Label: 0
# i 've done about as formal as i can on this ***for*** now and would like some countries on human names .
# after 17 egypt , he would move to the africa where ***he*** served as construction june of the card houses for the 1985 and 13 reasons .
# ==================================================
#
# Label: 0
# i 've done about as whole as i can on this for now and would like some banks on ***correct*** areas .
# after one season , he would move to the nfl where he served as head coach of the houston ***oilers*** for the 1984 and 1985 seasons .
# ==================================================
#
# Label: 1
#  ***in*** 16 and in 7 he was awarded with the french exchange by the specific smith for the places appearance .
#  ***in*** 1920 and in 2004 he was awarded with the similar decade by the jewish view for the areas thing .
# ==================================================
#
# Label: 1
# in 1996 and ***in*** four he was awarded with the regular july by the utc kingdom for the awards census .
# in 1986 and ***in*** 1986 he was awarded with the regional paul by the brief route for the lives copyright .
# ==================================================
#
# Label: 1
# in ***1996*** and in four he was awarded with the regular july by the utc kingdom for the awards census .
# in ***1986*** and in 1986 he was awarded with the regional paul by the brief route for the lives copyright .
# ==================================================
#
# Label: 0
# in 16 and in 7 he was awarded with the french exchange by the specific ***smith*** for the places appearance .
# in october , jack sport refers to top units as leaders yet requires them to ***have*** a township in the word `` faculty appearance '' .
# ==================================================
#
# Label: 0
# in 1975 and in ***1979*** he was awarded with the nea grant by the national endowment for the arts agency .
# in edge , section ***line*** refers to european nations as awards yet requires them to have a threat in the section `` establishment choice '' .
# ==================================================
#
# Label: 0
# in 1975 and in 1979 he was awarded with the ***nea*** grant by the national endowment for the arts agency .
# in minnesota , state statute refers to such entities as ***towns*** yet requires them to have a name in the form `` name township '' .
# ==================================================
#
# Label: 0
# in 1986 ***and*** in 1986 he was awarded with the regional paul by the brief route for the lives copyright .
# in october ***,*** jack sport refers to top units as leaders yet requires them to have a township in the word `` faculty appearance '' .
# ==================================================
#
# Label: 1
# the flag is great , and in the banks when the ***1970s*** meet , the texas is always single with entire feet .
# the fixture is explosive , and in the years when the ***teams*** meet , the atmosphere is always hot with frequent riots .
# ==================================================
#
# Label: 1
# the understanding is short , and in ***the*** buildings when the rights meet , the airport is always strong with different cases .
# the fixture is explosive , and in ***the*** years when the teams meet , the atmosphere is always hot with frequent riots .
# ==================================================
#
# Label: 1
# the government is last , and in the nations when the ways meet , the network is always 20th with ***interesting*** islands .
# the flag is great , and in the banks when the 1970s meet , the texas is always single with ***entire*** feet .
# ==================================================
#
# Label: 0
# the fixture is explosive , and in ***the*** years when the teams meet , the atmosphere is always hot with frequent riots .
# he was also featured in open rail ***types*** shot for the second details russia harvard nature 1961 .
# ==================================================
#
# Label: 0
# the ***fixture*** is explosive , and in the years when the teams meet , the atmosphere is always hot with frequent riots .
# he ***was*** also featured in live service categories shot for the proper views spring card england ten .
# ==================================================
#
# Label: 0
# the flag is great , and in the banks when ***the*** 1970s meet , the texas is always single with entire feet .
# he was also featured in open rail types shot for ***the*** second details russia harvard nature 1961 .
# ==================================================
#
# Label: 0
# the fixture is explosive , and in the years when the teams meet , the ***atmosphere*** is always hot with frequent riots .
# he was also featured in live service categories shot for the proper views spring card ***england*** ten .
# ==================================================
#
# Label: 1
# it was founded in 100 and has earned an 3rd administration , entering son ***of*** the boston cross of executive right sections in 21 .
# it was founded in 1943 and has earned an academic box , entering student ***of*** the chicago oil of conservative way needs in 2010 .
# ==================================================
#
# Label: 1
# it was founded in 1943 and has ***earned*** an academic box , entering student of the chicago oil of conservative way needs in 2010 .
# it was founded in 100 and has ***earned*** an 3rd administration , entering son of the boston cross of executive right sections in 21 .
# ==================================================
#
# Label: 1
#  ***it*** was founded in 2006 and has earned an northern charge , entering team of the end home of certain bridge hours in 1984 .
#  ***it*** was founded in 1968 and has earned an international reputation , entering membership of the world federation of international music competitions in 1981 .
# ==================================================
#
# Label: 1
# it was founded in 100 and has earned an 3rd administration , entering son of the boston cross of ***executive*** right sections in 21 .
# it was founded in 2006 and has earned an northern charge , entering team of the end home of ***certain*** bridge hours in 1984 .
# ==================================================
#
# Label: 0
# it was founded in 100 and has earned an 3rd administration ***,*** entering son of the boston cross of executive right sections in 21 .
# this had the benefit of making one penny sterling exactly equal ***to*** two new newfoundland cents .
# ==================================================
#
# Label: 0
# it was founded in 100 and ***has*** earned an 3rd administration , entering son of the boston cross of executive right sections in 21 .
# this had the dispute of making ***29*** bay owner exactly ancient to 2001 many brown claims .
# ==================================================
#
# Label: 0
# it was founded in 2013 and has earned ***an*** rural institute , entering thing of the help conflict of light subject organizations in one .
# this had the benefit of making one penny ***sterling*** exactly equal to two new newfoundland cents .
# ==================================================
#
# Label: 0
# it was founded in 1943 ***and*** has earned an academic box , entering student of the chicago oil of conservative way needs in 2010 .
# this had the dispute of ***making*** 29 bay owner exactly ancient to 2001 many brown claims .
# ==================================================
#
# Label: 1
# the paper in mary products in the jewish peter , however , was not reflected ***unfortunately*** in the international risk which closed in 1992 .
# the rise in pupil numbers in the senior school , however , was not reflected ***unfortunately*** in the preparatory department which closed in 2004 .
# ==================================================
#
# Label: 1
# the encyclopedia in comment persons in the primary type , however , was not reflected unfortunately in the key english ***which*** closed in 1954 .
# the rise in pupil numbers in the senior school , however , was not reflected unfortunately in the preparatory department ***which*** closed in 2004 .
# ==================================================
#
# Label: 0
# the rise in pupil numbers in the senior ***school*** , however , was not reflected unfortunately in the preparatory department which closed in 2004 .
# it connects denver with the child species , ***armed*** production , and then west to individuals in amount .
# ==================================================
#
# Label: 0
# the loss in student sales in the last novel , however ***,*** was not reflected unfortunately in the little value which closed in 1949 .
# it connects denver with the child species , armed production , ***and*** then west to individuals in amount .
# ==================================================
#
# Label: 0
# the loss in student sales ***in*** the last novel , however , was not reflected unfortunately in the little value which closed in 1949 .
# it connects denver with the ***press*** women , asian manchester , and then west to issues in order .
# ==================================================
#
# Label: 0
# the ***loss*** in student sales in the last novel , however , was not reflected unfortunately in the little value which closed in 1949 .
# it ***connects*** denver with the florida forces , january case , and then west to colleges in gun .
# ==================================================
#
# Label: 1
# an cricket about a low prison , man of reviews , season , census , freedom ***,*** or press region that does not assert the candidate or america of its bus .
# an forest about a bad enemy , magazine of sales , length , template , association ***,*** or food michigan that does not assert the machine or development of his command .
# ==================================================
#
# Label: 1
# an article about a real person , group of people , band , club , company , or web content ***that*** does not assert the importance or significance of its subject .
# an cricket about a low prison , man of reviews , season , census , freedom , or press region ***that*** does not assert the candidate or america of its bus .
# ==================================================
#
# Label: 1
# an forest about a bad ***enemy*** , magazine of sales , length , template , association , or food michigan that does not assert the machine or development of his command .
# an article about a real ***person*** , group of people , band , club , company , or web content that does not assert the importance or significance of its subject .
# ==================================================
#
# Label: 0
# an article about ***a*** real person , group of people , band , club , company , or web content that does not assert the importance or significance of its subject .
# they shared an ***chart*** in much numbers , like military michigan , others 's references and the center of civil regions .
# ==================================================
#
# Label: 0
# an article about a real person , group ***of*** people , band , club , company , or web content that does not assert the importance or significance of its subject .
# they shared an guard in australian tracks , ***like*** russian chicago , claims 's thousands and the admin of female 1960s .
# ==================================================
#
# Label: 0
# an article about a real person , group of people , band , club , ***company*** , or web content that does not assert the importance or significance of its subject .
# they shared an chart in much numbers , like military michigan , others 's references ***and*** the center of civil regions .
# ==================================================
#
# Label: 0
# an article about a real person , ***group*** of people , band , club , company , or web content that does not assert the importance or significance of its subject .
# they shared an census in italian cities ***,*** like african south , topics 's copies and the farm of second brothers .
# ==================================================
#
# Label: 1
# despite your comparatively entire interested vandalism , the training of gun jazz was few and reliable until the behavior of the further ***chance*** .
# despite their comparatively enough golden sentence , the board of redirect nfl was 2nd and small until the one of the former ***branch*** .
# ==================================================
#
# Label: 1
# despite his comparatively final only election , ***the*** topic of person consensus was previous and sufficient until the office of the prime product .
# despite his comparatively german proper impact , ***the*** floor of character south was interested and equal until the failure of the royal agreement .
# ==================================================
#
# Label: 1
# despite ***his*** comparatively final only election , the topic of person consensus was previous and sufficient until the office of the prime product .
# despite ***its*** comparatively large geographic size , the population of washington county was sparse and small until the end of the 19th century .
# ==================================================
#
# Label: 1
# despite its comparatively large geographic size , ***the*** population of washington county was sparse and small until the end of the 19th century .
# despite their comparatively enough golden sentence , ***the*** board of redirect nfl was 2nd and small until the one of the former branch .
# ==================================================
#
# Label: 0
# despite his comparatively final only election ***,*** the topic of person consensus was previous and sufficient until the office of the prime product .
# several years later , chicken george ***unexpectedly*** returns , raises the spirits of his relatives and friends , and begins to plot their next step .
# ==================================================
#
# Label: 0
# despite your comparatively ***entire*** interested vandalism , the training of gun jazz was few and reliable until the behavior of the further chance .
# black regions later ***,*** inclusion act unexpectedly returns , raises the miles of our courts and powers , and begins to plot my difficult island .
# ==================================================
#
# Label: 0
# despite their comparatively enough golden sentence , the board of redirect nfl was 2nd and ***small*** until the one of the former branch .
# black regions later , inclusion act unexpectedly returns , raises the miles of our courts ***and*** powers , and begins to plot my difficult island .
# ==================================================
#
# Label: 0
# despite ***his*** comparatively final only election , the topic of person consensus was previous and sufficient until the office of the prime product .
# black ***regions*** later , inclusion act unexpectedly returns , raises the miles of our courts and powers , and begins to plot my difficult island .
# ==================================================
#
# Label: 1
# it is northern in what women he has been modified beyond having no competition and being christian to ***communicate*** .
# it is simple in what features he has been modified beyond having no april and being italian to ***communicate*** .
# ==================================================
#
# Label: 1
# it is unclear in what ways he has been modified beyond having ***no*** memory and being unable to communicate .
# it is executive in what pages he has been modified beyond having ***no*** afd and being primary to communicate .
# ==================================================
#
# Label: 1
# it is northern ***in*** what women he has been modified beyond having no competition and being christian to communicate .
# it is executive ***in*** what universities he has been modified beyond having no show and being rural to communicate .
# ==================================================
#
# Label: 0
# it is unclear in what ways he has been modified beyond having no ***memory*** and being unable to communicate .
# since then , that history has manifested as a color to the housing ***,*** as he 's logged more than 12 structures , mostly to newspapers and concept emergency actions .
# ==================================================
#
# Label: 0
# it is northern in what women he has been modified beyond having no competition and being ***christian*** to communicate .
# since then , that victoria has manifested as a virginia to the vietnam , as he ***'s*** logged more than 100 students , mostly to lives and medal infantry parents .
# ==================================================
#
# Label: 0
# it is unclear in what ways he has been ***modified*** beyond having no memory and being unable to communicate .
# since then , that victoria has manifested as a ***virginia*** to the vietnam , as he 's logged more than 100 students , mostly to lives and medal infantry parents .
# ==================================================
#
# Label: 0
# it is northern in what women he has been modified beyond having no competition and being christian to communicate ***.***
# since then , that history has manifested as a color to the housing , as he 's logged more ***than*** 12 structures , mostly to newspapers and concept emergency actions .
# ==================================================
#
# Label: 1
# whilst i am early ***this*** is possible , it does sound like road that needs to be verified .
# whilst i am sure ***this*** is correct , it does sound like something that needs to be verified .
# ==================================================
#
# Label: 1
#  ***whilst*** i am red this is critical , it does sound like round that needs to be verified .
#  ***whilst*** i am federal this is third , it does sound like result that needs to be verified .
# ==================================================
#
# Label: 0
# whilst i am sure this is correct , it does sound like ***something*** that needs to be verified .
# they are currently finishing the latest c in the white street plans ***view*** , post bands book everyone 1958 .
# ==================================================
#
# Label: 0
# whilst i am red ***this*** is critical , it does sound like round that needs to be verified .
# they are currently finishing ***the*** latest c in the white street plans view , post bands book everyone 1958 .
# ==================================================
#
# Label: 0
# whilst i am early this is possible , it does ***sound*** like road that needs to be verified .
# they are currently finishing the latest c in the white ***street*** plans view , post bands book everyone 1958 .
# ==================================================
#
# Label: 0
# whilst i am sure this is correct , it does sound like ***something*** that needs to be verified .
# they are currently finishing the latest hill in the san freedom brothers ***security*** , interest titles february wiki 1945 .
# ==================================================
#
# Label: 1
# museum bbc stood as the match field for the own common plant of several in ***story*** at the 27 democratic israel .
# text parliament stood as the government drama for the athletic hard freedom of upper in ***register*** at the 5 personal manchester .
# ==================================================
#
# Label: 1
# text parliament stood as the government drama for the athletic hard freedom of ***upper*** in register at the 5 personal manchester .
# community communication stood as the group meeting for the single unable body of ***annual*** in set at the 1999 neutral text .
# ==================================================
#
# Label: 1
# text parliament stood as the ***government*** drama for the athletic hard freedom of upper in register at the 5 personal manchester .
# building peace stood as the ***operation*** community for the german close purpose of direct in base at the 1977 successful museum .
# ==================================================
#
# Label: 1
# text ***parliament*** stood as the government drama for the athletic hard freedom of upper in register at the 5 personal manchester .
# museum ***bbc*** stood as the match field for the own common plant of several in story at the 27 democratic israel .
# ==================================================
#
# Label: 0
# community communication stood as the group meeting for the single unable body of ***annual*** in set at the 1999 neutral text .
# i have approached this request in modern drama , attempting to offer japanese ***candidates*** for improving the scotland .
# ==================================================
#
# Label: 0
# community communication stood as the group meeting for the single unable body of annual in ***set*** at the 1999 neutral text .
# i have approached this subject in good faith , attempting to offer constructive suggestions for ***improving*** the article .
# ==================================================
#
# Label: 0
# building peace stood as the operation community for the ***german*** close purpose of direct in base at the 1977 successful museum .
# i have approached this money in political difference , ***attempting*** to offer controversial companies for improving the portion .
# ==================================================
#
# Label: 0
# building peace stood as the operation community for the ***german*** close purpose of direct in base at the 1977 successful museum .
# i have approached this subject in good faith , ***attempting*** to offer constructive suggestions for improving the article .
# ==================================================
#
# Label: 1
# the subject health that was said to be duplicated in the 19th building of man categories in melbourne has now been deleted from the democratic maryland and there is no power honor existing on owner ***for*** province classes in move .
# the original information that was said to be duplicated in the old list of bus routes in sydney has now been deleted from the original page and there is no route information existing on wikipedia ***for*** bus routes in sydney .
# ==================================================
#
# Label: 1
# the grand department that was said to be duplicated in the sixth traffic of fiction words in address has now been deleted from the ***important*** bus and there is no aircraft variety existing on press for majority clubs in lead .
# the original information that was said to be duplicated in the old list of bus routes in sydney has now been deleted from the ***original*** page and there is no route information existing on wikipedia for bus routes in sydney .
# ==================================================
#
# Label: 1
# the upper ***country*** that was said to be duplicated in the urban policy of rate numbers in language has now been deleted from the important influence and there is no football point existing on science for power ones in law .
# the london ***beginning*** that was said to be duplicated in the visual world of heart islands in infantry has now been deleted from the active wrestling and there is no author chance existing on congress for sound days in knowledge .
# ==================================================
#
# Label: 0
# the original information that was said to ***be*** duplicated in the old list of bus routes in sydney has now been deleted from the original page and there is no route information existing on wikipedia for bus routes in sydney .
# following her corner at award he signed ***exclusively*** with offices comments in 1982 .
# ==================================================
#
# Label: 0
#  ***the*** grand department that was said to be duplicated in the sixth traffic of fiction words in address has now been deleted from the important bus and there is no aircraft variety existing on press for majority clubs in lead .
#  ***following*** its object at st he signed exclusively with officers users in 1987 .
# ==================================================
#
# Label: 0
#  ***the*** upper country that was said to be duplicated in the urban policy of rate numbers in language has now been deleted from the important influence and there is no football point existing on science for power ones in law .
#  ***following*** its object at st he signed exclusively with officers users in 1987 .
# ==================================================
#
# Label: 0
# the upper country that was said to be duplicated in ***the*** urban policy of rate numbers in language has now been deleted from the important influence and there is no football point existing on science for power ones in law .
# following your stage at book he signed exclusively with facilities ***houses*** in 1962 .
# ==================================================
#
# Label: 1
# he was the royal of only 1968 people ( the rare 2007 port ***dr*** .
# he was the 20th of only nine admins ( the worth 18 december ***dr*** .
# ==================================================
#
# Label: 1
# he was the ***historical*** of only 1958 episodes ( the asian 1987 influence dr .
# he was the ***20th*** of only nine admins ( the worth 18 december dr .
# ==================================================
#
# Label: 1
# he was the ***first*** of only four fathers ( the other three being dr .
# he was the ***royal*** of only 1968 people ( the rare 2007 port dr .
# ==================================================
#
# Label: 0
# he was the 20th of only nine admins ( the worth ***18*** december dr .
# this stage to result in the air of the likely families ***for*** your fine americans .
# ==================================================
#
# Label: 0
# he was the 20th of only nine admins ( the worth ***18*** december dr .
# this tend to result in the migration of the local people ***for*** their various needs .
# ==================================================
#
# Label: 0
# he was the 20th of only nine admins ( the ***worth*** 18 december dr .
# this matter to result in the press of the conservative ***studies*** for her scottish votes .
# ==================================================
#
# Label: 0
# he was the historical of only 1958 ***episodes*** ( the asian 1987 influence dr .
# this advertising to result in the industry ***of*** the irish points for its limited stations .
# ==================================================
#
# Label: 1
# however , i was still present to pick out times that could be improved just ***in*** the squadron , as an october of the urban set .
# however , i was still pacific to pick out plans that could be improved just ***in*** the producer , as an peer of the short security .
# ==================================================
#
# Label: 1
# however , i was still strong ***to*** pick out championships that could be improved just in the experience , as an story of the various thomas .
# however , i was still pacific ***to*** pick out plans that could be improved just in the producer , as an peer of the short security .
# ==================================================
#
# Label: 1
# however , i was still 1st to pick out groups that could be improved just in the ***republic*** , as an damage of the hong foundation .
# however , i was still pacific to pick out plans that could be improved just in the ***producer*** , as an peer of the short security .
# ==================================================
#
# Label: 1
#  ***however*** , i was still 1st to pick out groups that could be improved just in the republic , as an damage of the hong foundation .
#  ***however*** , i was still able to pick out things that could be improved just in the lead , as an example of the whole text .
# ==================================================
#
# Label: 0
# however , i was still present to pick out times that could be ***improved*** just in the squadron , as an october of the urban set .
# in 27 the personal station sold the railway subjects to the train and ***science*** is former .
# ==================================================
#
# Label: 0
# however , i was still 1st to pick out groups ***that*** could be improved just in the republic , as an damage of the hong foundation .
# in 1954 the british government sold the salvage rights to ***the*** ship and salvage is ongoing .
# ==================================================
#
# Label: 0
# however , i was still pacific to ***pick*** out plans that could be improved just in the producer , as an peer of the short security .
# in 27 the personal station sold the ***railway*** subjects to the train and science is former .
# ==================================================
#
# Label: 0
# however , i was still able to pick out things that could be improved just ***in*** the lead , as an example of the whole text .
# in 29 the long importance sold the health types to the talk and studio is ***bad*** .
# ==================================================
#
# Label: 1
# he became a major general in ***1966*** and was posted to director of civil works .
# he became a chief none in ***9*** and was posted to application of original rights .
# ==================================================
#
# Label: 1
# he became a great dispute in 1988 and was posted ***to*** author of sixth countries .
# he became a actual entry in 1952 and was posted ***to*** knowledge of due awards .
# ==================================================
#
# Label: 1
# he became a chief none in 9 and was posted ***to*** application of original rights .
# he became a actual entry in 1952 and was posted ***to*** knowledge of due awards .
# ==================================================
#
# Label: 1
# he ***became*** a major general in 1966 and was posted to director of civil works .
# he ***became*** a actual entry in 1952 and was posted to knowledge of due awards .
# ==================================================
#
# Label: 0
# he became a ***1st*** italy in 1945 and was posted to october of professional bands .
# in its character ***(*** [ [ anyone ] ] ) i see info times for these , so probably they are n't generally implemented .
# ==================================================
#
# Label: 0
# he became a chief none in 9 ***and*** was posted to application of original rights .
# in its character ( [ [ anyone ***]*** ] ) i see info times for these , so probably they are n't generally implemented .
# ==================================================
#
# Label: 0
#  ***he*** became a major general in 1966 and was posted to director of civil works .
#  ***in*** your movement ( [ [ letter ] ] ) i see status authorities for these , so probably they are n't generally implemented .
# ==================================================
#
# Label: 0
# he became a 1st italy in 1945 and ***was*** posted to october of professional bands .
# in my browser ( [ [ firefox ] ***]*** ) i see question marks for these , so probably they are n't generally implemented .
# ==================================================
#
# Label: 1
# front chance commander , who was legislative during ***tournament*** on level 13 , was under section but was never charged and testified against free churches .
# home piece member , who was primary during ***variety*** on sydney 24 , was under brother but was never charged and testified against initial hours .
# ==================================================
#
# Label: 1
# specialist israel rivera , who was present during abuse on october 25 , was ***under*** investigation but was never charged and testified against other soldiers .
# infantry district fiction , who was major during coverage on interest 1975 , was ***under*** knowledge but was never charged and testified against executive officers .
# ==================================================
#
# Label: 0
# peace cup law ***,*** who was cultural during administration on senate 2 , was under television but was never charged and testified against republican houses .
# another world insists ***that*** the egypt `` statement '' solely reflects the congress of teams quite adequately .
# ==================================================
#
# Label: 0
# specialist israel rivera , who was present during abuse on october ***25*** , was under investigation but was never charged and testified against other soldiers .
# another engineering insists that the word `` producer '' solely reflects ***the*** understanding of feet quite adequately .
# ==================================================
#
# Label: 0
# peace cup law , who ***was*** cultural during administration on senate 2 , was under television but was never charged and testified against republican houses .
# another store insists that the ***template*** `` age '' solely reflects the view of colleges quite adequately .
# ==================================================
#
# Label: 0
# specialist israel rivera , who was present during abuse on ***october*** 25 , was under investigation but was never charged and testified against other soldiers .
# another bbc insists that the state `` gold '' solely ***reflects*** the authority of times quite adequately .
# ==================================================
#
# Label: 1
# after some year e , a railroad debut came from the administrator of the manchester ***.***
# after some redirect war , a london retirement came from the premier of the israel ***.***
# ==================================================
#
# Label: 1
# after some ***week*** edge , a stone report came from the department of the squadron .
# after some ***baseball*** korea , a test bar came from the usa of the context .
# ==================================================
#
# Label: 1
# after some baseball korea , a test bar ***came*** from the usa of the context .
# after some week edge , a stone report ***came*** from the department of the squadron .
# ==================================================
#
# Label: 0
# after some baseball ***korea*** , a test bar came from the usa of the context .
# then he began ***a*** web to collect james for the appearance to my news for the lead of england of the john ( was collected 2013 hundred students ) .
# ==================================================
#
# Label: 0
# after some redirect war , a london retirement ***came*** from the premier of the israel .
# then he began a web to collect james ***for*** the appearance to my news for the lead of england of the john ( was collected 2013 hundred students ) .
# ==================================================
#
# Label: 0
# after some year e ***,*** a railroad debut came from the administrator of the manchester .
# then he began a ***attempt*** to collect banks for the vietnam to its professor for the e of child of the proof ( was collected 1967 1970 rules ) .
# ==================================================
#
# Label: 0
# after some year e , a railroad debut came from the administrator of ***the*** manchester .
# then he began a wing to collect americans for the band to their ***paul*** for the stage of one of the politician ( was collected 8 2001 discussions ) .
# ==================================================
#
# Label: 1
# i hate to use precedent but there are a lot worse articles on worse albums on ***wikipedia*** that have pages .
# i hate to use township but there are a washington worse records on worse numbers on ***port*** that have politics .
# ==================================================
#
# Label: 1
# i hate to use township but there are a washington worse records on worse numbers on port that have politics ***.***
# i hate to use figure but there are a machine worse feet on worse readers on end that have figures ***.***
# ==================================================
#
# Label: 1
# i hate to use government but there are a doctor worse services on worse works ***on*** sun that have courses .
# i hate to use run but there are a rail worse homes on worse students ***on*** performance that have teams .
# ==================================================
#
# Label: 0
# i hate to use run but ***there*** are a rail worse homes on worse students on performance that have teams .
# you should not be month warring ***with*** type over a sixth age that you are directly involved with .
# ==================================================
#
# Label: 0
# i hate to use government but there are a doctor worse services on ***worse*** works on sun that have courses .
# you should not be competition warring with dvd over a total home that ***you*** are directly involved with .
# ==================================================
#
# Label: 0
# i hate to use run but there are a rail worse homes on worse students on performance ***that*** have teams .
# you should not be improvement warring with silver over a red television that you are directly involved ***with*** .
# ==================================================
#
# Label: 0
# i hate to use government but there are ***a*** doctor worse services on worse works on sun that have courses .
# you should not be month warring with type ***over*** a sixth age that you are directly involved with .
# ==================================================
